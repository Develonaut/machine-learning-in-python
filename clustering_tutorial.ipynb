# %% [markdown]
# # Clustering Tutorial

# %% [markdown]
# ## What's in scope
# - what is clustering?
# - clustering algorithms
#     - k-means
#     - hierarchical clustering
#         - affinity propagation
# - clustering word embeddings
#     - how to get insight from clusters of word embeddings
# - labeling clusters using a hierarchy

# %% [markdown]
# ## What's not in scope?
# - any other clustering algorithm
# - any other unsupervised learning algorithm

# %% [markdown]
# # What is Clustering?
#
# Remember how we had feature vectors (or word embeddings) that lived in n-dimensional space? Clustering is an [unsupervised learning algorithm](https://en.wikipedia.org/wiki/Unsupervised_learning) that puts similar feature vectors into the same group or cluster.
#
# ![hierarchical clustering](figures/hierarchical-clustering.gif)
#
# ## When should I use clustering?
#
# If you're wondering "what don't I know about this data set?", clustering will give some insight.
#
# Clustering can also be used as a feature extraction piece in the predictive modeling process.

# %%
# first, let's load in the FastText model from before so we're ready to cluster them
import os
from gensim.models import FastText

model_file = os.path.join('models', 'phrased_got_ft.model')
model = FastText.load(model_file)
print("yolo")
# Out:
# yolo

# %%
# in all of these clustering trials, we'll need a way to link
# the word vector from FastText to the word itself. 

"""
---------------------------------------------------------------
Objective: Keep track of your words and vectors in a smart way
---------------------------------------------------------------
each clustering algorithm will need the input as an iterable of 
vectors (and nothing else)

it'll return a cluster model object, which has an attribute model.labels_

These labels will be an index of the cluster this vector fell into

But we want to know what _word_ fell into each cluster

So we need a map to know which vector corrresponds to each word

You might want a few jupyter notebook cells to explore 
what the FastText model has (maybe a vocab attribute?)
"""
model.wv.vocab
# Out:
# {'what': <gensim.models.keyedvectors.Vocab at 0x2401d3382c8>,
#  'expect': <gensim.models.keyedvectors.Vocab at 0x2401d338408>,
#  'they’re': <gensim.models.keyedvectors.Vocab at 0x2401d338448>,
#  'savages': <gensim.models.keyedvectors.Vocab at 0x2401d3384c8>,
#  'one': <gensim.models.keyedvectors.Vocab at 0x2401d338548>,
#  'lot': <gensim.models.keyedvectors.Vocab at 0x2401d3385c8>,
#  'a': <gensim.models.keyedvectors.Vocab at 0x2401d338608>,
#  'goat': <gensim.models.keyedvectors.Vocab at 0x2401d338688>,
#  'from': <gensim.models.keyedvectors.Vocab at 0x2401d338708>,
#  'another': <gensim.models.keyedvectors.Vocab at 0x2401d338788>,
#  'and': <gensim.models.keyedvectors.Vocab at 0x2401d338808>,
#  'before': <gensim.models.keyedvectors.Vocab at 0x2401d338888>,
#  'you': <gensim.models.keyedvectors.Vocab at 0x2401d338908>,
#  'know': <gensim.models.keyedvectors.Vocab at 0x2401d338988>,
#  'it': <gensim.models.keyedvectors.Vocab at 0x2401d338a08>,
#  'each': <gensim.models.keyedvectors.Vocab at 0x2401d338a88>,
#  'other': <gensim.models.keyedvectors.Vocab at 0x2401d338b08>,
#  'to': <gensim.models.keyedvectors.Vocab at 0x2401d338b88>,
#  'pieces': <gensim.models.keyedvectors.Vocab at 0x2401d338c08>,
#  'wildlings': <gensim.models.keyedvectors.Vocab at 0x2401d338c88>,
#  'do': <gensim.models.keyedvectors.Vocab at 0x2401d338d08>,
#  'this': <gensim.models.keyedvectors.Vocab at 0x2401d338d88>,
#  'not': <gensim.models.keyedvectors.Vocab at 0x2401d338e08>,
#  'ever': <gensim.models.keyedvectors.Vocab at 0x2401d338e88>,
#  'in': <gensim.models.keyedvectors.Vocab at 0x2401d338f08>,
#  'my': <gensim.models.keyedvectors.Vocab at 0x2401d338f88>,
#  'life': <gensim.models.keyedvectors.Vocab at 0x2401d339048>,
#  'close': <gensim.models.keyedvectors.Vocab at 0x2401d3390c8>,
#  'as': <gensim.models.keyedvectors.Vocab at 0x2401d339148>,
#  'any': <gensim.models.keyedvectors.Vocab at 0x2401d3391c8>,
#  'man_would': <gensim.models.keyedvectors.Vocab at 0x2401d339248>,
#  'the': <gensim.models.keyedvectors.Vocab at 0x2401d3392c8>,
#  'dead': <gensim.models.keyedvectors.Vocab at 0x2401d339348>,
#  'frighten': <gensim.models.keyedvectors.Vocab at 0x2401d3393c8>,
#  'our': <gensim.models.keyedvectors.Vocab at 0x2401d339448>,
#  'orders': <gensim.models.keyedvectors.Vocab at 0x2401d3394c8>,
#  'were': <gensim.models.keyedvectors.Vocab at 0x2401d339548>,
#  'we': <gensim.models.keyedvectors.Vocab at 0x2401d3395c8>,
#  'them': <gensim.models.keyedvectors.Vocab at 0x2401d339648>,
#  'they': <gensim.models.keyedvectors.Vocab at 0x2401d3396c8>,
#  'won’t': <gensim.models.keyedvectors.Vocab at 0x2401d339708>,
#  'trouble': <gensim.models.keyedvectors.Vocab at 0x2401d339788>,
#  'us': <gensim.models.keyedvectors.Vocab at 0x2401d339808>,
#  'no': <gensim.models.keyedvectors.Vocab at 0x2401d339888>,
#  'more': <gensim.models.keyedvectors.Vocab at 0x2401d339908>,
#  'don’t_think': <gensim.models.keyedvectors.Vocab at 0x2401d339948>,
#  'he’ll': <gensim.models.keyedvectors.Vocab at 0x2401d339988>,
#  'ask': <gensim.models.keyedvectors.Vocab at 0x2401d339a08>,
#  'how': <gensim.models.keyedvectors.Vocab at 0x2401d339a88>,
#  'died': <gensim.models.keyedvectors.Vocab at 0x2401d339b08>,
#  'get_back': <gensim.models.keyedvectors.Vocab at 0x2401d339b88>,
#  'on': <gensim.models.keyedvectors.Vocab at 0x2401d339c08>,
#  'your': <gensim.models.keyedvectors.Vocab at 0x2401d339c88>,
#  'horse': <gensim.models.keyedvectors.Vocab at 0x2401d339d08>,
#  'dead_men': <gensim.models.keyedvectors.Vocab at 0x2401d339d88>,
#  'seem': <gensim.models.keyedvectors.Vocab at 0x2401d339e08>,
#  'have': <gensim.models.keyedvectors.Vocab at 0x2401d339e88>,
#  'moved': <gensim.models.keyedvectors.Vocab at 0x2401d339f08>,
#  'camp': <gensim.models.keyedvectors.Vocab at 0x2401d339f88>,
#  'here': <gensim.models.keyedvectors.Vocab at 0x2401d340048>,
#  'see': <gensim.models.keyedvectors.Vocab at 0x2401d3400c8>,
#  'where': <gensim.models.keyedvectors.Vocab at 0x2401d340148>,
#  'went': <gensim.models.keyedvectors.Vocab at 0x2401d3401c8>,
#  'is': <gensim.models.keyedvectors.Vocab at 0x2401d340248>,
#  'it’s': <gensim.models.keyedvectors.Vocab at 0x2401d340288>,
#  'go': <gensim.models.keyedvectors.Vocab at 0x2401d340308>,
#  'father’s': <gensim.models.keyedvectors.Vocab at 0x2401d340348>,
#  'watching': <gensim.models.keyedvectors.Vocab at 0x2401d3403c8>,
#  'mother': <gensim.models.keyedvectors.Vocab at 0x2401d340448>,
#  'always': <gensim.models.keyedvectors.Vocab at 0x2401d3404c8>,
#  'well_done': <gensim.models.keyedvectors.Vocab at 0x2401d340548>,
#  'thank': <gensim.models.keyedvectors.Vocab at 0x2401d3405c8>,
#  'i': <gensim.models.keyedvectors.Vocab at 0x2401d340608>,
#  'love': <gensim.models.keyedvectors.Vocab at 0x2401d340688>,
#  'that': <gensim.models.keyedvectors.Vocab at 0x2401d340708>,
#  'you’ve': <gensim.models.keyedvectors.Vocab at 0x2401d340748>,
#  'managed': <gensim.models.keyedvectors.Vocab at 0x2401d3407c8>,
#  'get': <gensim.models.keyedvectors.Vocab at 0x2401d340848>,
#  'which': <gensim.models.keyedvectors.Vocab at 0x2401d3408c8>,
#  'at': <gensim.models.keyedvectors.Vocab at 0x2401d340948>,
#  'ten': <gensim.models.keyedvectors.Vocab at 0x2401d3409c8>,
#  'keep': <gensim.models.keyedvectors.Vocab at 0x2401d340a48>,
#  'practicing': <gensim.models.keyedvectors.Vocab at 0x2401d340ac8>,
#  'bran': <gensim.models.keyedvectors.Vocab at 0x2401d340b48>,
#  'too': <gensim.models.keyedvectors.Vocab at 0x2401d340bc8>,
#  'jon': <gensim.models.keyedvectors.Vocab at 0x2401d340c48>,
#  'quick': <gensim.models.keyedvectors.Vocab at 0x2401d340cc8>,
#  'faster': <gensim.models.keyedvectors.Vocab at 0x2401d340d48>,
#  'just': <gensim.models.keyedvectors.Vocab at 0x2401d340dc8>,
#  'rode': <gensim.models.keyedvectors.Vocab at 0x2401d340e48>,
#  'hills': <gensim.models.keyedvectors.Vocab at 0x2401d340ec8>,
#  'they’ve': <gensim.models.keyedvectors.Vocab at 0x2401d340f08>,
#  'captured': <gensim.models.keyedvectors.Vocab at 0x2401d340f88>,
#  'night’s_watch': <gensim.models.keyedvectors.Vocab at 0x2401d340fc8>,
#  'lads': <gensim.models.keyedvectors.Vocab at 0x2401d345088>,
#  'saddle': <gensim.models.keyedvectors.Vocab at 0x2401d345108>,
#  'their': <gensim.models.keyedvectors.Vocab at 0x2401d345188>,
#  'horses': <gensim.models.keyedvectors.Vocab at 0x2401d345208>,
#  'he': <gensim.models.keyedvectors.Vocab at 0x2401d345288>,
#  'swore_an_oath': <gensim.models.keyedvectors.Vocab at 0x2401d345308>,
#  'cat': <gensim.models.keyedvectors.Vocab at 0x2401d345388>,
#  'law': <gensim.models.keyedvectors.Vocab at 0x2401d345408>,
#  'lady': <gensim.models.keyedvectors.Vocab at 0x2401d345488>,
#  'tell': <gensim.models.keyedvectors.Vocab at 0x2401d345508>,
#  'he’s_coming': <gensim.models.keyedvectors.Vocab at 0x2401d345548>,
#  'ned': <gensim.models.keyedvectors.Vocab at 0x2401d3455c8>,
#  'young': <gensim.models.keyedvectors.Vocab at 0x2401d345648>,
#  'such': <gensim.models.keyedvectors.Vocab at 0x2401d3456c8>,
#  'things': <gensim.models.keyedvectors.Vocab at 0x2401d345748>,
#  'be': <gensim.models.keyedvectors.Vocab at 0x2401d3457c8>,
#  'boy': <gensim.models.keyedvectors.Vocab at 0x2401d345848>,
#  'forever': <gensim.models.keyedvectors.Vocab at 0x2401d3458c8>,
#  'winter_is_coming': <gensim.models.keyedvectors.Vocab at 0x2401d345908>,
#  'lad': <gensim.models.keyedvectors.Vocab at 0x2401d345988>,
#  'rest': <gensim.models.keyedvectors.Vocab at 0x2401d345a08>,
#  'white_walkers': <gensim.models.keyedvectors.Vocab at 0x2401d345a88>,
#  'saw_the_white_walkers': <gensim.models.keyedvectors.Vocab at 0x2401d345ac8>,
#  'saw': <gensim.models.keyedvectors.Vocab at 0x2401d345b48>,
#  'broke': <gensim.models.keyedvectors.Vocab at 0x2401d345bc8>,
#  'oath': <gensim.models.keyedvectors.Vocab at 0x2401d345c48>,
#  'i’m': <gensim.models.keyedvectors.Vocab at 0x2401d345c88>,
#  'should': <gensim.models.keyedvectors.Vocab at 0x2401d345d08>,
#  'gone': <gensim.models.keyedvectors.Vocab at 0x2401d345d88>,
#  'warned': <gensim.models.keyedvectors.Vocab at 0x2401d345e08>,
#  'but': <gensim.models.keyedvectors.Vocab at 0x2401d345e88>,
#  'if': <gensim.models.keyedvectors.Vocab at 0x2401d345f08>,
#  'can': <gensim.models.keyedvectors.Vocab at 0x2401d345f88>,
#  'family': <gensim.models.keyedvectors.Vocab at 0x2401d349048>,
#  'coward': <gensim.models.keyedvectors.Vocab at 0x2401d3490c8>,
#  'sorry': <gensim.models.keyedvectors.Vocab at 0x2401d349148>,
#  'first_of_his_name': <gensim.models.keyedvectors.Vocab at 0x2401d349188>,
#  'away': <gensim.models.keyedvectors.Vocab at 0x2401d349208>,
#  'king_of_the_andals_and_the_first_men': <gensim.models.keyedvectors.Vocab at 0x2401d349248>,
#  'father': <gensim.models.keyedvectors.Vocab at 0x2401d3492c8>,
#  'will': <gensim.models.keyedvectors.Vocab at 0x2401d349348>,
#  'lord_of_the_seven_kingdoms_and_protector': <gensim.models.keyedvectors.Vocab at 0x2401d349388>,
#  'of': <gensim.models.keyedvectors.Vocab at 0x2401d349408>,
#  'realm': <gensim.models.keyedvectors.Vocab at 0x2401d349488>,
#  'house_stark': <gensim.models.keyedvectors.Vocab at 0x2401d349508>,
#  'lord_of_winterfell_and_warden_of_the_north': <gensim.models.keyedvectors.Vocab at 0x2401d349548>,
#  'sentence_you_to_die': <gensim.models.keyedvectors.Vocab at 0x2401d349588>,
#  'did': <gensim.models.keyedvectors.Vocab at 0x2401d349608>,
#  'well': <gensim.models.keyedvectors.Vocab at 0x2401d349688>,
#  'understand': <gensim.models.keyedvectors.Vocab at 0x2401d349708>,
#  'why': <gensim.models.keyedvectors.Vocab at 0x2401d349788>,
#  'said': <gensim.models.keyedvectors.Vocab at 0x2401d349808>,
#  'was': <gensim.models.keyedvectors.Vocab at 0x2401d349888>,
#  'had': <gensim.models.keyedvectors.Vocab at 0x2401d349908>,
#  'kill': <gensim.models.keyedvectors.Vocab at 0x2401d349988>,
#  'him': <gensim.models.keyedvectors.Vocab at 0x2401d349a08>,
#  'way': <gensim.models.keyedvectors.Vocab at 0x2401d349a88>,
#  'sword': <gensim.models.keyedvectors.Vocab at 0x2401d349b08>,
#  'true': <gensim.models.keyedvectors.Vocab at 0x2401d349b88>,
#  'been': <gensim.models.keyedvectors.Vocab at 0x2401d349c08>,
#  'so': <gensim.models.keyedvectors.Vocab at 0x2401d349c88>,
#  'lying': <gensim.models.keyedvectors.Vocab at 0x2401d349d08>,
#  'madman': <gensim.models.keyedvectors.Vocab at 0x2401d349d88>,
#  'sees': <gensim.models.keyedvectors.Vocab at 0x2401d349e08>,
#  'mountain': <gensim.models.keyedvectors.Vocab at 0x2401d349e88>,
#  'lion': <gensim.models.keyedvectors.Vocab at 0x2401d349f08>,
#  'there': <gensim.models.keyedvectors.Vocab at 0x2401d349f88>,
#  'are': <gensim.models.keyedvectors.Vocab at 0x2401d34f048>,
#  'lions': <gensim.models.keyedvectors.Vocab at 0x2401d34f0c8>,
#  'these': <gensim.models.keyedvectors.Vocab at 0x2401d34f148>,
#  'woods': <gensim.models.keyedvectors.Vocab at 0x2401d34f1c8>,
#  'direwolf': <gensim.models.keyedvectors.Vocab at 0x2401d34f248>,
#  'tough_old': <gensim.models.keyedvectors.Vocab at 0x2401d34f2c8>,
#  'beast': <gensim.models.keyedvectors.Vocab at 0x2401d34f348>,
#  'now': <gensim.models.keyedvectors.Vocab at 0x2401d34f3c8>,
#  'five': <gensim.models.keyedvectors.Vocab at 0x2401d34f448>,
#  'down': <gensim.models.keyedvectors.Vocab at 0x2401d34f4c8>,
#  'better': <gensim.models.keyedvectors.Vocab at 0x2401d34f548>,
#  'last': <gensim.models.keyedvectors.Vocab at 0x2401d34f5c8>,
#  'without': <gensim.models.keyedvectors.Vocab at 0x2401d34f648>,
#  'put': <gensim.models.keyedvectors.Vocab at 0x2401d34f6c8>,
#  'blade': <gensim.models.keyedvectors.Vocab at 0x2401d34f748>,
#  'please': <gensim.models.keyedvectors.Vocab at 0x2401d34f7c8>,
#  'i’m_sorry': <gensim.models.keyedvectors.Vocab at 0x2401d34f808>,
#  'train': <gensim.models.keyedvectors.Vocab at 0x2401d34f888>,
#  'yourselves': <gensim.models.keyedvectors.Vocab at 0x2401d34f908>,
#  'feed': <gensim.models.keyedvectors.Vocab at 0x2401d34f988>,
#  'die': <gensim.models.keyedvectors.Vocab at 0x2401d34fa08>,
#  'bury': <gensim.models.keyedvectors.Vocab at 0x2401d34fa88>,
#  'about': <gensim.models.keyedvectors.Vocab at 0x2401d34fb08>,
#  'one’s': <gensim.models.keyedvectors.Vocab at 0x2401d34fb48>,
#  'yours': <gensim.models.keyedvectors.Vocab at 0x2401d34fbc8>,
#  'snow': <gensim.models.keyedvectors.Vocab at 0x2401d34fc48>,
#  'brother': <gensim.models.keyedvectors.Vocab at 0x2401d34fcc8>,
#  'feel': <gensim.models.keyedvectors.Vocab at 0x2401d34fd48>,
#  'duty': <gensim.models.keyedvectors.Vocab at 0x2401d34fdc8>,
#  'warn': <gensim.models.keyedvectors.Vocab at 0x2401d34fe48>,
#  'worry': <gensim.models.keyedvectors.Vocab at 0x2401d34fec8>,
#  'much': <gensim.models.keyedvectors.Vocab at 0x2401d34ff48>,
#  'starting': <gensim.models.keyedvectors.Vocab at 0x2401d34ffc8>,
#  'show': <gensim.models.keyedvectors.Vocab at 0x2401d512088>,
#  'never': <gensim.models.keyedvectors.Vocab at 0x2401d512108>,
#  'anything': <gensim.models.keyedvectors.Vocab at 0x2401d512188>,
#  'when': <gensim.models.keyedvectors.Vocab at 0x2401d512208>,
#  'seven': <gensim.models.keyedvectors.Vocab at 0x2401d512288>,
#  'off': <gensim.models.keyedvectors.Vocab at 0x2401d512308>,
#  'casterly_rock': <gensim.models.keyedvectors.Vocab at 0x2401d512388>,
#  'hundred': <gensim.models.keyedvectors.Vocab at 0x2401d512408>,
#  'foot': <gensim.models.keyedvectors.Vocab at 0x2401d512488>,
#  'drop': <gensim.models.keyedvectors.Vocab at 0x2401d512508>,
#  'into': <gensim.models.keyedvectors.Vocab at 0x2401d512588>,
#  'water': <gensim.models.keyedvectors.Vocab at 0x2401d512608>,
#  'afraid': <gensim.models.keyedvectors.Vocab at 0x2401d512688>,
#  'nothing': <gensim.models.keyedvectors.Vocab at 0x2401d512708>,
#  'until': <gensim.models.keyedvectors.Vocab at 0x2401d512788>,
#  'told': <gensim.models.keyedvectors.Vocab at 0x2401d512808>,
#  'we’re': <gensim.models.keyedvectors.Vocab at 0x2401d512848>,
#  'lannisters': <gensim.models.keyedvectors.Vocab at 0x2401d5128c8>,
#  'jon_arryn': <gensim.models.keyedvectors.Vocab at 0x2401d512948>,
#  'someone': <gensim.models.keyedvectors.Vocab at 0x2401d5129c8>,
#  'husband': <gensim.models.keyedvectors.Vocab at 0x2401d512a48>,
#  'hand_of_the_king': <gensim.models.keyedvectors.Vocab at 0x2401d512a88>,
#  'all': <gensim.models.keyedvectors.Vocab at 0x2401d512b08>,
#  'years': <gensim.models.keyedvectors.Vocab at 0x2401d512b88>,
#  'like': <gensim.models.keyedvectors.Vocab at 0x2401d512c08>,
#  'an': <gensim.models.keyedvectors.Vocab at 0x2401d512c88>,
#  'outsider': <gensim.models.keyedvectors.Vocab at 0x2401d512d08>,
#  'come': <gensim.models.keyedvectors.Vocab at 0x2401d512d88>,
#  'wonder': <gensim.models.keyedvectors.Vocab at 0x2401d512e08>,
#  'old_gods': <gensim.models.keyedvectors.Vocab at 0x2401d512e88>,
#  'agree': <gensim.models.keyedvectors.Vocab at 0x2401d512f08>,
#  'gods': <gensim.models.keyedvectors.Vocab at 0x2401d512f88>,
#  'with': <gensim.models.keyedvectors.Vocab at 0x2401d519048>,
#  'rules': <gensim.models.keyedvectors.Vocab at 0x2401d5190c8>,
#  'me': <gensim.models.keyedvectors.Vocab at 0x2401d519148>,
#  'fever': <gensim.models.keyedvectors.Vocab at 0x2401d5191c8>,
#  'took': <gensim.models.keyedvectors.Vocab at 0x2401d519248>,
#  'both': <gensim.models.keyedvectors.Vocab at 0x2401d5192c8>,
#  'health': <gensim.models.keyedvectors.Vocab at 0x2401d519348>,
#  'gods_be_good': <gensim.models.keyedvectors.Vocab at 0x2401d5193c8>,
#  'raven': <gensim.models.keyedvectors.Vocab at 0x2401d519448>,
#  'brought': <gensim.models.keyedvectors.Vocab at 0x2401d5194c8>,
#  'news': <gensim.models.keyedvectors.Vocab at 0x2401d519548>,
#  'for': <gensim.models.keyedvectors.Vocab at 0x2401d5195c8>,
#  'winterfell': <gensim.models.keyedvectors.Vocab at 0x2401d519648>,
#  'queen': <gensim.models.keyedvectors.Vocab at 0x2401d5196c8>,
#  'far_north': <gensim.models.keyedvectors.Vocab at 0x2401d519748>,
#  'there’s': <gensim.models.keyedvectors.Vocab at 0x2401d519788>,
#  'only': <gensim.models.keyedvectors.Vocab at 0x2401d519808>,
#  'one_thing': <gensim.models.keyedvectors.Vocab at 0x2401d519888>,
#  'he’s': <gensim.models.keyedvectors.Vocab at 0x2401d5198c8>,
#  'after': <gensim.models.keyedvectors.Vocab at 0x2401d519948>,
#  'need': <gensim.models.keyedvectors.Vocab at 0x2401d5199c8>,
#  'plenty': <gensim.models.keyedvectors.Vocab at 0x2401d519a48>,
#  'candles': <gensim.models.keyedvectors.Vocab at 0x2401d519ac8>,
#  'lord': <gensim.models.keyedvectors.Vocab at 0x2401d519b48>,
#  'chamber': <gensim.models.keyedvectors.Vocab at 0x2401d519bc8>,
#  'reads': <gensim.models.keyedvectors.Vocab at 0x2401d519c48>,
#  'night': <gensim.models.keyedvectors.Vocab at 0x2401d519cc8>,
#  'drinks': <gensim.models.keyedvectors.Vocab at 0x2401d519d48>,
#  'drink': <gensim.models.keyedvectors.Vocab at 0x2401d519dc8>,
#  'man': <gensim.models.keyedvectors.Vocab at 0x2401d519e48>,
#  'his': <gensim.models.keyedvectors.Vocab at 0x2401d519ec8>,
#  'we’ve': <gensim.models.keyedvectors.Vocab at 0x2401d519f08>,
#  'up': <gensim.models.keyedvectors.Vocab at 0x2401d519f88>,
#  'eight': <gensim.models.keyedvectors.Vocab at 0x2401d51c048>,
#  'barrels': <gensim.models.keyedvectors.Vocab at 0x2401d51c0c8>,
#  'ale': <gensim.models.keyedvectors.Vocab at 0x2401d51c148>,
#  'perhaps': <gensim.models.keyedvectors.Vocab at 0x2401d51c1c8>,
#  'out': <gensim.models.keyedvectors.Vocab at 0x2401d51c248>,
#  'case': <gensim.models.keyedvectors.Vocab at 0x2401d51c2c8>,
#  'pretty': <gensim.models.keyedvectors.Vocab at 0x2401d51c348>,
#  'king': <gensim.models.keyedvectors.Vocab at 0x2401d51c3c8>,
#  'bet': <gensim.models.keyedvectors.Vocab at 0x2401d51c448>,
#  'hear': <gensim.models.keyedvectors.Vocab at 0x2401d51c4c8>,
#  'she': <gensim.models.keyedvectors.Vocab at 0x2401d51c548>,
#  'think': <gensim.models.keyedvectors.Vocab at 0x2401d51c5c8>,
#  'those': <gensim.models.keyedvectors.Vocab at 0x2401d51c648>,
#  'southern': <gensim.models.keyedvectors.Vocab at 0x2401d51c6c8>,
#  'girls': <gensim.models.keyedvectors.Vocab at 0x2401d51c748>,
#  'gets': <gensim.models.keyedvectors.Vocab at 0x2401d51c7c8>,
#  'stab': <gensim.models.keyedvectors.Vocab at 0x2401d51c848>,
#  'right': <gensim.models.keyedvectors.Vocab at 0x2401d51c8c8>,
#  'royal': <gensim.models.keyedvectors.Vocab at 0x2401d51c948>,
#  'good': <gensim.models.keyedvectors.Vocab at 0x2401d51c9c8>,
#  'met': <gensim.models.keyedvectors.Vocab at 0x2401d51ca48>,
#  'girl': <gensim.models.keyedvectors.Vocab at 0x2401d51cac8>,
#  'likes': <gensim.models.keyedvectors.Vocab at 0x2401d51cb48>,
#  'than': <gensim.models.keyedvectors.Vocab at 0x2401d51cbc8>,
#  'own': <gensim.models.keyedvectors.Vocab at 0x2401d51cc48>,
#  'hair': <gensim.models.keyedvectors.Vocab at 0x2401d51ccc8>,
#  'grow': <gensim.models.keyedvectors.Vocab at 0x2401d51cd48>,
#  'fast': <gensim.models.keyedvectors.Vocab at 0x2401d51cdc8>,
#  'brandon': <gensim.models.keyedvectors.Vocab at 0x2401d51ce48>,
#  'he’s_got': <gensim.models.keyedvectors.Vocab at 0x2401d51ce88>,
#  'hundreds': <gensim.models.keyedvectors.Vocab at 0x2401d51cf08>,
#  'people': <gensim.models.keyedvectors.Vocab at 0x2401d51cf88>,
#  'road': <gensim.models.keyedvectors.Vocab at 0x2401d520048>,
#  'promise': <gensim.models.keyedvectors.Vocab at 0x2401d5200c8>,
#  'look': <gensim.models.keyedvectors.Vocab at 0x2401d520148>,
#  'feet': <gensim.models.keyedvectors.Vocab at 0x2401d5201c8>,
#  'lie': <gensim.models.keyedvectors.Vocab at 0x2401d520248>,
#  'run': <gensim.models.keyedvectors.Vocab at 0x2401d5202c8>,
#  'find': <gensim.models.keyedvectors.Vocab at 0x2401d520348>,
#  'where’s': <gensim.models.keyedvectors.Vocab at 0x2401d520388>,
#  'arya': <gensim.models.keyedvectors.Vocab at 0x2401d520408>,
#  'sansa': <gensim.models.keyedvectors.Vocab at 0x2401d520488>,
#  'sister': <gensim.models.keyedvectors.Vocab at 0x2401d520508>,
#  'hey_hey': <gensim.models.keyedvectors.Vocab at 0x2401d520588>,
#  'doing': <gensim.models.keyedvectors.Vocab at 0x2401d520608>,
#  'move': <gensim.models.keyedvectors.Vocab at 0x2401d520688>,
#  'grace': <gensim.models.keyedvectors.Vocab at 0x2401d520708>,
#  'you’ve_got': <gensim.models.keyedvectors.Vocab at 0x2401d520748>,
#  'fat': <gensim.models.keyedvectors.Vocab at 0x2401d5207c8>,
#  'nine_years': <gensim.models.keyedvectors.Vocab at 0x2401d520848>,
#  'haven’t': <gensim.models.keyedvectors.Vocab at 0x2401d520888>,
#  'seen': <gensim.models.keyedvectors.Vocab at 0x2401d520908>,
#  'hell': <gensim.models.keyedvectors.Vocab at 0x2401d520988>,
#  'guarding': <gensim.models.keyedvectors.Vocab at 0x2401d520a08>,
#  'north': <gensim.models.keyedvectors.Vocab at 0x2401d520a88>,
#  'shut': <gensim.models.keyedvectors.Vocab at 0x2401d520b08>,
#  'ooh': <gensim.models.keyedvectors.Vocab at 0x2401d520b88>,
#  'show_us': <gensim.models.keyedvectors.Vocab at 0x2401d520c08>,
#  'you’ll': <gensim.models.keyedvectors.Vocab at 0x2401d520c48>,
#  'soldier': <gensim.models.keyedvectors.Vocab at 0x2401d520cc8>,
#  'that’s': <gensim.models.keyedvectors.Vocab at 0x2401d520d08>,
#  'jaime_lannister': <gensim.models.keyedvectors.Vocab at 0x2401d520d88>,
#  'queen’s': <gensim.models.keyedvectors.Vocab at 0x2401d520dc8>,
#  'would_you_please_shut': <gensim.models.keyedvectors.Vocab at 0x2401d520e08>,
#  'take': <gensim.models.keyedvectors.Vocab at 0x2401d520e88>,
#  'crypt': <gensim.models.keyedvectors.Vocab at 0x2401d520f08>,
#  'riding': <gensim.models.keyedvectors.Vocab at 0x2401d520f88>,
#  'month': <gensim.models.keyedvectors.Vocab at 0x2401d526048>,
#  'surely': <gensim.models.keyedvectors.Vocab at 0x2401d5260c8>,
#  'wait': <gensim.models.keyedvectors.Vocab at 0x2401d526148>,
#  'go_find': <gensim.models.keyedvectors.Vocab at 0x2401d5261c8>,
#  'fine': <gensim.models.keyedvectors.Vocab at 0x2401d526248>,
#  'then': <gensim.models.keyedvectors.Vocab at 0x2401d5262c8>,
#  'burned': <gensim.models.keyedvectors.Vocab at 0x2401d526348>,
#  'through': <gensim.models.keyedvectors.Vocab at 0x2401d5263c8>,
#  'whatever': <gensim.models.keyedvectors.Vocab at 0x2401d526448>,
#  'loved': <gensim.models.keyedvectors.Vocab at 0x2401d5264c8>,
#  'teach': <gensim.models.keyedvectors.Vocab at 0x2401d526548>,
#  'remember': <gensim.models.keyedvectors.Vocab at 0x2401d5265c8>,
#  '16': <gensim.models.keyedvectors.Vocab at 0x2401d526648>,
#  'wanted': <gensim.models.keyedvectors.Vocab at 0x2401d5266c8>,
#  'skulls': <gensim.models.keyedvectors.Vocab at 0x2401d526748>,
#  'fuck': <gensim.models.keyedvectors.Vocab at 0x2401d5267c8>,
#  'showed': <gensim.models.keyedvectors.Vocab at 0x2401d526848>,
#  'aye': <gensim.models.keyedvectors.Vocab at 0x2401d5268c8>,
#  'fault': <gensim.models.keyedvectors.Vocab at 0x2401d526948>,
#  'kings_landing': <gensim.models.keyedvectors.Vocab at 0x2401d5269c8>,
#  'you’re': <gensim.models.keyedvectors.Vocab at 0x2401d526a08>,
#  'damn': <gensim.models.keyedvectors.Vocab at 0x2401d526a88>,
#  'use': <gensim.models.keyedvectors.Vocab at 0x2401d526b08>,
#  'anybody': <gensim.models.keyedvectors.Vocab at 0x2401d526b88>,
#  'lord_eddard_stark': <gensim.models.keyedvectors.Vocab at 0x2401d526bc8>,
#  'would': <gensim.models.keyedvectors.Vocab at 0x2401d526c48>,
#  'name': <gensim.models.keyedvectors.Vocab at 0x2401d526cc8>,
#  'worthy': <gensim.models.keyedvectors.Vocab at 0x2401d526d48>,
#  'honor': <gensim.models.keyedvectors.Vocab at 0x2401d526dc8>,
#  'trying': <gensim.models.keyedvectors.Vocab at 0x2401d526e48>,
#  'i’m_trying': <gensim.models.keyedvectors.Vocab at 0x2401d526e88>,
#  'kingdom': <gensim.models.keyedvectors.Vocab at 0x2401d526f08>,
#  'while': <gensim.models.keyedvectors.Vocab at 0x2401d526f88>,
#  'whore': <gensim.models.keyedvectors.Vocab at 0x2401d52a048>,
#  'stand': <gensim.models.keyedvectors.Vocab at 0x2401d52a0c8>,
#  'helped': <gensim.models.keyedvectors.Vocab at 0x2401d52a148>,
#  'win': <gensim.models.keyedvectors.Vocab at 0x2401d52a1c8>,
#  'iron_throne': <gensim.models.keyedvectors.Vocab at 0x2401d52a248>,
#  'help': <gensim.models.keyedvectors.Vocab at 0x2401d52a2c8>,
#  'meant': <gensim.models.keyedvectors.Vocab at 0x2401d52a348>,
#  'rule': <gensim.models.keyedvectors.Vocab at 0x2401d52a3c8>,
#  'together': <gensim.models.keyedvectors.Vocab at 0x2401d52a448>,
#  'lived': <gensim.models.keyedvectors.Vocab at 0x2401d52a4c8>,
#  'bound': <gensim.models.keyedvectors.Vocab at 0x2401d52a548>,
#  'by': <gensim.models.keyedvectors.Vocab at 0x2401d52a5c8>,
#  'blood': <gensim.models.keyedvectors.Vocab at 0x2401d52a648>,
#  'son': <gensim.models.keyedvectors.Vocab at 0x2401d52a6c8>,
#  'daughter': <gensim.models.keyedvectors.Vocab at 0x2401d52a748>,
#  'we’ll': <gensim.models.keyedvectors.Vocab at 0x2401d52a788>,
#  'join': <gensim.models.keyedvectors.Vocab at 0x2401d52a808>,
#  'houses': <gensim.models.keyedvectors.Vocab at 0x2401d52a888>,
#  'northern': <gensim.models.keyedvectors.Vocab at 0x2401d52a908>,
#  'king’s': <gensim.models.keyedvectors.Vocab at 0x2401d52a948>,
#  'clever': <gensim.models.keyedvectors.Vocab at 0x2401d52a9c8>,
#  'call': <gensim.models.keyedvectors.Vocab at 0x2401d52aa48>,
#  'imp': <gensim.models.keyedvectors.Vocab at 0x2401d52aac8>,
#  'oh': <gensim.models.keyedvectors.Vocab at 0x2401d52ab48>,
#  'earned': <gensim.models.keyedvectors.Vocab at 0x2401d52abc8>,
#  'manner': <gensim.models.keyedvectors.Vocab at 0x2401d52ac48>,
#  'expecting': <gensim.models.keyedvectors.Vocab at 0x2401d52acc8>,
#  'lord_tyrion': <gensim.models.keyedvectors.Vocab at 0x2401d52ad48>,
#  'explain': <gensim.models.keyedvectors.Vocab at 0x2401d52adc8>,
#  'meaning': <gensim.models.keyedvectors.Vocab at 0x2401d52ae48>,
#  'closed': <gensim.models.keyedvectors.Vocab at 0x2401d52aec8>,
#  'door': <gensim.models.keyedvectors.Vocab at 0x2401d52af48>,
#  'doubt': <gensim.models.keyedvectors.Vocab at 0x2401d52afc8>,
#  'attention': <gensim.models.keyedvectors.Vocab at 0x2401d52e088>,
#  'starks': <gensim.models.keyedvectors.Vocab at 0x2401d52e108>,
#  'sundown': <gensim.models.keyedvectors.Vocab at 0x2401d52e188>,
#  'don’t': <gensim.models.keyedvectors.Vocab at 0x2401d52e1c8>,
#  'leave_me_alone': <gensim.models.keyedvectors.Vocab at 0x2401d52e248>,
#  'i’ve': <gensim.models.keyedvectors.Vocab at 0x2401d52e288>,
#  'begun': <gensim.models.keyedvectors.Vocab at 0x2401d52e308>,
#  'feast': <gensim.models.keyedvectors.Vocab at 0x2401d52e388>,
#  'first': <gensim.models.keyedvectors.Vocab at 0x2401d52e408>,
#  'many': <gensim.models.keyedvectors.Vocab at 0x2401d52e488>,
#  'say': <gensim.models.keyedvectors.Vocab at 0x2401d52e508>,
#  'since': <gensim.models.keyedvectors.Vocab at 0x2401d52e588>,
#  'short': <gensim.models.keyedvectors.Vocab at 0x2401d52e608>,
#  'changes': <gensim.models.keyedvectors.Vocab at 0x2401d52e688>,
#  'her': <gensim.models.keyedvectors.Vocab at 0x2401d52e708>,
#  'place_like': <gensim.models.keyedvectors.Vocab at 0x2401d52e788>,
#  'hill': <gensim.models.keyedvectors.Vocab at 0x2401d52e808>,
#  'somewhere': <gensim.models.keyedvectors.Vocab at 0x2401d52e888>,
#  'sun': <gensim.models.keyedvectors.Vocab at 0x2401d52e908>,
#  'clouds': <gensim.models.keyedvectors.Vocab at 0x2401d52e988>,
#  'above': <gensim.models.keyedvectors.Vocab at 0x2401d52ea08>,
#  'dreams': <gensim.models.keyedvectors.Vocab at 0x2401d52ea88>,
#  'every_night': <gensim.models.keyedvectors.Vocab at 0x2401d52eb08>,
#  'done': <gensim.models.keyedvectors.Vocab at 0x2401d52eb88>,
#  'targaryens': <gensim.models.keyedvectors.Vocab at 0x2401d52ec08>,
#  'daenerys': <gensim.models.keyedvectors.Vocab at 0x2401d52ec88>,
#  'bride': <gensim.models.keyedvectors.Vocab at 0x2401d52ed08>,
#  '–': <gensim.models.keyedvectors.Vocab at 0x2401d52ed48>,
#  'gift': <gensim.models.keyedvectors.Vocab at 0x2401d52edc8>,
#  'touch': <gensim.models.keyedvectors.Vocab at 0x2401d52ee48>,
#  'isn’t': <gensim.models.keyedvectors.Vocab at 0x2401d52ee88>,
#  'guests': <gensim.models.keyedvectors.Vocab at 0x2401d52ef08>,
#  'over': <gensim.models.keyedvectors.Vocab at 0x2401d52ef88>,
#  'year': <gensim.models.keyedvectors.Vocab at 0x2401d534048>,
#  'asked': <gensim.models.keyedvectors.Vocab at 0x2401d5340c8>,
#  'fool': <gensim.models.keyedvectors.Vocab at 0x2401d534148>,
#  'knows': <gensim.models.keyedvectors.Vocab at 0x2401d5341c8>,
#  'forget': <gensim.models.keyedvectors.Vocab at 0x2401d534248>,
#  'friends': <gensim.models.keyedvectors.Vocab at 0x2401d5342c8>,
#  'throne': <gensim.models.keyedvectors.Vocab at 0x2401d534348>,
#  'still': <gensim.models.keyedvectors.Vocab at 0x2401d5343c8>,
#  'let_me_see': <gensim.models.keyedvectors.Vocab at 0x2401d534448>,
#  'woman’s': <gensim.models.keyedvectors.Vocab at 0x2401d534488>,
#  'body': <gensim.models.keyedvectors.Vocab at 0x2401d534508>,
#  'perfect': <gensim.models.keyedvectors.Vocab at 0x2401d534588>,
#  'today': <gensim.models.keyedvectors.Vocab at 0x2401d534608>,
#  'don’t_want': <gensim.models.keyedvectors.Vocab at 0x2401d534648>,
#  'wake': <gensim.models.keyedvectors.Vocab at 0x2401d5346c8>,
#  'dragon': <gensim.models.keyedvectors.Vocab at 0x2401d534748>,
#  'write': <gensim.models.keyedvectors.Vocab at 0x2401d5347c8>,
#  'history': <gensim.models.keyedvectors.Vocab at 0x2401d534848>,
#  'reign': <gensim.models.keyedvectors.Vocab at 0x2401d5348c8>,
#  'sweet_sister': <gensim.models.keyedvectors.Vocab at 0x2401d534948>,
#  'began': <gensim.models.keyedvectors.Vocab at 0x2401d5349c8>,
#  'dothraki': <gensim.models.keyedvectors.Vocab at 0x2401d534a48>,
#  'known': <gensim.models.keyedvectors.Vocab at 0x2401d534ac8>,
#  'viserys': <gensim.models.keyedvectors.Vocab at 0x2401d534b48>,
#  'house_targaryen': <gensim.models.keyedvectors.Vocab at 0x2401d534bc8>,
#  'third': <gensim.models.keyedvectors.Vocab at 0x2401d534c48>,
#  'long': <gensim.models.keyedvectors.Vocab at 0x2401d534cc8>,
#  'defeated': <gensim.models.keyedvectors.Vocab at 0x2401d534d48>,
#  'combat': <gensim.models.keyedvectors.Vocab at 0x2401d534dc8>,
#  'cut': <gensim.models.keyedvectors.Vocab at 0x2401d534e48>,
#  'shame': <gensim.models.keyedvectors.Vocab at 0x2401d534ec8>,
#  'khal_drogo': <gensim.models.keyedvectors.Vocab at 0x2401d534f48>,
#  'has': <gensim.models.keyedvectors.Vocab at 0x2401d534fc8>,
#  'savage': <gensim.models.keyedvectors.Vocab at 0x2401d538088>,
#  'course': <gensim.models.keyedvectors.Vocab at 0x2401d538108>,
#  'finest': <gensim.models.keyedvectors.Vocab at 0x2401d538188>,
#  'killers': <gensim.models.keyedvectors.Vocab at 0x2401d538208>,
#  'alive': <gensim.models.keyedvectors.Vocab at 0x2401d538288>,
#  'come_forward': <gensim.models.keyedvectors.Vocab at 0x2401d538308>,
#  'dear': <gensim.models.keyedvectors.Vocab at 0x2401d538388>,
#  'going': <gensim.models.keyedvectors.Vocab at 0x2401d538408>,
#  'ceremony': <gensim.models.keyedvectors.Vocab at 0x2401d538488>,
#  'trust': <gensim.models.keyedvectors.Vocab at 0x2401d538508>,
#  'didn’t': <gensim.models.keyedvectors.Vocab at 0x2401d538548>,
#  'we’d': <gensim.models.keyedvectors.Vocab at 0x2401d538588>,
#  'soon': <gensim.models.keyedvectors.Vocab at 0x2401d538608>,
#  'back': <gensim.models.keyedvectors.Vocab at 0x2401d538688>,
#  'married': <gensim.models.keyedvectors.Vocab at 0x2401d538708>,
#  'stay': <gensim.models.keyedvectors.Vocab at 0x2401d538788>,
#  'wouldn’t': <gensim.models.keyedvectors.Vocab at 0x2401d5387c8>,
#  'drogo': <gensim.models.keyedvectors.Vocab at 0x2401d538848>,
#  'kings': <gensim.models.keyedvectors.Vocab at 0x2401d5388c8>,
#  'lack': <gensim.models.keyedvectors.Vocab at 0x2401d538948>,
#  'common': <gensim.models.keyedvectors.Vocab at 0x2401d5389c8>,
#  'men': <gensim.models.keyedvectors.Vocab at 0x2401d538a48>,
#  'apologies': <gensim.models.keyedvectors.Vocab at 0x2401d538ac8>,
#  'offense': <gensim.models.keyedvectors.Vocab at 0x2401d538b48>,
#  'play': <gensim.models.keyedvectors.Vocab at 0x2401d538bc8>,
#  'give': <gensim.models.keyedvectors.Vocab at 0x2401d538c48>,
#  'gives': <gensim.models.keyedvectors.Vocab at 0x2401d538cc8>,
#  'army': <gensim.models.keyedvectors.Vocab at 0x2401d538d48>,
#  'want_us': <gensim.models.keyedvectors.Vocab at 0x2401d538dc8>,
#  'go_home': <gensim.models.keyedvectors.Vocab at 0x2401d538e48>,
#  'don’t_know': <gensim.models.keyedvectors.Vocab at 0x2401d538e88>,
#  'would_let': <gensim.models.keyedvectors.Vocab at 0x2401d538f08>,
#  'whole': <gensim.models.keyedvectors.Vocab at 0x2401d538f88>,
#  'prince': <gensim.models.keyedvectors.Vocab at 0x2401d53e048>,
#  'ever_lived': <gensim.models.keyedvectors.Vocab at 0x2401d53e0c8>,
#  'handsome': <gensim.models.keyedvectors.Vocab at 0x2401d53e148>,
#  'or': <gensim.models.keyedvectors.Vocab at 0x2401d53e1c8>,
#  'hush': <gensim.models.keyedvectors.Vocab at 0x2401d53e248>,
#  'even': <gensim.models.keyedvectors.Vocab at 0x2401d53e2c8>,
#  'yes': <gensim.models.keyedvectors.Vocab at 0x2401d53e348>,
#  'he’d': <gensim.models.keyedvectors.Vocab at 0x2401d53e388>,
#  'second': <gensim.models.keyedvectors.Vocab at 0x2401d53e408>,
#  'most': <gensim.models.keyedvectors.Vocab at 0x2401d53e488>,
#  'powerful_man': <gensim.models.keyedvectors.Vocab at 0x2401d53e508>,
#  'kingdoms': <gensim.models.keyedvectors.Vocab at 0x2401d53e588>,
#  'home': <gensim.models.keyedvectors.Vocab at 0x2401d53e608>,
#  'left': <gensim.models.keyedvectors.Vocab at 0x2401d53e688>,
#  'i’d': <gensim.models.keyedvectors.Vocab at 0x2401d53e6c8>,
#  'someday': <gensim.models.keyedvectors.Vocab at 0x2401d53e748>,
#  'please_please': <gensim.models.keyedvectors.Vocab at 0x2401d53e7c8>,
#  'day': <gensim.models.keyedvectors.Vocab at 0x2401d53e848>,
#  'didn’t_want': <gensim.models.keyedvectors.Vocab at 0x2401d53e888>,
#  'aren’t': <gensim.models.keyedvectors.Vocab at 0x2401d53e8c8>,
#  'lady_stark': <gensim.models.keyedvectors.Vocab at 0x2401d53e948>,
#  'thought': <gensim.models.keyedvectors.Vocab at 0x2401d53e9c8>,
#  'might': <gensim.models.keyedvectors.Vocab at 0x2401d53ea48>,
#  'insult': <gensim.models.keyedvectors.Vocab at 0x2401d53eac8>,
#  'seat': <gensim.models.keyedvectors.Vocab at 0x2401d53eb48>,
#  'bastard': <gensim.models.keyedvectors.Vocab at 0x2401d53ebc8>,
#  'welcome': <gensim.models.keyedvectors.Vocab at 0x2401d53ec48>,
#  'wall': <gensim.models.keyedvectors.Vocab at 0x2401d53ecc8>,
#  'refused': <gensim.models.keyedvectors.Vocab at 0x2401d53ed48>,
#  'let': <gensim.models.keyedvectors.Vocab at 0x2401d53edc8>,
#  'going_anywhere': <gensim.models.keyedvectors.Vocab at 0x2401d53ee48>,
#  'i’m_ready': <gensim.models.keyedvectors.Vocab at 0x2401d53ee88>,
#  'swear': <gensim.models.keyedvectors.Vocab at 0x2401d53ef08>,
#  'don’t_understand': <gensim.models.keyedvectors.Vocab at 0x2401d53ef48>,
#  'you’d': <gensim.models.keyedvectors.Vocab at 0x2401d53ef88>,
#  'giving': <gensim.models.keyedvectors.Vocab at 0x2401d543048>,
#  'families': <gensim.models.keyedvectors.Vocab at 0x2401d5430c8>,
#  'none_of_us': <gensim.models.keyedvectors.Vocab at 0x2401d543148>,
#  'sons': <gensim.models.keyedvectors.Vocab at 0x2401d5431c8>,
#  'don’t_care': <gensim.models.keyedvectors.Vocab at 0x2401d543208>,
#  'knew': <gensim.models.keyedvectors.Vocab at 0x2401d543288>,
#  'inside': <gensim.models.keyedvectors.Vocab at 0x2401d543308>,
#  'rescue': <gensim.models.keyedvectors.Vocab at 0x2401d543388>,
#  'later': <gensim.models.keyedvectors.Vocab at 0x2401d543408>,
#  'what’re': <gensim.models.keyedvectors.Vocab at 0x2401d543448>,
#  'preparing': <gensim.models.keyedvectors.Vocab at 0x2401d5434c8>,
#  'wanted_to_see': <gensim.models.keyedvectors.Vocab at 0x2401d543548>,
#  'tyrion_lannister': <gensim.models.keyedvectors.Vocab at 0x2401d543588>,
#  'greatest': <gensim.models.keyedvectors.Vocab at 0x2401d543608>,
#  'ned_stark’s': <gensim.models.keyedvectors.Vocab at 0x2401d543648>,
#  'offend': <gensim.models.keyedvectors.Vocab at 0x2401d5436c8>,
#  'though': <gensim.models.keyedvectors.Vocab at 0x2401d543748>,
#  'making': <gensim.models.keyedvectors.Vocab at 0x2401d5437c8>,
#  'some': <gensim.models.keyedvectors.Vocab at 0x2401d543848>,
#  'advice': <gensim.models.keyedvectors.Vocab at 0x2401d5438c8>,
#  'never_forget': <gensim.models.keyedvectors.Vocab at 0x2401d543948>,
#  'wear': <gensim.models.keyedvectors.Vocab at 0x2401d5439c8>,
#  'armor': <gensim.models.keyedvectors.Vocab at 0x2401d543a48>,
#  'used': <gensim.models.keyedvectors.Vocab at 0x2401d543ac8>,
#  'hurt': <gensim.models.keyedvectors.Vocab at 0x2401d543b48>,
#  'being': <gensim.models.keyedvectors.Vocab at 0x2401d543bc8>,
#  'bastards': <gensim.models.keyedvectors.Vocab at 0x2401d543c48>,
#  'eyes': <gensim.models.keyedvectors.Vocab at 0x2401d543cc8>,
#  'bear': <gensim.models.keyedvectors.Vocab at 0x2401d543d48>,
#  'trap': <gensim.models.keyedvectors.Vocab at 0x2401d543dc8>,
#  'beheaded': <gensim.models.keyedvectors.Vocab at 0x2401d543e48>,
#  'tough': <gensim.models.keyedvectors.Vocab at 0x2401d543ec8>,
#  'ranger': <gensim.models.keyedvectors.Vocab at 0x2401d543f48>,
#  'talking': <gensim.models.keyedvectors.Vocab at 0x2401d543fc8>,
#  'madness': <gensim.models.keyedvectors.Vocab at 0x2401d548088>,
#  'walkers': <gensim.models.keyedvectors.Vocab at 0x2401d548108>,
#  'slaughtered': <gensim.models.keyedvectors.Vocab at 0x2401d548188>,
#  'two': <gensim.models.keyedvectors.Vocab at 0x2401d548208>,
#  'missing': <gensim.models.keyedvectors.Vocab at 0x2401d548288>,
#  'wildling': <gensim.models.keyedvectors.Vocab at 0x2401d548308>,
#  'maybe': <gensim.models.keyedvectors.Vocab at 0x2401d548388>,
#  'talk': <gensim.models.keyedvectors.Vocab at 0x2401d548408>,
#  'next': <gensim.models.keyedvectors.Vocab at 0x2401d548488>,
#  'hand': <gensim.models.keyedvectors.Vocab at 0x2401d548508>,
#  'uncle_benjen': <gensim.models.keyedvectors.Vocab at 0x2401d548588>,
#  'robb': <gensim.models.keyedvectors.Vocab at 0x2401d548608>,
#  'catelyn': <gensim.models.keyedvectors.Vocab at 0x2401d548688>,
#  'first_time': <gensim.models.keyedvectors.Vocab at 0x2401d548708>,
#  'lovely': <gensim.models.keyedvectors.Vocab at 0x2401d548788>,
#  'country': <gensim.models.keyedvectors.Vocab at 0x2401d548808>,
#  'i’m_sure': <gensim.models.keyedvectors.Vocab at 0x2401d548848>,
#  'very': <gensim.models.keyedvectors.Vocab at 0x2401d5488c8>,
#  'scared': <gensim.models.keyedvectors.Vocab at 0x2401d548948>,
#  'beauty': <gensim.models.keyedvectors.Vocab at 0x2401d5489c8>,
#  'old': <gensim.models.keyedvectors.Vocab at 0x2401d548a48>,
#  'thirteen': <gensim.models.keyedvectors.Vocab at 0x2401d548ac8>,
#  'tall': <gensim.models.keyedvectors.Vocab at 0x2401d548b48>,
#  'growing': <gensim.models.keyedvectors.Vocab at 0x2401d548bc8>,
#  'dress': <gensim.models.keyedvectors.Vocab at 0x2401d548c48>,
#  'make': <gensim.models.keyedvectors.Vocab at 0x2401d548cc8>,
#  'share': <gensim.models.keyedvectors.Vocab at 0x2401d548d48>,
#  'same': <gensim.models.keyedvectors.Vocab at 0x2401d548dc8>,
#  'capital': <gensim.models.keyedvectors.Vocab at 0x2401d548e48>,
#  'shouldn’t': <gensim.models.keyedvectors.Vocab at 0x2401d548e88>,
#  'hidden': <gensim.models.keyedvectors.Vocab at 0x2401d548f08>,
#  'pardon': <gensim.models.keyedvectors.Vocab at 0x2401d548f88>,
#  'it’s_true': <gensim.models.keyedvectors.Vocab at 0x2401d548fc8>,
#  'honored': <gensim.models.keyedvectors.Vocab at 0x2401d54d088>,
#  'offer': <gensim.models.keyedvectors.Vocab at 0x2401d54d108>,
#  'tournament': <gensim.models.keyedvectors.Vocab at 0x2401d54d188>,
#  'celebrate': <gensim.models.keyedvectors.Vocab at 0x2401d54d208>,
#  'new': <gensim.models.keyedvectors.Vocab at 0x2401d54d288>,
#  'title': <gensim.models.keyedvectors.Vocab at 0x2401d54d308>,
#  'accept': <gensim.models.keyedvectors.Vocab at 0x2401d54d388>,
#  'field': <gensim.models.keyedvectors.Vocab at 0x2401d54d408>,
#  'because': <gensim.models.keyedvectors.Vocab at 0x2401d54d488>,
#  'fight': <gensim.models.keyedvectors.Vocab at 0x2401d54d508>,
#  'real': <gensim.models.keyedvectors.Vocab at 0x2401d54d588>,
#  'time': <gensim.models.keyedvectors.Vocab at 0x2401d54d608>,
#  'bed': <gensim.models.keyedvectors.Vocab at 0x2401d54d688>,
#  'belong': <gensim.models.keyedvectors.Vocab at 0x2401d54d708>,
#  'south': <gensim.models.keyedvectors.Vocab at 0x2401d54d788>,
#  'takes': <gensim.models.keyedvectors.Vocab at 0x2401d54d808>,
#  'wants': <gensim.models.keyedvectors.Vocab at 0x2401d54d888>,
#  'i’ll': <gensim.models.keyedvectors.Vocab at 0x2401d54d8c8>,
#  'listen': <gensim.models.keyedvectors.Vocab at 0x2401d54d948>,
#  'taking': <gensim.models.keyedvectors.Vocab at 0x2401d54d9c8>,
#  'anywhere': <gensim.models.keyedvectors.Vocab at 0x2401d54da48>,
#  'belongs': <gensim.models.keyedvectors.Vocab at 0x2401d54dac8>,
#  'stops': <gensim.models.keyedvectors.Vocab at 0x2401d54db48>,
#  'eating': <gensim.models.keyedvectors.Vocab at 0x2401d54dbc8>,
#  'it’s_time': <gensim.models.keyedvectors.Vocab at 0x2401d54dc08>,
#  'maester_luwin': <gensim.models.keyedvectors.Vocab at 0x2401d54dc88>,
#  'send': <gensim.models.keyedvectors.Vocab at 0x2401d54dd08>,
#  'sent': <gensim.models.keyedvectors.Vocab at 0x2401d54dd88>,
#  'eyrie': <gensim.models.keyedvectors.Vocab at 0x2401d54de08>,
#  'what’s': <gensim.models.keyedvectors.Vocab at 0x2401d54de48>,
#  'wedding': <gensim.models.keyedvectors.Vocab at 0x2401d54dec8>,
#  'she’s': <gensim.models.keyedvectors.Vocab at 0x2401d54df08>,
#  'says': <gensim.models.keyedvectors.Vocab at 0x2401d54df88>,
#  'murdered': <gensim.models.keyedvectors.Vocab at 0x2401d552048>,
#  'danger': <gensim.models.keyedvectors.Vocab at 0x2401d5520c8>,
#  'fresh': <gensim.models.keyedvectors.Vocab at 0x2401d552148>,
#  'saying': <gensim.models.keyedvectors.Vocab at 0x2401d5521c8>,
#  'found': <gensim.models.keyedvectors.Vocab at 0x2401d552248>,
#  'letter': <gensim.models.keyedvectors.Vocab at 0x2401d5522c8>,
#  'son’s': <gensim.models.keyedvectors.Vocab at 0x2401d552308>,
#  'wasn’t': <gensim.models.keyedvectors.Vocab at 0x2401d552348>,
#  'certain': <gensim.models.keyedvectors.Vocab at 0x2401d5523c8>,
#  'against': <gensim.models.keyedvectors.Vocab at 0x2401d552448>,
#  'who': <gensim.models.keyedvectors.Vocab at 0x2401d5524c8>,
#  'want': <gensim.models.keyedvectors.Vocab at 0x2401d552548>,
#  'job': <gensim.models.keyedvectors.Vocab at 0x2401d5525c8>,
#  'trusts': <gensim.models.keyedvectors.Vocab at 0x2401d552648>,
#  'swore': <gensim.models.keyedvectors.Vocab at 0x2401d5526c8>,
#  'wars': <gensim.models.keyedvectors.Vocab at 0x2401d552748>,
#  'owes': <gensim.models.keyedvectors.Vocab at 0x2401d5527c8>,
#  'once': <gensim.models.keyedvectors.Vocab at 0x2401d552848>,
#  'demand': <gensim.models.keyedvectors.Vocab at 0x2401d5528c8>,
#  'different': <gensim.models.keyedvectors.Vocab at 0x2401d552948>,
#  'meet': <gensim.models.keyedvectors.Vocab at 0x2401d5529c8>,
#  'khal': <gensim.models.keyedvectors.Vocab at 0x2401d552a48>,
#  'begin': <gensim.models.keyedvectors.Vocab at 0x2401d552ac8>,
#  'planning': <gensim.models.keyedvectors.Vocab at 0x2401d552b48>,
#  'promised': <gensim.models.keyedvectors.Vocab at 0x2401d552bc8>,
#  'crown': <gensim.models.keyedvectors.Vocab at 0x2401d552c48>,
#  'shall': <gensim.models.keyedvectors.Vocab at 0x2401d552cc8>,
#  'favor': <gensim.models.keyedvectors.Vocab at 0x2401d552d48>,
#  'war': <gensim.models.keyedvectors.Vocab at 0x2401d552dc8>,
#  'piss': <gensim.models.keyedvectors.Vocab at 0x2401d552e48>,
#  'waited': <gensim.models.keyedvectors.Vocab at 0x2401d552ec8>,
#  '17_years': <gensim.models.keyedvectors.Vocab at 0x2401d552f48>,
#  'ser_jorah': <gensim.models.keyedvectors.Vocab at 0x2401d552fc8>,
#  'island': <gensim.models.keyedvectors.Vocab at 0x2401d556088>,
#  'served': <gensim.models.keyedvectors.Vocab at 0x2401d556108>,
#  'many_years': <gensim.models.keyedvectors.Vocab at 0x2401d556188>,
#  'hope': <gensim.models.keyedvectors.Vocab at 0x2401d556208>,
#  'serve': <gensim.models.keyedvectors.Vocab at 0x2401d556288>,
#  'rightful_king': <gensim.models.keyedvectors.Vocab at 0x2401d556308>,
#  'eggs': <gensim.models.keyedvectors.Vocab at 0x2401d556388>,
#  'beautiful': <gensim.models.keyedvectors.Vocab at 0x2401d556408>,
#  'happy': <gensim.models.keyedvectors.Vocab at 0x2401d556488>,
#  'word': <gensim.models.keyedvectors.Vocab at 0x2401d556508>,
#  'rough': <gensim.models.keyedvectors.Vocab at 0x2401d556588>,
#  'end': <gensim.models.keyedvectors.Vocab at 0x2401d556608>,
#  'pick': <gensim.models.keyedvectors.Vocab at 0x2401d556688>,
#  'hunter': <gensim.models.keyedvectors.Vocab at 0x2401d556708>,
#  'spear': <gensim.models.keyedvectors.Vocab at 0x2401d556788>,
#  'hunting': <gensim.models.keyedvectors.Vocab at 0x2401d556808>,
#  'pay': <gensim.models.keyedvectors.Vocab at 0x2401d556888>,
#  'putting': <gensim.models.keyedvectors.Vocab at 0x2401d556908>,
#  'last_one': <gensim.models.keyedvectors.Vocab at 0x2401d556988>,
#  'serve_you_well': <gensim.models.keyedvectors.Vocab at 0x2401d556a08>,
#  'fucking': <gensim.models.keyedvectors.Vocab at 0x2401d556a88>,
#  'boys': <gensim.models.keyedvectors.Vocab at 0x2401d556b08>,
#  'let’s_go': <gensim.models.keyedvectors.Vocab at 0x2401d556b48>,
#  'boar': <gensim.models.keyedvectors.Vocab at 0x2401d556bc8>,
#  'stop_stop': <gensim.models.keyedvectors.Vocab at 0x2401d556c48>,
#  'completely': <gensim.models.keyedvectors.Vocab at 0x2401d556cc8>,
#  'mad': <gensim.models.keyedvectors.Vocab at 0x2401d556d48>,
#  'saw_us': <gensim.models.keyedvectors.Vocab at 0x2401d556dc8>,
#  'it’s_all_right': <gensim.models.keyedvectors.Vocab at 0x2401d556e08>,
#  'heard': <gensim.models.keyedvectors.Vocab at 0x2401d556e88>,
#  'quite': <gensim.models.keyedvectors.Vocab at 0x2401d556f08>,
#  'little': <gensim.models.keyedvectors.Vocab at 0x2401d556f88>,
#  'child': <gensim.models.keyedvectors.Vocab at 0x2401d55b048>,
#  'eat': <gensim.models.keyedvectors.Vocab at 0x2401d55b0c8>,
#  'isnt': <gensim.models.keyedvectors.Vocab at 0x2401d55b148>,
#  'anything_else': <gensim.models.keyedvectors.Vocab at 0x2401d55b1c8>,
#  'grass': <gensim.models.keyedvectors.Vocab at 0x2401d55b248>,
#  'fields': <gensim.models.keyedvectors.Vocab at 0x2401d55b2c8>,
#  'ghost': <gensim.models.keyedvectors.Vocab at 0x2401d55b348>,
#  'pale': <gensim.models.keyedvectors.Vocab at 0x2401d55b3c8>,
#  'milk': <gensim.models.keyedvectors.Vocab at 0x2401d55b448>,
#  'murders': <gensim.models.keyedvectors.Vocab at 0x2401d55b4c8>,
#  'believe': <gensim.models.keyedvectors.Vocab at 0x2401d55b548>,
#  'one_day': <gensim.models.keyedvectors.Vocab at 0x2401d55b5c8>,
#  'cover': <gensim.models.keyedvectors.Vocab at 0x2401d55b648>,
#  'everything_thats': <gensim.models.keyedvectors.Vocab at 0x2401d55b688>,
#  'world': <gensim.models.keyedvectors.Vocab at 0x2401d55b708>,
#  'easier': <gensim.models.keyedvectors.Vocab at 0x2401d55b788>,
#  'khaleesi': <gensim.models.keyedvectors.Vocab at 0x2401d55b808>,
#  'hands': <gensim.models.keyedvectors.Vocab at 0x2401d55b888>,
#  'far': <gensim.models.keyedvectors.Vocab at 0x2401d55b908>,
#  'pentos': <gensim.models.keyedvectors.Vocab at 0x2401d55b988>,
#  'hospitality': <gensim.models.keyedvectors.Vocab at 0x2401d55ba08>,
#  'youd': <gensim.models.keyedvectors.Vocab at 0x2401d55ba88>,
#  'comfortable': <gensim.models.keyedvectors.Vocab at 0x2401d55bb08>,
#  'interest': <gensim.models.keyedvectors.Vocab at 0x2401d55bb88>,
#  'comfort': <gensim.models.keyedvectors.Vocab at 0x2401d55bc08>,
#  'mormont': <gensim.models.keyedvectors.Vocab at 0x2401d55bc88>,
#  'suppose': <gensim.models.keyedvectors.Vocab at 0x2401d55bd08>,
#  'beheading': <gensim.models.keyedvectors.Vocab at 0x2401d55bd88>,
#  'ned_stark': <gensim.models.keyedvectors.Vocab at 0x2401d55be08>,
#  'buying': <gensim.models.keyedvectors.Vocab at 0x2401d55be88>,
#  'slaver': <gensim.models.keyedvectors.Vocab at 0x2401d55bf08>,
#  'selling': <gensim.models.keyedvectors.Vocab at 0x2401d55bf88>,
#  'caught': <gensim.models.keyedvectors.Vocab at 0x2401d55f048>,
#  'land': <gensim.models.keyedvectors.Vocab at 0x2401d55f0c8>,
#  'under': <gensim.models.keyedvectors.Vocab at 0x2401d55f148>,
#  'wont': <gensim.models.keyedvectors.Vocab at 0x2401d55f1c8>,
#  'punished': <gensim.models.keyedvectors.Vocab at 0x2401d55f248>,
#  'nonsense': <gensim.models.keyedvectors.Vocab at 0x2401d55f2c8>,
#  'youre': <gensim.models.keyedvectors.Vocab at 0x2401d55f348>,
#  'uncle': <gensim.models.keyedvectors.Vocab at 0x2401d55f3c8>,
#  'mothers': <gensim.models.keyedvectors.Vocab at 0x2401d55f448>,
#  'looking': <gensim.models.keyedvectors.Vocab at 0x2401d55f4c8>,
#  'ride': <gensim.models.keyedvectors.Vocab at 0x2401d55f548>,
#  'none': <gensim.models.keyedvectors.Vocab at 0x2401d55f5c8>,
#  'expected': <gensim.models.keyedvectors.Vocab at 0x2401d55f648>,
#  'absence': <gensim.models.keyedvectors.Vocab at 0x2401d55f6c8>,
#  'already': <gensim.models.keyedvectors.Vocab at 0x2401d55f748>,
#  'means_nothing': <gensim.models.keyedvectors.Vocab at 0x2401d55f7c8>,
#  'cant_stand': <gensim.models.keyedvectors.Vocab at 0x2401d55f848>,
#  'women': <gensim.models.keyedvectors.Vocab at 0x2401d55f8c8>,
#  'fall': <gensim.models.keyedvectors.Vocab at 0x2401d55f948>,
#  'knees': <gensim.models.keyedvectors.Vocab at 0x2401d55f9c8>,
#  'front': <gensim.models.keyedvectors.Vocab at 0x2401d55fa48>,
#  'service': <gensim.models.keyedvectors.Vocab at 0x2401d55fac8>,
#  'cant': <gensim.models.keyedvectors.Vocab at 0x2401d55fb48>,
#  'little_lord': <gensim.models.keyedvectors.Vocab at 0x2401d55fbc8>,
#  'dog': <gensim.models.keyedvectors.Vocab at 0x2401d55fc48>,
#  'remind': <gensim.models.keyedvectors.Vocab at 0x2401d55fcc8>,
#  'breakfast': <gensim.models.keyedvectors.Vocab at 0x2401d55fd48>,
# ...
#  'burnt': <gensim.models.keyedvectors.Vocab at 0x2401d55ffc8>,
#  'black': <gensim.models.keyedvectors.Vocab at 0x2401d565088>,
#  'little_brother': <gensim.models.keyedvectors.Vocab at 0x2401d565108>,
#  'beloved': <gensim.models.keyedvectors.Vocab at 0x2401d565188>,
#  'mean': <gensim.models.keyedvectors.Vocab at 0x2401d565208>,
#  'maester': <gensim.models.keyedvectors.Vocab at 0x2401d565288>,
#  'live': <gensim.models.keyedvectors.Vocab at 0x2401d565308>,
#  'its': <gensim.models.keyedvectors.Vocab at 0x2401d565388>,
#  'mercy': <gensim.models.keyedvectors.Vocab at 0x2401d565408>,
#  'letting': <gensim.models.keyedvectors.Vocab at 0x2401d565488>,
#  'pain': <gensim.models.keyedvectors.Vocab at 0x2401d565508>,
#  'rest_of_us': <gensim.models.keyedvectors.Vocab at 0x2401d565588>,
#  'pray': <gensim.models.keyedvectors.Vocab at 0x2401d565608>,
#  'entirely': <gensim.models.keyedvectors.Vocab at 0x2401d565688>,
#  'lost': <gensim.models.keyedvectors.Vocab at 0x2401d565708>,
#  'ridiculous': <gensim.models.keyedvectors.Vocab at 0x2401d565788>,
#  'men_of_the_nights_watch': <gensim.models.keyedvectors.Vocab at 0x2401d5657c8>,
#  'thinking': <gensim.models.keyedvectors.Vocab at 0x2401d565848>,
#  'children': <gensim.models.keyedvectors.Vocab at 0x2401d5658c8>,
#  'dont_need': <gensim.models.keyedvectors.Vocab at 0x2401d565948>,
#  'filth': <gensim.models.keyedvectors.Vocab at 0x2401d5659c8>,
#  'lives': <gensim.models.keyedvectors.Vocab at 0x2401d565a48>,
#  'cripple': <gensim.models.keyedvectors.Vocab at 0x2401d565ac8>,
#  'times': <gensim.models.keyedvectors.Vocab at 0x2401d565b48>,
#  'whose': <gensim.models.keyedvectors.Vocab at 0x2401d565bc8>,
#  'wound': <gensim.models.keyedvectors.Vocab at 0x2401d565c48>,
#  'dressed': <gensim.models.keyedvectors.Vocab at 0x2401d565cc8>,
#  'im': <gensim.models.keyedvectors.Vocab at 0x2401d565d48>,
#  'guest': <gensim.models.keyedvectors.Vocab at 0x2401d565dc8>,
#  'fighter': <gensim.models.keyedvectors.Vocab at 0x2401d565e48>,
#  'tried': <gensim.models.keyedvectors.Vocab at 0x2401d565ec8>,
#  'beat': <gensim.models.keyedvectors.Vocab at 0x2401d565f48>,
#  'forgive': <gensim.models.keyedvectors.Vocab at 0x2401d565fc8>,
#  'last_thing': <gensim.models.keyedvectors.Vocab at 0x2401d568088>,
#  'never_knew': <gensim.models.keyedvectors.Vocab at 0x2401d568108>,
#  'years_ago': <gensim.models.keyedvectors.Vocab at 0x2401d568188>,
#  'robert': <gensim.models.keyedvectors.Vocab at 0x2401d568208>,
#  'bloody': <gensim.models.keyedvectors.Vocab at 0x2401d568288>,
#  'care': <gensim.models.keyedvectors.Vocab at 0x2401d568308>,
#  'looked': <gensim.models.keyedvectors.Vocab at 0x2401d568388>,
#  'bird': <gensim.models.keyedvectors.Vocab at 0x2401d568408>,
#  'held': <gensim.models.keyedvectors.Vocab at 0x2401d568488>,
#  'screamed': <gensim.models.keyedvectors.Vocab at 0x2401d568508>,
#  'again': <gensim.models.keyedvectors.Vocab at 0x2401d568588>,
#  'visited': <gensim.models.keyedvectors.Vocab at 0x2401d568608>,
#  'every_morning': <gensim.models.keyedvectors.Vocab at 0x2401d568688>,
#  'return': <gensim.models.keyedvectors.Vocab at 0x2401d568708>,
#  'am': <gensim.models.keyedvectors.Vocab at 0x2401d568788>,
#  'grateful': <gensim.models.keyedvectors.Vocab at 0x2401d568808>,
#  'shell': <gensim.models.keyedvectors.Vocab at 0x2401d568888>,
#  'good_man': <gensim.models.keyedvectors.Vocab at 0x2401d568908>,
#  'yet': <gensim.models.keyedvectors.Vocab at 0x2401d568988>,
#  'strange': <gensim.models.keyedvectors.Vocab at 0x2401d568a08>,
#  'thing': <gensim.models.keyedvectors.Vocab at 0x2401d568a88>,
#  'realize': <gensim.models.keyedvectors.Vocab at 0x2401d568b08>,
#  'meat': <gensim.models.keyedvectors.Vocab at 0x2401d568b88>,
#  'bone': <gensim.models.keyedvectors.Vocab at 0x2401d568c08>,
#  'standing': <gensim.models.keyedvectors.Vocab at 0x2401d568c88>,
#  'ahead': <gensim.models.keyedvectors.Vocab at 0x2401d568d08>,
#  'beyond_the_wall': <gensim.models.keyedvectors.Vocab at 0x2401d568d88>,
#  'men_like': <gensim.models.keyedvectors.Vocab at 0x2401d568e08>,
#  'weve': <gensim.models.keyedvectors.Vocab at 0x2401d568e88>,
#  'taken': <gensim.models.keyedvectors.Vocab at 0x2401d568f08>,
#  'vows': <gensim.models.keyedvectors.Vocab at 0x2401d568f88>,
#  'soon_enough': <gensim.models.keyedvectors.Vocab at 0x2401d56c048>,
#  'nights_watch': <gensim.models.keyedvectors.Vocab at 0x2401d56c0c8>,
#  'im_sure': <gensim.models.keyedvectors.Vocab at 0x2401d56c148>,
#  'force': <gensim.models.keyedvectors.Vocab at 0x2401d56c1c8>,
#  'nymeria': <gensim.models.keyedvectors.Vocab at 0x2401d56c248>,
#  'werent': <gensim.models.keyedvectors.Vocab at 0x2401d56c2c8>,
#  'properly': <gensim.models.keyedvectors.Vocab at 0x2401d56c348>,
#  'cares': <gensim.models.keyedvectors.Vocab at 0x2401d56c3c8>,
#  'theyre': <gensim.models.keyedvectors.Vocab at 0x2401d56c448>,
#  'theyre_going': <gensim.models.keyedvectors.Vocab at 0x2401d56c4c8>,
#  'anyway': <gensim.models.keyedvectors.Vocab at 0x2401d56c548>,
#  'watch': <gensim.models.keyedvectors.Vocab at 0x2401d56c5c8>,
#  'impressive': <gensim.models.keyedvectors.Vocab at 0x2401d56c648>,
#  'something': <gensim.models.keyedvectors.Vocab at 0x2401d56c6c8>,
#  'carefully': <gensim.models.keyedvectors.Vocab at 0x2401d56c748>,
#  'present': <gensim.models.keyedvectors.Vocab at 0x2401d56c7c8>,
#  'toy': <gensim.models.keyedvectors.Vocab at 0x2401d56c848>,
#  'yourself': <gensim.models.keyedvectors.Vocab at 0x2401d56c8c8>,
#  'skinny': <gensim.models.keyedvectors.Vocab at 0x2401d56c948>,
#  'blacksmith': <gensim.models.keyedvectors.Vocab at 0x2401d56c9c8>,
#  'special': <gensim.models.keyedvectors.Vocab at 0x2401d56ca48>,
#  'full': <gensim.models.keyedvectors.Vocab at 0x2401d56cac8>,
#  'holes': <gensim.models.keyedvectors.Vocab at 0x2401d56cb48>,
#  'enough': <gensim.models.keyedvectors.Vocab at 0x2401d56cbc8>,
#  'youll': <gensim.models.keyedvectors.Vocab at 0x2401d56cc48>,
#  'work': <gensim.models.keyedvectors.Vocab at 0x2401d56ccc8>,
#  'every_day': <gensim.models.keyedvectors.Vocab at 0x2401d56cd48>,
#  'does': <gensim.models.keyedvectors.Vocab at 0x2401d56cdc8>,
#  'lesson': <gensim.models.keyedvectors.Vocab at 0x2401d56ce48>,
#  'stick': <gensim.models.keyedvectors.Vocab at 0x2401d56cec8>,
#  'im_going': <gensim.models.keyedvectors.Vocab at 0x2401d56cf48>,
#  'miss': <gensim.models.keyedvectors.Vocab at 0x2401d56cfc8>,
#  'careful': <gensim.models.keyedvectors.Vocab at 0x2401d572088>,
#  'ive_got': <gensim.models.keyedvectors.Vocab at 0x2401d572108>,
#  'needle': <gensim.models.keyedvectors.Vocab at 0x2401d572188>,
#  'came': <gensim.models.keyedvectors.Vocab at 0x2401d572208>,
#  'say_goodbye': <gensim.models.keyedvectors.Vocab at 0x2401d572288>,
#  'ago': <gensim.models.keyedvectors.Vocab at 0x2401d572308>,
#  'robert_baratheon': <gensim.models.keyedvectors.Vocab at 0x2401d572348>,
#  'came_back': <gensim.models.keyedvectors.Vocab at 0x2401d5723c8>,
#  'youre_leaving': <gensim.models.keyedvectors.Vocab at 0x2401d572448>,
#  'choice': <gensim.models.keyedvectors.Vocab at 0x2401d5724c8>,
#  'calls': <gensim.models.keyedvectors.Vocab at 0x2401d572548>,
#  'thats': <gensim.models.keyedvectors.Vocab at 0x2401d5725c8>,
#  'youve_made': <gensim.models.keyedvectors.Vocab at 0x2401d572648>,
#  'must': <gensim.models.keyedvectors.Vocab at 0x2401d5726c8>,
#  'hard': <gensim.models.keyedvectors.Vocab at 0x2401d572748>,
#  'kind': <gensim.models.keyedvectors.Vocab at 0x2401d5727c8>,
#  'color': <gensim.models.keyedvectors.Vocab at 0x2401d572848>,
#  'farewell': <gensim.models.keyedvectors.Vocab at 0x2401d5728c8>,
#  'theres': <gensim.models.keyedvectors.Vocab at 0x2401d572948>,
#  'great_honor': <gensim.models.keyedvectors.Vocab at 0x2401d5729c8>,
#  'serving': <gensim.models.keyedvectors.Vocab at 0x2401d572a48>,
#  'manned': <gensim.models.keyedvectors.Vocab at 0x2401d572ac8>,
#  'thousands_of_years': <gensim.models.keyedvectors.Vocab at 0x2401d572b08>,
#  'stark': <gensim.models.keyedvectors.Vocab at 0x2401d572b88>,
#  'next_time': <gensim.models.keyedvectors.Vocab at 0x2401d572c08>,
#  'well_talk': <gensim.models.keyedvectors.Vocab at 0x2401d572c88>,
#  'leave': <gensim.models.keyedvectors.Vocab at 0x2401d572d08>,
#  'behind': <gensim.models.keyedvectors.Vocab at 0x2401d572d88>,
#  'kingsroad': <gensim.models.keyedvectors.Vocab at 0x2401d572e08>,
#  'swords': <gensim.models.keyedvectors.Vocab at 0x2401d572e88>,
#  'sides': <gensim.models.keyedvectors.Vocab at 0x2401d572f08>,
#  'couple': <gensim.models.keyedvectors.Vocab at 0x2401d572f88>,
#  'tavern': <gensim.models.keyedvectors.Vocab at 0x2401d575048>,
#  'warm': <gensim.models.keyedvectors.Vocab at 0x2401d5750c8>,
#  'beds': <gensim.models.keyedvectors.Vocab at 0x2401d575148>,
#  'tonight': <gensim.models.keyedvectors.Vocab at 0x2401d5751c8>,
#  'marry': <gensim.models.keyedvectors.Vocab at 0x2401d575248>,
#  'chance': <gensim.models.keyedvectors.Vocab at 0x2401d5752c8>,
#  'recall': <gensim.models.keyedvectors.Vocab at 0x2401d575348>,
#  'few': <gensim.models.keyedvectors.Vocab at 0x2401d5753c8>,
#  'chances': <gensim.models.keyedvectors.Vocab at 0x2401d575448>,
#  'great_big': <gensim.models.keyedvectors.Vocab at 0x2401d5754c8>,
#  'tits': <gensim.models.keyedvectors.Vocab at 0x2401d575548>,
#  'could': <gensim.models.keyedvectors.Vocab at 0x2401d5755c8>,
#  'face': <gensim.models.keyedvectors.Vocab at 0x2401d575648>,
#  'thank_the_gods': <gensim.models.keyedvectors.Vocab at 0x2401d5756c8>,
#  'rare': <gensim.models.keyedvectors.Vocab at 0x2401d575748>,
#  'never_told': <gensim.models.keyedvectors.Vocab at 0x2401d5757c8>,
#  'looked_like': <gensim.models.keyedvectors.Vocab at 0x2401d575848>,
#  'hit': <gensim.models.keyedvectors.Vocab at 0x2401d5758c8>,
#  'worst_thing': <gensim.models.keyedvectors.Vocab at 0x2401d575948>,
#  'ill_never': <gensim.models.keyedvectors.Vocab at 0x2401d5759c8>,
#  'daenerys_targaryen': <gensim.models.keyedvectors.Vocab at 0x2401d575a08>,
#  'wed': <gensim.models.keyedvectors.Vocab at 0x2401d575a88>,
#  'knife': <gensim.models.keyedvectors.Vocab at 0x2401d575b08>,
#  'sharp': <gensim.models.keyedvectors.Vocab at 0x2401d575b88>,
#  'shes': <gensim.models.keyedvectors.Vocab at 0x2401d575c08>,
#  'spread': <gensim.models.keyedvectors.Vocab at 0x2401d575c88>,
#  'legs': <gensim.models.keyedvectors.Vocab at 0x2401d575d08>,
#  'start': <gensim.models.keyedvectors.Vocab at 0x2401d575d88>,
#  'speaking': <gensim.models.keyedvectors.Vocab at 0x2401d575e08>,
#  'unspeakable': <gensim.models.keyedvectors.Vocab at 0x2401d575e88>,
#  'rhaegar_targaryen': <gensim.models.keyedvectors.Vocab at 0x2401d575ec8>,
#  'ill_kill': <gensim.models.keyedvectors.Vocab at 0x2401d575f48>,
#  'cant_get': <gensim.models.keyedvectors.Vocab at 0x2401d575fc8>,
#  'horde': <gensim.models.keyedvectors.Vocab at 0x2401d57b088>,
#  'million': <gensim.models.keyedvectors.Vocab at 0x2401d57b108>,
#  'threat': <gensim.models.keyedvectors.Vocab at 0x2401d57b188>,
#  'sea': <gensim.models.keyedvectors.Vocab at 0x2401d57b208>,
#  'ships': <gensim.models.keyedvectors.Vocab at 0x2401d57b288>,
#  'seven_kingdoms': <gensim.models.keyedvectors.Vocab at 0x2401d57b308>,
#  'usurper': <gensim.models.keyedvectors.Vocab at 0x2401d57b388>,
#  'targaryen': <gensim.models.keyedvectors.Vocab at 0x2401d57b408>,
#  'dothraki_horde': <gensim.models.keyedvectors.Vocab at 0x2401d57b488>,
#  'scum': <gensim.models.keyedvectors.Vocab at 0x2401d57b508>,
#  'cross': <gensim.models.keyedvectors.Vocab at 0x2401d57b588>,
#  'throw': <gensim.models.keyedvectors.Vocab at 0x2401d57b608>,
#  'dont_know': <gensim.models.keyedvectors.Vocab at 0x2401d57b688>,
#  'fighting': <gensim.models.keyedvectors.Vocab at 0x2401d57b708>,
#  'coming': <gensim.models.keyedvectors.Vocab at 0x2401d57b788>,
#  'sit': <gensim.models.keyedvectors.Vocab at 0x2401d57b808>,
#  'fed': <gensim.models.keyedvectors.Vocab at 0x2401d57b888>,
#  'untie': <gensim.models.keyedvectors.Vocab at 0x2401d57b908>,
#  'rapers': <gensim.models.keyedvectors.Vocab at 0x2401d57b988>,
#  'choose': <gensim.models.keyedvectors.Vocab at 0x2401d57ba08>,
#  'brothers': <gensim.models.keyedvectors.Vocab at 0x2401d57ba88>,
#  'trick': <gensim.models.keyedvectors.Vocab at 0x2401d57bb08>,
#  'dwarf': <gensim.models.keyedvectors.Vocab at 0x2401d57bb88>,
#  'id': <gensim.models.keyedvectors.Vocab at 0x2401d57bc08>,
#  'born': <gensim.models.keyedvectors.Vocab at 0x2401d57bc88>,
#  'peasant': <gensim.models.keyedvectors.Vocab at 0x2401d57bd08>,
#  '20_years': <gensim.models.keyedvectors.Vocab at 0x2401d57bd88>,
#  'killed': <gensim.models.keyedvectors.Vocab at 0x2401d57be08>,
#  'new_king': <gensim.models.keyedvectors.Vocab at 0x2401d57be88>,
#  'nephew': <gensim.models.keyedvectors.Vocab at 0x2401d57bf08>,
#  'part': <gensim.models.keyedvectors.Vocab at 0x2401d57bf88>,
#  'mind': <gensim.models.keyedvectors.Vocab at 0x2401d57f048>,
#  'needs': <gensim.models.keyedvectors.Vocab at 0x2401d57f0c8>,
#  'books': <gensim.models.keyedvectors.Vocab at 0x2401d57f148>,
#  'whats': <gensim.models.keyedvectors.Vocab at 0x2401d57f1c8>,
#  'story': <gensim.models.keyedvectors.Vocab at 0x2401d57f248>,
#  'nicely': <gensim.models.keyedvectors.Vocab at 0x2401d57f2c8>,
#  'maybe_ill': <gensim.models.keyedvectors.Vocab at 0x2401d57f348>,
#  'ancient': <gensim.models.keyedvectors.Vocab at 0x2401d57f3c8>,
#  'order': <gensim.models.keyedvectors.Vocab at 0x2401d57f448>,
#  'alongside': <gensim.models.keyedvectors.Vocab at 0x2401d57f4c8>,
#  'yes_yes': <gensim.models.keyedvectors.Vocab at 0x2401d57f548>,
#  'monsters': <gensim.models.keyedvectors.Vocab at 0x2401d57f5c8>,
#  'dont_believe': <gensim.models.keyedvectors.Vocab at 0x2401d57f648>,
#  'wine': <gensim.models.keyedvectors.Vocab at 0x2401d57f6c8>,
#  'belly': <gensim.models.keyedvectors.Vocab at 0x2401d57f748>,
#  'want_to_know': <gensim.models.keyedvectors.Vocab at 0x2401d57f7c8>,
#  'visit': <gensim.models.keyedvectors.Vocab at 0x2401d57f848>,
#  'cost_us': <gensim.models.keyedvectors.Vocab at 0x2401d57f8c8>,
#  'need_a_new': <gensim.models.keyedvectors.Vocab at 0x2401d57f948>,
#  'steward': <gensim.models.keyedvectors.Vocab at 0x2401d57f9c8>,
#  'several': <gensim.models.keyedvectors.Vocab at 0x2401d57fa48>,
#  'require': <gensim.models.keyedvectors.Vocab at 0x2401d57fac8>,
#  'immediate': <gensim.models.keyedvectors.Vocab at 0x2401d57fb48>,
#  'dont_care': <gensim.models.keyedvectors.Vocab at 0x2401d57fbc8>,
#  'ill_make': <gensim.models.keyedvectors.Vocab at 0x2401d57fc48>,
#  'first_thing': <gensim.models.keyedvectors.Vocab at 0x2401d57fcc8>,
#  'morning': <gensim.models.keyedvectors.Vocab at 0x2401d57fd48>,
#  'room': <gensim.models.keyedvectors.Vocab at 0x2401d57fdc8>,
#  'take_care': <gensim.models.keyedvectors.Vocab at 0x2401d57fe48>,
#  'rickon': <gensim.models.keyedvectors.Vocab at 0x2401d57fec8>,
#  'hes': <gensim.models.keyedvectors.Vocab at 0x2401d57ff48>,
#  'six': <gensim.models.keyedvectors.Vocab at 0x2401d57ffc8>,
#  'doesnt_know': <gensim.models.keyedvectors.Vocab at 0x2401d583088>,
#  'whats_happening': <gensim.models.keyedvectors.Vocab at 0x2401d583108>,
#  'follows': <gensim.models.keyedvectors.Vocab at 0x2401d583188>,
#  'around': <gensim.models.keyedvectors.Vocab at 0x2401d583208>,
#  'leg': <gensim.models.keyedvectors.Vocab at 0x2401d583288>,
#  'crying': <gensim.models.keyedvectors.Vocab at 0x2401d583308>,
#  'stop': <gensim.models.keyedvectors.Vocab at 0x2401d583388>,
#  'fire': <gensim.models.keyedvectors.Vocab at 0x2401d583408>,
#  'come_back': <gensim.models.keyedvectors.Vocab at 0x2401d583488>,
#  'youre_not_supposed': <gensim.models.keyedvectors.Vocab at 0x2401d5834c8>,
#  'supposed': <gensim.models.keyedvectors.Vocab at 0x2401d583548>,
#  'hes_dead': <gensim.models.keyedvectors.Vocab at 0x2401d5835c8>,
#  'brave_men': <gensim.models.keyedvectors.Vocab at 0x2401d583648>,
#  'dragons': <gensim.models.keyedvectors.Vocab at 0x2401d5836c8>,
#  'moon': <gensim.models.keyedvectors.Vocab at 0x2401d583748>,
#  'egg': <gensim.models.keyedvectors.Vocab at 0x2401d5837c8>,
#  'sky': <gensim.models.keyedvectors.Vocab at 0x2401d583848>,
#  'heat': <gensim.models.keyedvectors.Vocab at 0x2401d5838c8>,
#  'drank': <gensim.models.keyedvectors.Vocab at 0x2401d583948>,
#  'wife': <gensim.models.keyedvectors.Vocab at 0x2401d5839c8>,
#  'stories': <gensim.models.keyedvectors.Vocab at 0x2401d583a48>,
#  'nine': <gensim.models.keyedvectors.Vocab at 0x2401d583ac8>,
#  ...}

# %%
words = [word for word in model.wv.vocab]
vectors = [model.wv[word] for word in words]

# %%
def get_vectors_and_words(model):
    words = [word for word in model.wv.vocab]
    vectors = [model.wv[word] for word in words]
    return vectors, words
vectors, words = get_vectors_and_words(model)

# %% [markdown]
# ## Clustering Algorithms
#
# ### k-means
# ![k-means](figures/K-means-convergence.gif)
#
# As an input, the k-means algorithm requires the number of clusters present `k`, and a maximum number of iterations `i`.
#
# This algorithms consists of alternating two steps `i` times
# 1. assignment step: Assign each observation to the cluster whose mean has the least squared Euclidean distance, this is intuitively the "nearest" mean.
# 2. update step: Calculate the new means (centroids) of the observations in the new clusters. Do this by averaging the vectors for all instances in a given cluster
#
# Quiz: What's the run time for k-means for `n` data points?

# %%
# let's implement k-means on our word data
from sklearn.cluster import KMeans
vectors, words = get_vectors_and_words(model)
# k means takes as an input the number of clusters we expect to see. 
# we'll have to take a guess
num_clusters_guess = 300
kmeans = KMeans(n_clusters=num_clusters_guess, random_state=0)
kmeans.fit(vectors)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=300, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=0, tol=0.0001, verbose=0)

# %%
# we want the attribute of the KMeans model model.labels_

# %%
'''
-----------------------------------------------------------------
Objective: find a way to view words that are in the same cluster
-----------------------------------------------------------------
Right now we have the words ['these', 'are', 'unique', 'vocab', 'items', ...]
and the labels [0, 1, 1, 0, 2, ...]
These labels don't mean anything except that all the 1s go together, all the 2s, and so on

Figure out a way to hold this information so you can see which words are in which clusters
'''
from collections import defaultdict

def get_clusters(words, cluster_model):
    id_to_words = defaultdict(lambda: [])
    labels = cluster_model.labels_
    for word, label, in zip(words, labels):
        id_to_words[label].append(word)
    return id_to_words

clusters = get_clusters(words, kmeans)
clusters[4]
# Out:
# ['giving',
#  'missing',
#  'selling',
#  'speaking',
#  'new_king',
#  'telling',
#  'charming',
#  'needing',
#  'seeing',
#  'marching',
#  'advising',
#  'keeping',
#  'true_king',
#  'willing',
#  'trusting',
#  'searching',
#  'losing',
#  'living',
#  'according',
#  'saving',
#  'crossing',
#  'chopping',
#  'calling',
#  'future_king',
#  'helping',
#  'torturing',
#  'hang',
#  'raping',
#  'feeding',
#  'feeling',
#  'treating',
#  'sailing',
#  'defending',
#  'knowing',
#  'traveling',
#  'bleeding',
#  'kneeling',
#  'following',
#  'choosing',
#  'discussing',
#  'breaking',
#  'including',
#  'i’m_telling',
#  'sparring',
#  'night_king']

# %% [markdown]
# ##### show the first few clusters by printing them

# %% [markdown]
# #### How did K-means do?
#
# How do the clusters look? Do they make sense?
#
# How do we know that our number of clusters guess was right?

# %% [markdown]
# ### Hierarchical Clustering
#
# [Hierarchical clustering](https://en.wikipedia.org/wiki/Hierarchical_clustering) is a method of cluster analysis which seeks to build a hierarchy of clusters. There are two ways to do this
#
# 1. Agglomerative: bottom-up. Each observation starts in its own cluster and pairs of clusters are merged as we work up the hierarchy
# 2. Divisive: top-down. All observations start in one cluster, and splits are performed recursively as we move down the hierarchy.

# %% [markdown]
# ### Affinity Propagation - a type of Hierarchical Clustering
# ![affinity propagation](figures/affinity-propagation.gif)
#
# gif taken from [NIPS 2017 paper video](https://www.youtube.com/watch?v=1IOEFNGPNJc)
#
# From [sklearn's documentation](https://scikit-learn.org/stable/modules/clustering.html#affinity-propagation):
# >AffinityPropagation creates clusters by sending messages between pairs of samples until convergence. A dataset is then described using a small number of exemplars, which are identified as those most representative of other samples. The messages sent between pairs represent the suitability for one sample to be the exemplar of the other, which is updated in response to the values from other pairs. This updating happens iteratively until convergence, at which point the final exemplars are chosen, and hence the final clustering is given.
#
# One of the major benefits of affinity propagation is that it determines the number of clusters automatically.
#
# One of the downfalls of affinity propagation is the run time: `O(in^2)`

# %% [markdown]
# For more parameter's that come in sklearn, check [the documentation](https://scikit-learn.org/stable/modules/generated/sklearn.cluster.AffinityPropagation.html#sklearn.cluster.AffinityPropagation).

# %%
'''
---------------------------------------
objective: cluster the word embeddings
---------------------------------------
we're going to use sklearn's affinity propagation 

'''

from sklearn.cluster import AffinityPropagation

af = AffinityPropagation(convergence_iter=40, max_iter=1000)
af.fit(vectors)
# Out:
# AffinityPropagation(affinity='euclidean', convergence_iter=40, copy=True,
#                     damping=0.5, max_iter=1000, preference=None, verbose=False)

# %%
# how many clusters were generated? 
len(set(af.labels_))
# Out:
# 661

# %%
# let's take a look at the clusters by printing the first 20
clusters = get_clusters(words, af)
clusters
# Out:
# defaultdict(<function __main__.get_clusters.<locals>.<lambda>()>,
#             {200: ['what',
#               'that’s',
#               'whatever',
#               'what’re',
#               'what’s',
#               'whats',
#               'what’s_wrong',
#               'what’s_left'],
#              297: ['expect',
#               'meant',
#               'doubt',
#               'never_forget',
#               'never_knew',
#               'never_told',
#               'never_meant',
#               'never_asked',
#               'never_know',
#               'never_said',
#               'never_talked',
#               'never_leave',
#               'never_wanted',
#               'ever_met',
#               'never_thought',
#               'never_trust',
#               'never_liked',
#               'never_get',
#               'never_let'],
#              641: ['they’re',
#               'they',
#               'they’ve',
#               'theyre',
#               'theyd',
#               'theyll',
#               'theirs',
#               'they’ll',
#               'they’re_gonna',
#               'they’d'],
#              438: ['savages',
#               'lads',
#               'rules',
#               'candles',
#               'reads',
#               'fields',
#               'dark',
#               'troubles',
#               'minds',
#               'wolves',
#               'spikes',
#               'riders',
#               'resources',
#               'flowers',
#               'rides',
#               'stables',
#               'titles',
#               'riddles',
#               'mistakes',
#               'dirt',
#               'passes',
#               'tribes',
#               'agrees',
#               'garden',
#               'duties',
#               'creatures',
#               'towers',
#               'doom',
#               'farmers',
#               'hates',
#               'tales',
#               'gardens',
#               'ride_south',
#               'mines',
#               'open_the_gates',
#               'water_gardens',
#               'beetles',
#               'kisses',
#               'nods'],
#              0: ['one'],
#              1: ['lot'],
#              2: ['a'],
#              660: ['goat',
#               'quick',
#               'clouds',
#               'dress',
#               'eyrie',
#               'job',
#               'weak',
#               'dresses',
#               'patrol',
#               'scar',
#               'cloak',
#               'golden',
#               'gonna',
#               'gold_cloaks',
#               'siege',
#               'asks',
#               'farm',
#               'docks',
#               'podrick',
#               'cocks',
#               'cargo',
#               'address',
#               'gold_cloak',
#               'pod',
#               'tormund',
#               'locke',
#               'folks',
#               'missandei',
#               'oldtown',
#               'addresses',
#               'ser_rodrick',
#               'walking_along',
#               'goldcloaks'],
#              3: ['from'],
#              593: ['another',
#               'another_day',
#               'another_man',
#               'one_another',
#               'another_way',
#               'one_way_or_another'],
#              659: ['and',
#               'rickon',
#               'bran_and_rickon',
#               'randyll',
#               'dickon',
#               'daenerys_and_drogon',
#               'randyll_and_dickon',
#               'sandor'],
#              4: ['before'],
#              468: ['you',
#               'youre',
#               'youre_leaving',
#               'youre_not_supposed',
#               'youre_safe',
#               'youre_a_liar',
#               'lucky',
#               'youre_right',
#               'youre_heading',
#               'eh',
#               'youre_good',
#               'youre_far',
#               'youre_mine',
#               'youre_lying',
#               'youre_lucky',
#               'youre_gonna',
#               'youre_still',
#               'youre_a_woman',
#               'youre_coming',
#               'youre_supposed',
#               'maybe_youre'],
#              604: ['know',
#               'known',
#               'doesnt_know',
#               'must_know',
#               'l_know',
#               'ever_known',
#               'know_i_know',
#               'didn’t_know'],
#              5: ['it'],
#              6: ['each'],
#              7: ['other', 'others'],
#              8: ['to'],
#              466: ['pieces',
#               'owes',
#               'cares',
#               'holes',
#               'hides',
#               'babies',
#               'thieves',
#               'faces',
#               'clothes',
#               'fires',
#               'trees',
#               'bones',
#               'corpses',
#               'villages',
#               'goes',
#               'moves',
#               'axes',
#               'jokes',
#               'stones',
#               'losses',
#               'foes',
#               'lines',
#               'shoes',
#               'roses',
#               'loses',
#               'pauses'],
#              205: ['wildlings', 'wildling', 'wildling_army'],
#              9: ['do'],
#              628: ['this',
#               'outsider',
#               'ale',
#               'front',
#               'seven_hells',
#               'hounds',
#               'iron_islands',
#               'wisdom',
#               'darkest',
#               'braavosi',
#               'one_true_god',
#               'coin',
#               'iron',
#               'priest',
#               'braavos',
#               'chickens',
#               'iron_bank',
#               'iron_bank_of_braavos',
#               'queen_daenerys',
#               'consequences',
#               'queen_of_thorns',
#               'iron_fleet'],
#              10: ['not'],
#              11: ['ever'],
#              12: ['in'],
#              13: ['my'],
#              14: ['life'],
#              441: ['close', 'closed', 'closest', 'closer'],
#              15: ['as'],
#              16: ['any'],
#              496: ['man_would',
#               'never_would',
#               'l_could',
#               'else_would',
#               'one_would'],
#              17: ['the'],
#              18: ['dead'],
#              529: ['frighten',
#               'cat',
#               'he’s_coming',
#               'winter_is_coming',
#               'health',
#               'savage',
#               'ceremony',
#               'island',
#               'remind',
#               'meat',
#               'blacksmith',
#               'six',
#               'valyrian_steel',
#               'executioner',
#               'directly',
#               'sorts',
#               'amongst',
#               'fools',
#               'plead',
#               'meal',
#               'keeps',
#               'dancing_master',
#               'going_to_get',
#               'valyria',
#               'keep_the_peace',
#               'tragedy',
#               'freezing',
#               'hungry',
#               'mance_rayder',
#               'manage',
#               'attempt',
#               'sigil',
#               'drunk',
#               'fun',
#               'send_a_raven',
#               'clegane',
#               'hero',
#               'funeral',
#               'meals',
#               'frightened',
#               'make_peace',
#               'obey',
#               'summons',
#               'blind',
#               'afterwards',
#               'natural',
#               'temple',
#               'exactly',
#               'pockets',
#               'hes_got',
#               'creature',
#               'ashore',
#               'among',
#               'execute',
#               'summer_isles',
#               'demon_monkey',
#               'whilst',
#               'usual',
#               'demons',
#               'ordinary',
#               'heroes',
#               'diamonds',
#               'smash',
#               'lemon_cakes',
#               'general',
#               'valyrian',
#               'sandor_clegane',
#               'abandon',
#               'formal',
#               'attempts',
#               'bedding_ceremony',
#               'testimony',
#               'dozens',
#               'marwyn'],
#              19: ['our'],
#              20: ['orders', 'order'],
#              431: ['were', 'aren’t', 'werent', 'weren’t'],
#              21: ['we'],
#              22: ['them'],
#              23: ['won’t', 'can’t'],
#              591: ['trouble',
#               'forever',
#               'plenty',
#               'pretty',
#               'clever',
#               'sundown',
#               'perfect',
#               'today',
#               'insult',
#               'lovely',
#               'share',
#               'easier',
#               'dog',
#               'grateful',
#               'impressive',
#               'carefully',
#               'special',
#               'miss',
#               'careful',
#               'sharp',
#               'untie',
#               'nicely',
#               'accompany',
#               'dangerous_place',
#               'happier',
#               'supper',
#               'load',
#               'ugly',
#               'double',
#               'supply',
#               'idiot',
#               'bad',
#               'marvelous',
#               'able',
#               'miserable',
#               'empty',
#               'easy',
#               'enjoy',
#               'company',
#               'memory',
#               'expensive',
#               'sad',
#               'unlikely',
#               'sooner',
#               'likely',
#               'quiet',
#               'answer',
#               'admirable',
#               'soft',
#               'purpose',
#               'important',
#               'quality',
#               'purse',
#               'awful',
#               'difficult',
#               'discuss',
#               'simple',
#               'lust',
#               'rarely',
#               'possess',
#               'perfectly',
#               'suffer',
#               'suitable',
#               'mindless',
#               'somehow',
#               'complicated',
#               'entirely_different',
#               'capable',
#               'especially',
#               'eager',
#               'hurry',
#               'smuggler',
#               'pretend',
#               'however',
#               'useful',
#               'pretender',
#               'merely',
#               'quite_good',
#               'subjects',
#               'useless',
#               'surprise',
#               'authority',
#               'lawful',
#               'luckily',
#               'much_easier',
#               'wonderful',
#               'successful',
#               'tiny',
#               'answers',
#               'softly',
#               'glorious_queen',
#               'actress'],
#              24: ['us'],
#              25: ['no'],
#              26: ['more'],
#              460: ['don’t_think',
#               'think',
#               'dont_think',
#               'dont_you_think',
#               'didnt_think',
#               'could_think',
#               'l_think',
#               'really_think',
#               'youd_think',
#               'didn’t_think'],
#              425: ['he’ll', 'we’ll', 'shell', 'she’ll'],
#              27: ['ask'],
#              28: ['how'],
#              29: ['died'],
#              576: ['get_back',
#               'takes',
#               'came_back',
#               'come_back',
#               'go_back',
#               'take_us',
#               'never_come_back',
#               'take_back',
#               'fall_back',
#               'take_me_back',
#               'turns_back'],
#              30: ['on'],
#              618: ['your',
#               'saddle',
#               'swore_an_oath',
#               'sentence_you_to_die',
#               'direwolf',
#               'tough_old',
#               'blade',
#               'one’s',
#               'agree',
#               'gods_be_good',
#               'hey_hey',
#               'ooh',
#               'would_you_please_shut',
#               'crypt',
#               '16',
#               'aye',
#               'damn',
#               'anybody',
#               'explain',
#               'leave_me_alone',
#               'begun',
#               '–',
#               'write',
#               'viserys',
#               'khal_drogo',
#               'come_forward',
#               'apologies',
#               'offense',
#               'hush',
#               'he’d',
#               'someday',
#               'i’m_ready',
#               'none_of_us',
#               'rescue',
#               'wanted_to_see',
#               'offend',
#               'uncle_benjen',
#               'it’s_true',
#               'celebrate',
#               'it’s_time',
#               'son’s',
#               'favor',
#               'eggs',
#               'serve_you_well',
#               'completely',
#               'ghost',
#               'everything_thats',
#               'hospitality',
#               'nonsense',
#               'already',
#               'ridiculous',
#               'ahead',
#               'nymeria',
#               'skinny',
#               'say_goodbye',
#               'color',
#               'farewell',
#               'thank_the_gods',
#               'unspeakable',
#               'scum',
#               'cost_us',
#               'hes_dead',
#               'egg',
#               'lys',
#               'upset',
#               'mycah',
#               'butchers_boy',
#               'filthy',
#               'inn',
#               'bite',
#               'anyone',
#               'appropriate',
#               'nobody',
#               'except',
#               'aerys',
#               'admire',
#               'duel',
#               'beg_your_pardon',
#               'mmm',
#               '3',
#               'tomorrow',
#               'hill_tribes',
#               'em',
#               'sweet_girl',
#               'know_how_to_use',
#               'oh_my_sweet',
#               'felt',
#               'freeze',
#               'still_dont',
#               'lost_your_mind',
#               'must_admit',
#               'itd',
#               'petyr',
#               'task',
#               'stupid',
#               'wish_i_could',
#               'huh',
#               'howd',
#               'dumb',
#               'blond_hair',
#               'm',
#               'week',
#               'dont_have_enough_men',
#               'particularly',
#               'axe',
#               'benjen',
#               'keep_warm',
#               'rabbits',
#               'ducks',
#               'target',
#               'robbs',
#               'resist',
#               'sailors',
#               'samwell_tarly',
#               'horn_hill',
#               'ive_come',
#               'sure_you_want',
#               '15',
#               'asshai',
#               'sails',
#               'cruel',
#               'need_more_men',
#               '50',
#               'thank_you_my_lord',
#               'envy',
#               'blue',
#               'presume',
#               'study',
#               'shadows',
#               'said_im',
#               'almost',
#               'pycelle',
#               'said_hed',
#               'regret',
#               'afternoon',
#               'anymore',
#               'im_gonna',
#               'invite',
#               'slut',
#               'officers',
#               'pregnant',
#               'rhaegar',
#               'rude',
#               'music',
#               'im_glad',
#               'somebody',
#               'hmm',
#               'quite_a_bit',
#               'ah',
#               'slept',
#               'absolutely',
#               'jealous',
#               '17',
#               'tried_to_kill',
#               'oh_im',
#               'rumor',
#               'earlier',
#               'may_i_ask',
#               'aunt',
#               'lysa',
#               'wrote',
#               'shh_shh_shh',
#               'sweet_boy',
#               'slip',
#               'yes_well',
#               'needs_to_be_done',
#               'wont_be_able',
#               'hide_behind',
#               'spite',
#               'lyanna',
#               'healthy',
#               'overcome',
#               'put_an_end',
#               'admit',
#               'let_him_go',
#               'osha',
#               'nobility',
#               'intend',
#               'wish_to_confess',
#               'yes_my_lady',
#               'found_guilty',
#               'beg',
#               'avenge',
#               'size',
#               'assume',
#               'anointed_knight',
#               'aware',
#               'salt',
#               'uh',
#               'value',
#               'seize',
#               'time_to_go',
#               'fierce',
#               'corpse',
#               'ive_made',
#               'yes_my_lord',
#               'lets_start',
#               'go_ahead',
#               'confidant',
#               'jaw',
#               'aint',
#               'across_the_sea',
#               'merchant',
#               'fruit',
#               'certainly',
#               'revenge',
#               'odd',
#               'come_with_us',
#               'thirsty',
#               'eunuch',
#               'sadly',
#               'thats_true',
#               'id_say',
#               'fealty',
#               'im_hungry',
#               'rumors',
#               'go_to_war',
#               'persuade',
#               'seriously',
#               'brush',
#               'gratitude',
#               'melt',
#               'l_cant',
#               'l_didnt',
#               'sense',
#               'apologize',
#               'really_want',
#               'pursue',
#               'sooner_or_later',
#               'sun_and_stars',
#               'interrupt',
#               'discipline',
#               'shae',
#               'last_night_in_this_world',
#               'across_the_narrow_sea',
#               'hes_already',
#               'magic',
#               'lowborn',
#               'orphan',
#               'man_and_wife',
#               'yeah',
#               '20',
#               'take_him_away',
#               'swore_to_protect',
#               'merciful',
#               'shaggydog',
#               'sansa_and_arya',
#               'let_me_show',
#               'sue_for_peace',
#               'stupidity',
#               '500',
#               'dust',
#               'whats_your_name',
#               'ghosts',
#               'brought_you_back',
#               'dusk',
#               'name_day',
#               'adventures',
#               'oh_aye',
#               'night_is_dark_and_full_of_terrors',
#               'lord_cast_your_light_upon',
#               'fanatics',
#               'time_has_come',
#               'apology',
#               'whats_wrong',
#               'perhaps_youll',
#               'gossip',
#               'rum',
#               'stink',
#               'negotiate',
#               'changed_my_mind',
#               'close_your_eyes',
#               'appreciate',
#               'jaqen_hghar',
#               'spirit',
#               'dignity',
#               'seems_a_bit',
#               'potatoes',
#               'oh_oh',
#               'im_done',
#               'cabin',
#               'shhh',
#               'poor_little',
#               'intelligent',
#               'definitely',
#               'i’ll_see',
#               'apologies_my_lord',
#               'give_the_order',
#               'uncomfortable',
#               'within_a_mile',
#               'hot_pie',
#               'ive_brought',
#               'dead_may_never_die',
#               'vouch',
#               'correct',
#               'salladhor_saan',
#               'ive_known',
#               'exist',
#               'keep_you_safe',
#               'fought_bravely',
#               'recognize',
#               'ripe',
#               'deepwood_motte',
#               'get_one',
#               'wont_even_know',
#               'bent_the_knee',
#               'handmaiden',
#               'queen_mustnt_know',
#               'affairs',
#               'virgin',
#               'tear_us_apart',
#               'safest_place',
#               'head_on_a_spike',
#               'willem',
#               'ax',
#               'cub',
#               'kill_joffrey',
#               'behavior',
#               'favorite',
#               'necessary',
#               'fanatic',
#               'xaro_xhoan_daxos',
#               'cupbearer',
#               'grand_maester_pycelle',
#               'oh_well',
#               'ser_davos_seaworth',
#               'wildfire',
#               'worship',
#               'issue',
#               'time_comes',
#               '40',
#               'hes_the_one',
#               'romantic',
#               'gentle',
#               'ocean',
#               'brilliant',
#               'ygritte',
#               'free_folk',
#               'qhorin_halfhand',
#               'loudly',
#               'hail',
#               'go_and_find',
#               'met_many',
#               'silver_hair',
#               'argue',
#               'youve_already',
#               'spy',
#               'o',
#               'outlaws',
#               'mutton',
#               'whole_life',
#               'legacy',
#               'valuable',
#               'oil',
#               'let_me_help',
#               'may_as_well',
#               'seem_to_recall',
#               'itself',
#               'open_the_gate',
#               'crib',
#               'lets_see',
#               'crush',
#               'explains',
#               'necklace',
#               'virtue',
#               '12',
#               'rhoyne',
#               'cheese',
#               'set_him_free',
#               'beef',
#               'essence_of_nightshade',
#               'horror',
#               'drums',
#               '13',
#               'open_rebellion',
#               'solemn',
#               '2',
#               'tullys',
#               'back_to_the_iron_islands',
#               'swim',
#               'mine_from_this_day_until_the_end_of_my_days',
#               'valar_morghulis',
#               'jaqen',
#               'said_youd',
#               'edd',
#               'know_whats',
#               'chicken',
#               'thought_you_were_dead',
#               'avoid',
#               'dumb_bitch',
#               'babe',
#               'meaning_no_offense',
#               'luthor',
#               'jojen',
#               'jump',
#               'politics',
#               'aim',
#               'prize',
#               'lifetime',
#               'equal',
#               'gamble',
#               'men_must_die',
#               'ahem',
#               'sapphires',
#               'daddy',
#               'extraordinary',
#               'traditionally',
#               '700',
#               'start_a_war',
#               'saved_your_life',
#               'watch_has_ended',
#               'trial_by_combat',
#               'check',
#               'beric',
#               'im_a_bit',
#               'mm',
#               'mmhmm',
#               'find_sansa',
#               'im_the_only_one',
#               'even_though',
#               'come_on_come',
#               'bald',
#               'rip',
#               'complain',
#               'daario_naharis',
#               'triumph',
#               'moment_alone',
#               'it’s_good',
#               'how’s',
#               'best_part',
#               'gonna_die',
#               'arrogant',
#               'mhysa',
#               'mhysa_mhysa_mhysa',
#               'left_hand',
#               'timid',
#               'take_off_your_clothes',
#               'arrange',
#               'quite_a_lot',
#               'ellaria_sand',
#               'aunt_lysa',
#               'took_us',
#               'reek',
#               'im_guilty',
#               'youd_forget',
#               'mutineers',
#               'set_me_free',
#               'rest_of_your_life',
#               'uncle_petyr',
#               'meryn_trant',
#               'im_going_to_kill',
#               'shh_shh',
#               'im_reek',
#               'hizdahr_zo_loraq',
#               'lollys',
#               'kidney_pie',
#               'gravy',
#               'um',
#               'suicide',
#               'khuu_khuu_khuu',
#               'elia_martell',
#               'wanna',
#               'im_sorry_i_cant',
#               'dig',
#               'valar_dohaeris',
#               'uncle_kevan',
#               'royal_decree',
#               'pay_us',
#               'trystane',
#               'i’ve_come',
#               'bucket',
#               'i’m_glad',
#               'obviously',
#               'it’s_hard',
#               'you’re_welcome',
#               'momma',
#               'wolkan',
#               'nods_his_head',
#               'shakes_his_head'],
#              358: ['horse',
#               'horses',
#               'horseback',
#               'neck',
#               'weeks',
#               'floor',
#               'way_back',
#               'backs',
#               'stuck',
#               'suck'],
#              549: ['dead_men',
#               'brave_men',
#               '500_men',
#               'old_men',
#               '100_men',
#               'two_men',
#               'need_men',
#               '20_men',
#               'wounded_men',
#               'free_men',
#               '1000_men'],
#              31: ['seem', 'seems'],
#              141: ['have', 'haven’t', 'havent'],
#              248: ['moved', 'loved', 'lived', 'beloved'],
#              651: ['camp',
#               'touch',
#               'third',
#               'catelyn',
#               'begin',
#               'pentos',
#               'breakfast',
#               'wash',
#               'spread',
#               'myself',
#               'prayer',
#               'calm',
#               'tunnel',
#               'grip',
#               'shape',
#               'get_past',
#               'tourney',
#               'poison',
#               'septa',
#               'varys',
#               'sneak',
#               'spit',
#               'box',
#               'ill_bring',
#               'convincing',
#               'fish',
#               'white_harbor',
#               'im_giving',
#               'collapse',
#               'sept_of_baelor',
#               'make_sure',
#               'assassins',
#               'view',
#               'laugh',
#               'septon',
#               'baelor',
#               'torrhens_square',
#               'seas',
#               'trip',
#               'punish',
#               'dinner',
#               'herself',
#               'harbor',
#               'overthrow',
#               'brienne_of_tarth',
#               'brienne',
#               'myrcella',
#               'princess_myrcella',
#               'convince',
#               'seduce',
#               'black_cells',
#               'crew',
#               'halfhand',
#               'warlocks',
#               'opportunity',
#               'courtyard',
#               'square',
#               'sunrise',
#               'raven_scroll',
#               'dracarys',
#               'judge',
#               'torch',
#               'blackfish',
#               'qyburn',
#               'ash',
#               'heir_to_highgarden',
#               'yunkish',
#               'myranda',
#               'back_to_castle_black',
#               'sept',
#               'crasters_keep',
#               'greyscale',
#               'many_faced_god',
#               'septa_unella',
#               'stops_and_turns',
#               'turns_to_look'],
#              599: ['here',
#               'where',
#               'where’s',
#               'somewhere',
#               'still',
#               'going_anywhere',
#               'anywhere',
#               'wherever',
#               'somewhere_else',
#               'wheres',
#               'somewhere_safe',
#               'nowhere',
#               'elsewhere'],
#              32: ['see'],
#              33: ['went'],
#              34: ['is'],
#              35: ['it’s'],
#              36: ['go'],
#              337: ['father’s',
#               'father',
#               'uncle',
#               'father_knew',
#               'fathers',
#               'father_used',
#               'father_would',
#               'father_gave',
#               'father_told',
#               'father_died'],
#              355: ['watching',
#               'making',
#               'talking',
#               'taking',
#               'fucking',
#               'thinking',
#               'speaking',
#               'coming',
#               'joking',
#               'drinking',
#               'lurking',
#               'walking',
#               'having',
#               'asking',
#               'stealing',
#               'i’m_talking',
#               'stinking',
#               'moving',
#               'leaving',
#               'working',
#               'helping',
#               'knocking',
#               'night_king'],
#              483: ['mother',
#               'brother',
#               'mothers',
#               'brothers',
#               'brotherhood',
#               'brothels',
#               'brothel',
#               'older_brother',
#               'brother_jaime',
#               'brother’s',
#               'brothers_and_sisters',
#               'brother_and_sister',
#               'mother_and_father',
#               'mother_and_brother',
#               'baby_brother',
#               'grandmother',
#               'mother’s'],
#              617: ['always',
#               'happy',
#               'always_wanted',
#               'glad',
#               'always_thought',
#               'always_loved',
#               'always_knew'],
#              439: ['well_done',
#               'well_talk',
#               'well_well',
#               'well_go',
#               'wet',
#               'well_get',
#               'well_make',
#               'well_fought',
#               'well_take',
#               'well_hes',
#               'well_meet',
#               'well_find',
#               'well_need'],
#              37: ['thank', 'thanks'],
#              38: ['i'],
#              39: ['love'],
#              649: ['that',
#               'something',
#               'sometimes',
#               'there’s_nothing',
#               'something_else',
#               'theres_something',
#               'something_like',
#               'something_important',
#               'here’s',
#               'there’s_something'],
#              646: ['you’ve',
#               'you’ve_got',
#               'you’d',
#               'hes_always',
#               'youve_always',
#               'ive_always',
#               'you’ve_done',
#               'you’ve_always'],
#              452: ['managed',
#               'since',
#               'refused',
#               'beheaded',
#               'settled',
#               'hoped',
#               'wept',
#               'forced',
#               'needed',
#               'stayed',
#               'doomed',
#               'accused',
#               'agreed',
#               'determined',
#               'ended',
#               'engaged',
#               'surprised',
#               'opened',
#               'cursed',
#               'arranged',
#               'wounded',
#               'breed',
#               'marched',
#               'crushed',
#               'devoted',
#               'headed',
#               'wished',
#               'pledged',
#               'disobeyed',
#               'counseled',
#               'confused',
#               'intended',
#               'defended'],
#              40: ['get'],
#              41: ['which'],
#              42: ['at'],
#              383: ['ten', 'forgot', 'forgotten', 'gotten'],
#              43: ['keep'],
#              631: ['practicing',
#               'guarding',
#               'riding',
#               'giving',
#               'beheading',
#               'laughing',
#               'providing',
#               'charming',
#               'finding',
#               'needing',
#               'holding',
#               'seeing',
#               'pretending',
#               'starving',
#               'dancing',
#               'offering',
#               'sending',
#               'whispering',
#               'according',
#               'gathering',
#               'leading',
#               'torturing',
#               'reading',
#               'feeding',
#               'spending',
#               'sailing',
#               'defending',
#               'im_warning',
#               'knowing',
#               'bleeding',
#               'hiding',
#               'heading',
#               'betraying',
#               'discussing',
#               'breaking',
#               'building',
#               'including'],
#              633: ['bran',
#               'brandon',
#               'brans',
#               't',
#               'ran',
#               'ya',
#               'bran_bran',
#               'bran_wake'],
#              44: ['too'],
#              45: ['jon'],
#              46: ['faster', 'master', 'monster', 'craster'],
#              47: ['just'],
#              389: ['rode',
#               'road',
#               'room',
#               'rooms',
#               'rot',
#               'ros',
#               'roots',
#               'boots',
#               'lots',
#               'root',
#               'rots',
#               'roof',
#               'roads',
#               'sets'],
#              404: ['hills',
#               'skulls',
#               'shame',
#               'skills',
#               'kills',
#               'ls',
#               'skill'],
#              398: ['captured',
#               'five',
#               'capital',
#               'receive',
#               'capture',
#               'captive',
#               'arrive',
#               'captain',
#               'lve',
#               'carve',
#               'survive',
#               'captains',
#               'drive'],
#              253: ['night’s_watch',
#               'men_of_the_nights_watch',
#               'nights_watch',
#               'man_of_the_nights_watch',
#               'city_watch',
#               'nights',
#               'knights_of_the_vale',
#               'lord_commander_of_the_nights_watch',
#               'warden_of_the_north'],
#              48: ['their'],
#              49: ['he'],
#              409: ['law',
#               'join',
#               'play',
#               'demand',
#               'owe',
#               'deliver',
#               'delay',
#               'lay',
#               'slay',
#               'repay',
#               'demands'],
#              543: ['lady',
#               'lady_stark',
#               'welcome',
#               'ladys',
#               'sansa_come',
#               'lady_catelyn',
#               'pleasure',
#               'lady_sansa',
#               'lady_my_lady',
#               'milady',
#               'lady_brienne',
#               'lady_melisandre',
#               'lady_talisa',
#               'lady_margaery',
#               'welcome_home',
#               'lady_olenna',
#               'lady_crane'],
#              50: ['tell'],
#              51: ['ned'],
#              385: ['young', 'best', 'youngest', 'biggest', 'younger'],
#              52: ['such'],
#              582: ['things',
#               'terrible_thing',
#               'horrible',
#               'terrible',
#               'ways',
#               'lots_of_things',
#               'terribly',
#               'many_things',
#               'terrible_things',
#               'see_things'],
#              53: ['be'],
#              54: ['boy'],
#              55: ['lad'],
#              56: ['rest'],
#              57: ['white_walkers',
#               'saw_the_white_walkers',
#               'walkers',
#               'beyond_the_wall',
#               'north_of_the_wall',
#               'south_of_the_wall',
#               'white',
#               'climb_the_wall',
#               'killed_a_white_walker',
#               'white_walker'],
#              58: ['saw'],
#              451: ['broke',
#               'first_of_his_name',
#               'he’s_got',
#               'let_me_see',
#               'rest_of_us',
#               'toy',
#               'whats_happening',
#               'leg',
#               'drank',
#               'whip',
#               'pet',
#               'sat',
#               'pyp',
#               'close_my_eyes',
#               'heavy',
#               'one_hand',
#               'sam',
#               'hello',
#               'helmet',
#               'thoros_of_myr',
#               'gag',
#               'arse',
#               'private',
#               'send_word',
#               'ingslayer',
#               'we’ll_take',
#               'stuff',
#               'sausage',
#               'moon_door',
#               'ranks',
#               'get_your_hands',
#               'one_of_us',
#               'step_aside',
#               'blame',
#               'seek',
#               'get_out_of_my_way',
#               'bronn',
#               'lf',
#               'cut_your_throat',
#               'get_some_sleep',
#               'heel',
#               'put_a_sword',
#               'escape',
#               'shut_your_mouth',
#               'kingbeyondthewall',
#               'cup_of_wine',
#               'cut_his_throat',
#               'pyke',
#               'way_around',
#               'best_way',
#               'drowned_god',
#               'treachery',
#               'guide',
#               'push',
#               'joy',
#               'rest_of_my_life',
#               'misery',
#               'mud_gate',
#               'sounds',
#               'climate',
#               'bolt',
#               'disease',
#               'guilty',
#               'hut',
#               'bag_of_gold',
#               'i’m_telling',
#               'what’s_happening',
#               'steps_forward',
#               'closer_to_jon',
#               'retrieves',
#               'walks_away'],
#              632: ['oath', 'filth', 'death', 'birth', 'bath', 'path', 'naath'],
#              59: ['i’m'],
#              211: ['should',
#               'didn’t',
#               'wouldn’t',
#               'shouldn’t',
#               'shouldnt',
#               'couldn’t'],
#              60: ['gone'],
#              440: ['warned', 'earned', 'learn', 'learned'],
#              61: ['but'],
#              62: ['if'],
#              63: ['can'],
#              539: ['family',
#               'families',
#               'family_name',
#               'familiar',
#               'familys',
#               'family_home'],
#              367: ['coward', 'cowards', 'toward', 'stewards', 'towards'],
#              87: ['sorry', 'i’m_sorry', 'worry', 'i’m_sure', 'im_sorry'],
#              64: ['away'],
#              65: ['king_of_the_andals_and_the_first_men',
#               'lord_of_the_seven_kingdoms_and_protector',
#               'hand_of_the_king',
#               'wife_of_the_great_khal',
#               'protector_of_the_realm',
#               'milk_of_the_poppy',
#               'jorah_the_andal',
#               'lord_commander_of_the_kingsguard',
#               'sight_of_gods_and_men',
#               'children_of_the_forest',
#               'light_of_the_seven',
#               'fist_of_the_first_men',
#               'house_of_the_undying',
#               'edge_of_the_world',
#               'men_lord_of_the_seven',
#               'kingdoms_and_protector_of_the_realm',
#               'half_the_men',
#               'tower_of_the_hand',
#               'army_of_the_dead',
#               'sand',
#               'lord_of_the_vale',
#               'sons_of_the_harpy'],
#              66: ['will'],
#              67: ['of'],
#              508: ['realm',
#               'real',
#               'realize',
#               'really',
#               'realized',
#               'read',
#               'real_war'],
#              335: ['house_stark',
#               'ned_stark’s',
#               'ned_stark',
#               'ned_starks_bastard',
#               'ned_starks_son',
#               'brandon_stark',
#               'catelyn_starks',
#               'arya_stark',
#               'robb_stark',
#               'eddard_stark',
#               'robb_starks',
#               'ned_starks',
#               'catelyn_stark',
#               'karstarks',
#               'sansa_stark',
#               'karstark'],
#              655: ['lord_of_winterfell_and_warden_of_the_north',
#               'winterfell',
#               'ready',
#               'lord_of_winterfell',
#               'cell',
#               'take_winterfell',
#               'bastard_of_winterfell',
#               'come_to_winterfell',
#               'lady_of_winterfell'],
#              68: ['did'],
#              69: ['well'],
#              482: ['understand',
#               'don’t_understand',
#               'dont_know',
#               'dont_believe',
#               'understands',
#               'understood',
#               'dont_understand'],
#              70: ['why'],
#              602: ['said', 'paid', 'maid', 'raid', 'aid', 'laid'],
#              71: ['was'],
#              72: ['had'],
#              73: ['kill'],
#              74: ['him'],
#              75: ['way'],
#              76: ['sword'],
#              77: ['true'],
#              78: ['been'],
#              79: ['so'],
#              520: ['lying',
#               'trying',
#               'being',
#               'saying',
#               'buying',
#               'crying',
#               'darling',
#               'praying',
#               'playing',
#               'hoping',
#               'enjoying',
#               'staying',
#               'keeping',
#               'dying',
#               'sing',
#               'sleeping',
#               'begging',
#               'carrying',
#               'flying',
#               'smiling',
#               'spying',
#               'raping',
#               'marrying',
#               'paying',
#               'weeping',
#               'terrifying',
#               'ending',
#               'sparring'],
#              418: ['madman',
#               'fool',
#               'dwarf',
#               'young_man',
#               'halfman',
#               'clever_man',
#               'last_man',
#               'dwarf_man',
#               'dead_man',
#               'old_man',
#               'one_man',
#               'human',
#               'kill_a_man',
#               'rich_man',
#               'flayed_man'],
#              622: ['sees',
#               'approaching',
#               'baelish',
#               'approach',
#               'aryas',
#               'reaches',
#               'approaches'],
#              341: ['mountain',
#               'certain',
#               'pain',
#               'rain',
#               'maintain',
#               'mountains',
#               'remain',
#               'main',
#               'grain'],
#              492: ['lion',
#               'attention',
#               'reputation',
#               'mention',
#               'position',
#               'invitation',
#               'action',
#               'conversation',
#               'ambition',
#               'direction',
#               'situation',
#               'notion',
#               'corruption',
#               'imagination',
#               'affliction',
#               'devotion',
#               'distinction',
#               'tradition',
#               'option',
#               'proposition'],
#              80: ['there'],
#              81: ['are'],
#              331: ['lions',
#               'alive',
#               'ladies',
#               'favorites',
#               'instructions',
#               'reports',
#               'glory',
#               'giants',
#               'dungeons',
#               'companions',
#               'veins',
#               'lessons',
#               'information',
#               'whispers',
#               'homes',
#               'forces',
#               'free_cities',
#               'courage',
#               'affection',
#               'tents',
#               'responsibilities',
#               'lips',
#               'theons',
#               'troops',
#               'circumstances',
#               'onions',
#               'talents',
#               'thenns',
#               'intentions',
#               'visions',
#               'decisions',
#               'inspire',
#               'former_slaves',
#               'poisons',
#               'traditions',
#               'generations'],
#              82: ['these'],
#              531: ['woods', 'wooden', 'wood'],
#              513: ['beast',
#               'fast',
#               'feast',
#               'least',
#               'feasts',
#               'rast',
#               'past',
#               'cost',
#               'breast',
#               'east',
#               'coast',
#               'cast',
#               'beasts',
#               'toast'],
#              83: ['now'],
#              84: ['down'],
#              584: ['better',
#               'letter',
#               'hunter',
#               'im_better',
#               'prettier',
#               'harder',
#               'matter',
#               'feel_better',
#               'even_better',
#               'youd_better',
#               'much_better',
#               'far_better',
#               'better_place'],
#              85: ['last'],
#              499: ['without',
#               'with',
#               'question',
#               'questions',
#               'within',
#               'request',
#               'without_question',
#               'man_without',
#               'men_without'],
#              86: ['put'],
#              471: ['please',
#               'please_please',
#               'please_dont',
#               'release',
#               'cry',
#               'angry',
#               'ease',
#               'stop_please',
#               'grace_please',
#               'please_stop',
#               'pleased',
#               'khaleesi_please'],
#              454: ['train', 'traitor', 'traitors'],
#              88: ['yourselves', 'yourself', 'themselves', 'ourselves'],
#              89: ['feed'],
#              90: ['die'],
#              247: ['bury', 'burned', 'burnt', 'burn', 'burning', 'burns'],
#              91: ['about'],
#              290: ['yours', 'hours', 'ours', 'hour'],
#              551: ['snow',
#               'nothing',
#               'perhaps',
#               'means_nothing',
#               'bend_the_knee',
#               'respect',
#               'nothing_like',
#               'going_to_kill',
#               'jon_snow',
#               'nothing_else',
#               'nothing_to_say',
#               'note',
#               'know_nothing',
#               'know_nothing_jon_snow',
#               'us_jon_snow',
#               'nothing_to_fear',
#               'know_you’re'],
#              92: ['feel', 'feels'],
#              503: ['duty',
#               'rightful_king',
#               'new_king',
#               'mad_king',
#               'true_king',
#               'future_king',
#               'future'],
#              574: ['warn',
#               'news',
#               'royal',
#               'fault',
#               'whore',
#               'common',
#               'go_home',
#               'lesson',
#               'ancient',
#               'archer',
#               'warrior',
#               'like_your_father',
#               'mark',
#               'summer',
#               'id_rather',
#               'nameday',
#               'songs',
#               'cousin',
#               'ancestors',
#               'sweet',
#               'grandfather',
#               'struck',
#               'last_hearth',
#               'song',
#               'victory',
#               'remove',
#               'sow',
#               'reply',
#               'vile',
#               'marriage',
#               'father_wants',
#               'represent',
#               'confess',
#               'son_bran',
#               'barristan',
#               'teeth',
#               'comes_of_age',
#               'homeland',
#               'vow',
#               'custody',
#               'window',
#               'hostage',
#               'harrenhal',
#               'faithfully',
#               'torn',
#               'lord_father',
#               'role',
#               'husbands',
#               'scouts',
#               'sin',
#               'apprentice',
#               'killed_my_father',
#               'stable_boy',
#               'cousins',
#               'warriors',
#               'soul',
#               'palace',
#               'cutthroat',
#               'ironborn',
#               'curse',
#               'released',
#               'fate',
#               'daenerys_stormborn',
#               'smith',
#               'common_enemy',
#               'pyromancer',
#               'wifes',
#               'commoner',
#               'custom',
#               'whether',
#               'eldest_son',
#               'hardly',
#               'strife',
#               'father_smith_warrior_mother',
#               'baby_boy',
#               'fancy',
#               'stubborn',
#               'choosing',
#               'survival',
#               'primary',
#               'father_never',
#               'niece',
#               'currently',
#               'yes_father',
#               'fought_together',
#               'orson',
#               'faith_militant',
#               'hardhome',
#               'faithful',
#               'firstborn_son',
#               'mad_kings_daughter'],
#              93: ['much'],
#              332: ['starting',
#               'expecting',
#               'missing',
#               'eating',
#               'hunting',
#               'looking',
#               'hurting',
#               'meeting',
#               'counting',
#               'jousting',
# ...
#              294: ['anyway',
#               'go_away',
#               'far_away',
#               'run_away',
#               'ran_away',
#               'gave_me_away',
#               'got_away'],
#              562: ['watch', 'watched', 'watches'],
#              259: ['work', 'works'],
#              260: ['does'],
#              481: ['ive_got', 'youve_got', 'theyve', 'weve_got', 'theyve_got'],
#              607: ['needle',
#               'needs',
#               'need_a_new',
#               'need_to_get',
#               'need_help',
#               'need_to_make',
#               'need_someone',
#               'need_to_speak',
#               'need_to_find',
#               'need_to_know',
#               'need_to_keep',
#               'need_to_go',
#               'need_your_help'],
#              261: ['came'],
#              469: ['robert_baratheon',
#               'hey',
#               'baratheons',
#               'baratheon',
#               'stannis_baratheon',
#               'joffrey_baratheon',
#               'renly_baratheon'],
#              534: ['youve_made',
#               'ive_seen',
#               'youve_seen',
#               'ive_done',
#               'youve_done',
#               'ever_done',
#               'ever_seen',
#               'ive_never_seen',
#               'youve_come',
#               'youve_ever_seen',
#               'ive_ever_seen',
#               'youve_ever',
#               'you’ve_seen',
#               'i’ve_seen'],
#              262: ['must'],
#              263: ['hard'],
#              614: ['manned',
#               'chained',
#               'trained',
#               'experienced',
#               'named',
#               'received',
#               'seemed',
#               'seized',
#               'spoke',
#               'arrived',
#               'planned',
#               'owned',
#               'sealed',
#               'spoken',
#               'drowned',
#               'joined',
#               'ruined',
#               'played',
#               'wasted',
#               'combined',
#               'signed',
#               'pardoned'],
#              350: ['sides', 'decides', 'decide', 'decided'],
#              479: ['marry', 'carry', 'arry'],
#              344: ['chance', 'lance', 'lancel', 'dance', 'mance'],
#              264: ['few'],
#              515: ['chances', 'alliances', 'alliance'],
#              557: ['tits', 'shits', 'sits', 'pits', 'wits', 'hits'],
#              357: ['could',
#               'could_tell',
#               'could_say',
#               'could_use',
#               'could_see',
#               'could_make',
#               'could_help',
#               'could_get',
#               'could_find',
#               'could_take',
#               'couldve'],
#              266: ['face'],
#              267: ['hit'],
#              269: ['wed'],
#              386: ['knife',
#               'twice',
#               'notice',
#               'justice',
#               'practice',
#               'voice',
#               'slice',
#               'nice',
#               'price',
#               'slit',
#               'ice'],
#              270: ['shes'],
#              353: ['legs', 'gut', 'finds', 'guts', 'puts', 'pots'],
#              501: ['start', 'started', 'starts'],
#              339: ['ill_kill',
#               'ill_get',
#               'ill_try',
#               'ill_go',
#               'ill_tell',
#               'ill_take',
#               'l_want',
#               'ill_leave'],
#              598: ['million',
#               'champion',
#               'proof',
#               'companion',
#               'person',
#               'mission',
#               'reward',
#               'permission',
#               'opinion',
#               'personal',
#               'discussion',
#               'plan',
#               'passion',
#               'religion',
#               'onion',
#               'decision',
#               'profession',
#               'provisions',
#               'complication'],
#              422: ['threat',
#               'eaten',
#               'threatening',
#               'threaten',
#               'threats',
#               'threatened'],
#              271: ['sea'],
#              489: ['ships',
#               'many_times',
#               'many_ships',
#               'many_men',
#               'many_enemies'],
#              273: ['cross', 'crossing', 'across', 'crossbow'],
#              654: ['throw',
#               'thrown',
#               'threw',
#               'throat',
#               'throats',
#               'pulls',
#               'throws'],
#              274: ['sit'],
#              275: ['fed'],
#              625: ['rapers', 'raped', 'rat', 'rape', 'raper'],
#              568: ['choose', 'chose', 'nose', 'lose', 'loose', 'rose'],
#              276: ['id'],
#              277: ['born'],
#              419: ['peasant', 'unpleasant', 'pleasant', 'peasants', 'giant'],
#              567: ['part', 'smart', 'art', 'apart'],
#              376: ['books', 'book', 'cook'],
#              647: ['monsters',
#               'hers',
#               'lords',
#               'masters',
#               'matters',
#               'letters',
#               'terms',
#               'crasters',
#               'quarters',
#               'invaders',
#               'oysters'],
#              279: ['wine'],
#              388: ['belly',
#               'easily',
#               'finally',
#               'sally',
#               'silly',
#               'tully',
#               'rally',
#               'gilly',
#               'olly'],
#              587: ['steward',
#               'stern',
#               'steps',
#               'steal',
#               'stead',
#               'step',
#               'stew'],
#              555: ['require', 'squire', 'desires', 'requires', 'squires'],
#              572: ['ill_make',
#               'dont_make',
#               'wont_let',
#               'wont_get',
#               'wont_take',
#               'must_make',
#               'cant_make',
#               'wont_make'],
#              280: ['hes'],
#              281: ['follows', 'follow', 'followed', 'following'],
#              560: ['sky',
#               'fly',
#               'flesh',
#               'group',
#               'wagon',
#               'flame',
#               'flag',
#               'flames',
#               'rocks'],
#              282: ['wife'],
#              283: ['between'],
#              545: ['reason',
#               'treason',
#               'reasons',
#               'tree',
#               'treat',
#               'treasonous',
#               'reasonable'],
#              284: ['loyalty', 'loyal'],
#              286: ['gave'],
#              287: ['try'],
#              474: ['comes', 'become', 'becomes'],
#              505: ['large', 'bigger', 'larger'],
#              359: ['prayed', 'betray', 'betrayed'],
#              289: ['enemies', 'enemy', 'armies'],
#              433: ['bitch',
#               'butcher',
#               'catch',
#               'ass',
#               'hatch',
#               'eastwatch',
#               'pitch',
#               'match',
#               'kitchens',
#               'fetch',
#               'witch',
#               'kitchen'],
#              506: ['hasnt', 'ham', 'ha'],
#              547: ['ripped',
#               'chopped',
#               'stopped',
#               'wrapped',
#               'stripped',
#               'shipped',
#               'stepped',
#               'slipped',
#               'dropped',
#               'trapped',
#               'whipped'],
#              292: ['speaks', 'speak'],
#              295: ['ill'],
#              581: ['bring',
#               'bring_him_back',
#               'coming_back',
#               'bring_back',
#               'brings'],
#              476: ['joffrey',
#               'joffreys',
#               'frey',
#               'king_joffrey',
#               'freys',
#               'king_joffreys',
#               'even_joffrey',
#               'king_stannis'],
#              298: ['bit'],
#              380: ['happened', 'happen', 'happens', 'happening'],
#              299: ['set'],
#              435: ['attacked', 'attack', 'attacks', 'attacking'],
#              430: ['river', 'riverrun', 'westerlands', 'lands', 'riverlands'],
#              300: ['asleep', 'deep', 'sleep', 'weep'],
#              301: ['streets', 'street'],
#              302: ['wasnt'],
#              634: ['s',
#               'hodor',
#               'hodor_hodor',
#               'hodor_hodor_hodor',
#               'hodor_hodor_hodor_hodor',
#               'hold_the_door',
#               'hold_the_door_hold_the_door'],
#              448: ['protecting',
#               'protect',
#               'protection',
#               'protected',
#               'protector',
#               'protect_us'],
#              303: ['ing'],
#              393: ['finger', 'rangers', 'fingers'],
#              527: ['renly', 'himself', 'renlys'],
#              307: ['ive'],
#              361: ['winter', 'wind', 'winters'],
#              308: ['may'],
#              436: ['cannot',
#               'cannot_give',
#               'i’ll_give',
#               'ill_give',
#               'wont_give',
#               'cannot_let'],
#              462: ['20000', '2000', '10000', '200', '100', '1000', '8000'],
#              309: ['gold'],
#              310: ['spend', 'spent'],
#              583: ['wise', 'raise', 'rise', 'praise'],
#              311: ['fear'],
#              450: ['nearly', 'tarly', 'clean', 'early', 'clear', 'clearly'],
#              312: ['rebel', 'rebellion', 'rebelled', 'rebels'],
#              552: ['allow',
#               'slow',
#               'low',
#               'blow',
#               'swallow',
#               'yellow',
#               'fellow'],
#              609: ['consider',
#               'refuse',
#               'choices',
#               'advantage',
#               'armory',
#               'fact',
#               'coat',
#               'continue',
#               'risk',
#               'pact',
#               'confuse',
#               'contents',
#               'wealth',
#               'control',
#               'continues',
#               'contract',
#               'destiny'],
#              314: ['command', 'commander', 'commanded', 'commands'],
#              315: ['big'],
#              317: ['save'],
#              318: ['food'],
#              518: ['tells', 'cells', 'martell', 'martells', 'bells'],
#              635: ['rather',
#               'gather',
#               'bother',
#               'further',
#               'fewer',
#               'farther',
#               'weather'],
#              319: ['makes'],
#              320: ['dont'],
#              321: ['youve'],
#              322: ['mine'],
#              323: ['hate'],
#              324: ['side'],
#              325: ['either', 'neither'],
#              326: ['hated'],
#              327: ['ones'],
#              328: ['castles', 'castle'],
#              524: ['cities',
#               'tries',
#               'dies',
#               'lies',
#               'spies',
#               'allies',
#               'flies',
#               'bodies'],
#              548: ['climb', 'climbed', 'onto', 'rope', 'climbs', 'cliff'],
#              330: ['city'],
#              487: ['knowledge', 'edge', 'pledge', 'sledge'],
#              333: ['grew'],
#              334: ['turn', 'turns', 'turned'],
#              336: ['shed'],
#              408: ['place', 'placed', 'places'],
#              517: ['hadnt',
#               'cunt',
#               'couldnt',
#               'wouldnt',
#               'wouldnt_let',
#               'wouldnt_know',
#               'wouldnt_mind',
#               'couldnt_keep',
#               'couldnt_bear',
#               'wouldnt_you_say'],
#              400: ['dont_imagine', 'imagine', 'imagined'],
#              342: ['late'],
#              343: ['cerseis', 'cersei', 'joffrey_cersei', 'queen_cersei'],
#              366: ['dangerous',
#               'famous',
#               'curious',
#               'vicious',
#               'generous',
#               'serious',
#               'obvious',
#               'glorious',
#               'tedious',
#               'precious',
#               'suspicious'],
#              470: ['heart', 'hearts', 'hears'],
#              345: ['arrow', 'row', 'arrows', 'sparrow'],
#              475: ['strong', 'longer', 'stronger', 'strongest'],
#              347: ['hed'],
#              348: ['means'],
#              637: ['eats', 'cats', 'lts', 'rats', 'boats', 'twats'],
#              349: ['head'],
#              459: ['number', 'numbers', 'umbers'],
#              458: ['given',
#               'provided',
#               'provide',
#               'proved',
#               'prove',
#               'proven'],
#              352: ['walk', 'walks'],
#              558: ['ate', 'gates', 'gate'],
#              535: ['taste',
#               'red_keep',
#               'restore',
#               'waste',
#               'red_god',
#               'red_waste'],
#              354: ['half'],
#              603: ['cold',
#               'holds',
#               'hold',
#               'bold',
#               'sail',
#               'holdfast',
#               'grow_old',
#               'uphold',
#               'karhold'],
#              360: ['baby'],
#              362: ['days'],
#              406: ['eventually',
#               'usually',
#               'actually',
#               'act',
#               'actual',
#               'ally'],
#              363: ['arent'],
#              364: ['wrong'],
#              544: ['westeros', 'lords_of_westeros', 'west', 'westerosi'],
#              652: ['greyjoy',
#               'balon_greyjoy',
#               'greyjoys',
#               'lord_greyjoy',
#               'theon_greyjoy',
#               'euron_greyjoy',
#               'euron'],
#              455: ['disappointment',
#               'point',
#               'disappoint',
#               'disappeared',
#               'disappointed',
#               'points',
#               'disappear'],
#              477: ['defend', 'defense', 'defenses'],
#              368: ['marching', 'searching', 'march'],
#              370: ['open'],
#              371: ['possible', 'impossible', 'possibly'],
#              372: ['build', 'built', 'builders'],
#              392: ['names', 'games', 'game'],
#              373: ['got'],
#              375: ['ser'],
#              657: ['guards',
#               'guard',
#               'yards',
#               'boat',
#               'board',
#               'regards',
#               'two_guards'],
#              578: ['coins',
#               'ruin',
#               'sins',
#               'remains',
#               'runs',
#               'twins',
#               'begins',
#               'wins',
#               'tywins',
#               'ruins'],
#              541: ['jons', 'tyrion', 'tyrions'],
#              532: ['claim', 'claims', 'claimed'],
#              381: ['gendry', 'davos', 'gendrys'],
#              528: ['four', 'pour', 'sour'],
#              387: ['won'],
#              564: ['cock',
#               'lock',
#               'luck',
#               'knock',
#               'flock',
#               'rock',
#               'nock',
#               'mock'],
#              473: ['lead', 'heads', 'leaves', 'leads'],
#              399: ['concerned', 'concerns', 'concerning', 'concern'],
#              394: ['red'],
#              397: ['bow'],
#              522: ['loras',
#               'tyrell',
#               'loras_tyrell',
#               'tyrells',
#               'ser_loras_tyrell',
#               'margaery',
#               'house_tyrell',
#               'lord_tyrell'],
#              403: ['arms', 'arm'],
#              577: ['freedom', 'free', 'freed'],
#              410: ['idea', 'ideas'],
#              411: ['safely', 'safety', 'safe', 'safer'],
#              412: ['prisoner', 'prisoners', 'prison'],
#              579: ['grant', 'grand', 'grandson', 'grandsons'],
#              421: ['looks'],
#              424: ['charges', 'charge', 'charged'],
#              656: ['earth', 'qarth', 'tarth', 'naarth'],
#              445: ['conqueror',
#               'conquerors',
#               'conquering',
#               'conquered',
#               'conquer'],
#              447: ['led'],
#              449: ['heir'],
#              457: ['l'],
#              561: ['smile', 'smiles', 'miles'],
#              490: ['god'],
#              636: ['lord_bolton',
#               'boltons',
#               'roose_bolton',
#               'ramsay',
#               'bolton',
#               'ramsay_bolton']})

# %% [markdown]
# That's pretty neat! We get some clusters, and we can see how the words are put in the same groups.
#
# Is there anything kind of annoying? Too many one-word clusters? Clusters with too many words? Let's remove them to find some more insightful results.

# %%
def get_insightful_clusters(clusters, min_len=3, max_len=25):
    insightful_clusters = {}
    for idx, words in clusters.items():
        if len(words) < min_len or len(words) > max_len:
            continue
        insightful_clusters[idx] = words
    return insightful_clusters
        

get_insightful_clusters(clusters)
# Out:
# {200: ['what',
#   'that’s',
#   'whatever',
#   'what’re',
#   'what’s',
#   'whats',
#   'what’s_wrong',
#   'what’s_left'],
#  297: ['expect',
#   'meant',
#   'doubt',
#   'never_forget',
#   'never_knew',
#   'never_told',
#   'never_meant',
#   'never_asked',
#   'never_know',
#   'never_said',
#   'never_talked',
#   'never_leave',
#   'never_wanted',
#   'ever_met',
#   'never_thought',
#   'never_trust',
#   'never_liked',
#   'never_get',
#   'never_let'],
#  641: ['they’re',
#   'they',
#   'they’ve',
#   'theyre',
#   'theyd',
#   'theyll',
#   'theirs',
#   'they’ll',
#   'they’re_gonna',
#   'they’d'],
#  593: ['another',
#   'another_day',
#   'another_man',
#   'one_another',
#   'another_way',
#   'one_way_or_another'],
#  659: ['and',
#   'rickon',
#   'bran_and_rickon',
#   'randyll',
#   'dickon',
#   'daenerys_and_drogon',
#   'randyll_and_dickon',
#   'sandor'],
#  468: ['you',
#   'youre',
#   'youre_leaving',
#   'youre_not_supposed',
#   'youre_safe',
#   'youre_a_liar',
#   'lucky',
#   'youre_right',
#   'youre_heading',
#   'eh',
#   'youre_good',
#   'youre_far',
#   'youre_mine',
#   'youre_lying',
#   'youre_lucky',
#   'youre_gonna',
#   'youre_still',
#   'youre_a_woman',
#   'youre_coming',
#   'youre_supposed',
#   'maybe_youre'],
#  604: ['know',
#   'known',
#   'doesnt_know',
#   'must_know',
#   'l_know',
#   'ever_known',
#   'know_i_know',
#   'didn’t_know'],
#  205: ['wildlings', 'wildling', 'wildling_army'],
#  628: ['this',
#   'outsider',
#   'ale',
#   'front',
#   'seven_hells',
#   'hounds',
#   'iron_islands',
#   'wisdom',
#   'darkest',
#   'braavosi',
#   'one_true_god',
#   'coin',
#   'iron',
#   'priest',
#   'braavos',
#   'chickens',
#   'iron_bank',
#   'iron_bank_of_braavos',
#   'queen_daenerys',
#   'consequences',
#   'queen_of_thorns',
#   'iron_fleet'],
#  441: ['close', 'closed', 'closest', 'closer'],
#  496: ['man_would', 'never_would', 'l_could', 'else_would', 'one_would'],
#  431: ['were', 'aren’t', 'werent', 'weren’t'],
#  460: ['don’t_think',
#   'think',
#   'dont_think',
#   'dont_you_think',
#   'didnt_think',
#   'could_think',
#   'l_think',
#   'really_think',
#   'youd_think',
#   'didn’t_think'],
#  425: ['he’ll', 'we’ll', 'shell', 'she’ll'],
#  576: ['get_back',
#   'takes',
#   'came_back',
#   'come_back',
#   'go_back',
#   'take_us',
#   'never_come_back',
#   'take_back',
#   'fall_back',
#   'take_me_back',
#   'turns_back'],
#  358: ['horse',
#   'horses',
#   'horseback',
#   'neck',
#   'weeks',
#   'floor',
#   'way_back',
#   'backs',
#   'stuck',
#   'suck'],
#  549: ['dead_men',
#   'brave_men',
#   '500_men',
#   'old_men',
#   '100_men',
#   'two_men',
#   'need_men',
#   '20_men',
#   'wounded_men',
#   'free_men',
#   '1000_men'],
#  141: ['have', 'haven’t', 'havent'],
#  248: ['moved', 'loved', 'lived', 'beloved'],
#  599: ['here',
#   'where',
#   'where’s',
#   'somewhere',
#   'still',
#   'going_anywhere',
#   'anywhere',
#   'wherever',
#   'somewhere_else',
#   'wheres',
#   'somewhere_safe',
#   'nowhere',
#   'elsewhere'],
#  337: ['father’s',
#   'father',
#   'uncle',
#   'father_knew',
#   'fathers',
#   'father_used',
#   'father_would',
#   'father_gave',
#   'father_told',
#   'father_died'],
#  355: ['watching',
#   'making',
#   'talking',
#   'taking',
#   'fucking',
#   'thinking',
#   'speaking',
#   'coming',
#   'joking',
#   'drinking',
#   'lurking',
#   'walking',
#   'having',
#   'asking',
#   'stealing',
#   'i’m_talking',
#   'stinking',
#   'moving',
#   'leaving',
#   'working',
#   'helping',
#   'knocking',
#   'night_king'],
#  483: ['mother',
#   'brother',
#   'mothers',
#   'brothers',
#   'brotherhood',
#   'brothels',
#   'brothel',
#   'older_brother',
#   'brother_jaime',
#   'brother’s',
#   'brothers_and_sisters',
#   'brother_and_sister',
#   'mother_and_father',
#   'mother_and_brother',
#   'baby_brother',
#   'grandmother',
#   'mother’s'],
#  617: ['always',
#   'happy',
#   'always_wanted',
#   'glad',
#   'always_thought',
#   'always_loved',
#   'always_knew'],
#  439: ['well_done',
#   'well_talk',
#   'well_well',
#   'well_go',
#   'wet',
#   'well_get',
#   'well_make',
#   'well_fought',
#   'well_take',
#   'well_hes',
#   'well_meet',
#   'well_find',
#   'well_need'],
#  649: ['that',
#   'something',
#   'sometimes',
#   'there’s_nothing',
#   'something_else',
#   'theres_something',
#   'something_like',
#   'something_important',
#   'here’s',
#   'there’s_something'],
#  646: ['you’ve',
#   'you’ve_got',
#   'you’d',
#   'hes_always',
#   'youve_always',
#   'ive_always',
#   'you’ve_done',
#   'you’ve_always'],
#  383: ['ten', 'forgot', 'forgotten', 'gotten'],
#  633: ['bran', 'brandon', 'brans', 't', 'ran', 'ya', 'bran_bran', 'bran_wake'],
#  46: ['faster', 'master', 'monster', 'craster'],
#  389: ['rode',
#   'road',
#   'room',
#   'rooms',
#   'rot',
#   'ros',
#   'roots',
#   'boots',
#   'lots',
#   'root',
#   'rots',
#   'roof',
#   'roads',
#   'sets'],
#  404: ['hills', 'skulls', 'shame', 'skills', 'kills', 'ls', 'skill'],
#  398: ['captured',
#   'five',
#   'capital',
#   'receive',
#   'capture',
#   'captive',
#   'arrive',
#   'captain',
#   'lve',
#   'carve',
#   'survive',
#   'captains',
#   'drive'],
#  253: ['night’s_watch',
#   'men_of_the_nights_watch',
#   'nights_watch',
#   'man_of_the_nights_watch',
#   'city_watch',
#   'nights',
#   'knights_of_the_vale',
#   'lord_commander_of_the_nights_watch',
#   'warden_of_the_north'],
#  409: ['law',
#   'join',
#   'play',
#   'demand',
#   'owe',
#   'deliver',
#   'delay',
#   'lay',
#   'slay',
#   'repay',
#   'demands'],
#  543: ['lady',
#   'lady_stark',
#   'welcome',
#   'ladys',
#   'sansa_come',
#   'lady_catelyn',
#   'pleasure',
#   'lady_sansa',
#   'lady_my_lady',
#   'milady',
#   'lady_brienne',
#   'lady_melisandre',
#   'lady_talisa',
#   'lady_margaery',
#   'welcome_home',
#   'lady_olenna',
#   'lady_crane'],
#  385: ['young', 'best', 'youngest', 'biggest', 'younger'],
#  582: ['things',
#   'terrible_thing',
#   'horrible',
#   'terrible',
#   'ways',
#   'lots_of_things',
#   'terribly',
#   'many_things',
#   'terrible_things',
#   'see_things'],
#  57: ['white_walkers',
#   'saw_the_white_walkers',
#   'walkers',
#   'beyond_the_wall',
#   'north_of_the_wall',
#   'south_of_the_wall',
#   'white',
#   'climb_the_wall',
#   'killed_a_white_walker',
#   'white_walker'],
#  632: ['oath', 'filth', 'death', 'birth', 'bath', 'path', 'naath'],
#  211: ['should', 'didn’t', 'wouldn’t', 'shouldn’t', 'shouldnt', 'couldn’t'],
#  440: ['warned', 'earned', 'learn', 'learned'],
#  539: ['family',
#   'families',
#   'family_name',
#   'familiar',
#   'familys',
#   'family_home'],
#  367: ['coward', 'cowards', 'toward', 'stewards', 'towards'],
#  87: ['sorry', 'i’m_sorry', 'worry', 'i’m_sure', 'im_sorry'],
#  65: ['king_of_the_andals_and_the_first_men',
#   'lord_of_the_seven_kingdoms_and_protector',
#   'hand_of_the_king',
#   'wife_of_the_great_khal',
#   'protector_of_the_realm',
#   'milk_of_the_poppy',
#   'jorah_the_andal',
#   'lord_commander_of_the_kingsguard',
#   'sight_of_gods_and_men',
#   'children_of_the_forest',
#   'light_of_the_seven',
#   'fist_of_the_first_men',
#   'house_of_the_undying',
#   'edge_of_the_world',
#   'men_lord_of_the_seven',
#   'kingdoms_and_protector_of_the_realm',
#   'half_the_men',
#   'tower_of_the_hand',
#   'army_of_the_dead',
#   'sand',
#   'lord_of_the_vale',
#   'sons_of_the_harpy'],
#  508: ['realm', 'real', 'realize', 'really', 'realized', 'read', 'real_war'],
#  335: ['house_stark',
#   'ned_stark’s',
#   'ned_stark',
#   'ned_starks_bastard',
#   'ned_starks_son',
#   'brandon_stark',
#   'catelyn_starks',
#   'arya_stark',
#   'robb_stark',
#   'eddard_stark',
#   'robb_starks',
#   'ned_starks',
#   'catelyn_stark',
#   'karstarks',
#   'sansa_stark',
#   'karstark'],
#  655: ['lord_of_winterfell_and_warden_of_the_north',
#   'winterfell',
#   'ready',
#   'lord_of_winterfell',
#   'cell',
#   'take_winterfell',
#   'bastard_of_winterfell',
#   'come_to_winterfell',
#   'lady_of_winterfell'],
#  482: ['understand',
#   'don’t_understand',
#   'dont_know',
#   'dont_believe',
#   'understands',
#   'understood',
#   'dont_understand'],
#  602: ['said', 'paid', 'maid', 'raid', 'aid', 'laid'],
#  418: ['madman',
#   'fool',
#   'dwarf',
#   'young_man',
#   'halfman',
#   'clever_man',
#   'last_man',
#   'dwarf_man',
#   'dead_man',
#   'old_man',
#   'one_man',
#   'human',
#   'kill_a_man',
#   'rich_man',
#   'flayed_man'],
#  622: ['sees',
#   'approaching',
#   'baelish',
#   'approach',
#   'aryas',
#   'reaches',
#   'approaches'],
#  341: ['mountain',
#   'certain',
#   'pain',
#   'rain',
#   'maintain',
#   'mountains',
#   'remain',
#   'main',
#   'grain'],
#  492: ['lion',
#   'attention',
#   'reputation',
#   'mention',
#   'position',
#   'invitation',
#   'action',
#   'conversation',
#   'ambition',
#   'direction',
#   'situation',
#   'notion',
#   'corruption',
#   'imagination',
#   'affliction',
#   'devotion',
#   'distinction',
#   'tradition',
#   'option',
#   'proposition'],
#  531: ['woods', 'wooden', 'wood'],
#  513: ['beast',
#   'fast',
#   'feast',
#   'least',
#   'feasts',
#   'rast',
#   'past',
#   'cost',
#   'breast',
#   'east',
#   'coast',
#   'cast',
#   'beasts',
#   'toast'],
#  584: ['better',
#   'letter',
#   'hunter',
#   'im_better',
#   'prettier',
#   'harder',
#   'matter',
#   'feel_better',
#   'even_better',
#   'youd_better',
#   'much_better',
#   'far_better',
#   'better_place'],
#  499: ['without',
#   'with',
#   'question',
#   'questions',
#   'within',
#   'request',
#   'without_question',
#   'man_without',
#   'men_without'],
#  471: ['please',
#   'please_please',
#   'please_dont',
#   'release',
#   'cry',
#   'angry',
#   'ease',
#   'stop_please',
#   'grace_please',
#   'please_stop',
#   'pleased',
#   'khaleesi_please'],
#  454: ['train', 'traitor', 'traitors'],
#  88: ['yourselves', 'yourself', 'themselves', 'ourselves'],
#  247: ['bury', 'burned', 'burnt', 'burn', 'burning', 'burns'],
#  290: ['yours', 'hours', 'ours', 'hour'],
#  551: ['snow',
#   'nothing',
#   'perhaps',
#   'means_nothing',
#   'bend_the_knee',
#   'respect',
#   'nothing_like',
#   'going_to_kill',
#   'jon_snow',
#   'nothing_else',
#   'nothing_to_say',
#   'note',
#   'know_nothing',
#   'know_nothing_jon_snow',
#   'us_jon_snow',
#   'nothing_to_fear',
#   'know_you’re'],
#  503: ['duty',
#   'rightful_king',
#   'new_king',
#   'mad_king',
#   'true_king',
#   'future_king',
#   'future'],
#  144: ['show',
#   'show_us',
#   'saw_us',
#   'told_us',
#   'tell_us',
#   'leave_us',
#   'give_us',
#   'shown',
#   'hear_us',
#   'find_us',
#   'shows',
#   'see_us'],
#  571: ['never',
#   'fever',
#   'ill_never',
#   'theyve_never',
#   'ive_never',
#   'youve_never',
#   'would_never',
#   'i’ll_never',
#   'ive_ever',
#   'whenever',
#   'could_never',
#   'theyll_never',
#   'hes_never',
#   'id_never',
#   'i’ve_never'],
#  268: ['anything',
#   'one_thing',
#   'last_thing',
#   'thing',
#   'worst_thing',
#   'first_thing',
#   'everything',
#   'good_thing',
#   'worst',
#   'sort_of_thing',
#   'right_thing'],
#  316: ['seven', 'old_gods', 'gods', 'seven_gods'],
#  580: ['casterly_rock',
#   'battle',
#   'battlements',
#   'castle_black',
#   'battlefield',
#   'battles',
#   'blackwater_bay',
#   'bay',
#   'ser_bronn_of_the_blackwater',
#   'battle_of_blackwater_bay',
#   'blackwater'],
#  405: ['foot', 'shoot', 'shove', 'shot', 'shop'],
#  658: ['drop',
#   'feet',
#   'draw',
#   'dry',
#   'strikes',
#   'drops',
#   'claws',
#   'drawn',
#   'draws'],
#  365: ['water',
#   'later',
#   'wars',
#   'warm',
#   'warmer',
#   'rider',
#   'worse',
#   'enter',
#   'warg'],
#  500: ['afraid',
#   'im_afraid',
#   'im_not_asking',
#   'im_not_sure',
#   'youre_afraid',
#   'lm',
#   'im_not_afraid',
#   'dont_be_afraid',
#   'you’re_afraid',
#   'i’m_afraid'],
#  178: ['we’re', 'we’ve', 'we’d'],
#  590: ['lannisters',
#   'jaime_lannister',
#   'tyrion_lannister',
#   'lannister',
#   'lannisport',
#   'cersei_lannister',
#   'house_lannister',
#   'tywin_lannister',
#   'lannister_men',
#   'ser_jaime_lannister',
#   'lannister_soldiers',
#   'lancel_lannister',
#   'martyn_lannister',
#   'lannister_army'],
#  516: ['jon_arryn',
#   'robb',
#   'arryn',
#   'lord_arryn',
#   'robin',
#   'lady_arryn',
#   'yara',
#   'robin_arryn',
#   'lysa_arryn',
#   'meryn',
#   'oberyn'],
#  594: ['someone',
#   'one_else',
#   'someones',
#   'everyone_else',
#   'anyone_else',
#   'someone_else',
#   'someone_else’s'],
#  428: ['husband', 'sister', 'sweet_sister', 'sisters', 'sister’s'],
#  140: ['years',
#   'nine_years',
#   'year',
#   '17_years',
#   'many_years',
#   'lost',
#   '20_years',
#   'tears',
#   'years_old',
#   'many_years_ago',
#   '300_years',
#   'ears',
#   'wears',
#   '10_years',
#   'centuries',
#   'appears',
#   'spears',
#   '1000_years'],
#  415: ['wonder', 'under', 'kind', 'kinder', 'leader', 'older'],
#  601: ['brought', 'caught', 'fought', 'ought', 'bought', 'taught', 'sought'],
#  146: ['queen',
#   'queen’s',
#   'queens',
#   'queen_regent',
#   'new_queen',
#   'queen_margaery',
#   'queen_mother'],
#  575: ['far_north',
#   'north',
#   'northmen',
#   'ing_in_the_north',
#   'ing_in_the_north_ing_in_the_north',
#   'entire_north',
#   'king_in_the_north',
#   'go_north',
#   'went_north',
#   'rule_the_north'],
#  565: ['there’s',
#   'theres',
#   'theres_only_one',
#   'theres_nothing',
#   'theres_no_need',
#   'therell',
#   'heres',
#   'theres_no_time',
#   'theres_still',
#   'theres_no_one'],
#  514: ['chamber',
#   'tongue',
#   'hot',
#   'cup',
#   'chambers',
#   'chain',
#   'chamber_pot',
#   'chaos'],
#  526: ['night',
#   'tonight',
#   'knight',
#   'long_night',
#   'last_night',
#   'fortnight',
#   'one_boy',
#   'day_and_night',
#   'one_night'],
#  113: ['drinks', 'drink', 'picks'],
#  117: ['eight', 'straight', 'sight', 'weight', 'light', 'height'],
#  521: ['case', 'mind', 'age', 'message', 'cart', 'cage', 'cave', 'carriage'],
#  313: ['southern',
#   'together',
#   'northern',
#   'northerners',
#   'northerner',
#   'southerners',
#   'northern_lords'],
#  597: ['girls',
#   'yes_yes',
#   'loves',
#   'oh_yes',
#   'besides',
#   'notices',
#   'oh_yes_yes',
#   'blue_eyes',
#   'ah_yes',
#   'hopes'],
#  509: ['stab',
#   'starve',
#   'steel',
#   'stag',
#   'stairs',
#   'stags',
#   'stares',
#   'stays'],
#  396: ['right',
#   'it’s_all_right',
#   'right_hand',
#   'rich',
#   'hes_right',
#   'right_all_right',
#   'bright',
#   'mine_by_right',
#   'thats_right',
#   'right_ill',
#   'rightful',
#   'alright',
#   'you’re_right'],
#  586: ['likes',
#   'place_like',
#   'men_like',
#   'looked_like',
#   'sounds_like',
#   'youd_like',
#   'felt_like',
#   'looks_like',
#   'smell',
#   'girls_like',
#   'look_like',
#   'doesnt_like',
#   'id_like',
#   'seems_like',
#   'feel_like',
#   'alike',
#   'smells_like',
#   'sound_like',
#   'i’d_like'],
#  346: ['hair', 'air', 'fair', 'chair', 'pair'],
#  491: ['grow', 'brown', 'town', 'gown', 'grown', 'drown', 'grows'],
#  619: ['people', 'common_people', 'many_people', 'people_wont', 'people_dont'],
#  130: ['promise', 'promised', 'promises'],
#  423: ['move', 'south', 'mouths', 'mouth', 'mount', 'mom'],
#  556: ['shut', 'field', 'held', 'yield', 'ship', 'shield'],
#  645: ['you’ll', 'ill_find', 'i’ll_find', 'you’ll_find', 'you’ll_get'],
#  145: ['soldier', 'sold', 'soldiers'],
#  644: ['surely',
#   'imp',
#   'im_sure',
#   'rare',
#   'probably',
#   'barely',
#   'assure',
#   'written',
#   'sure',
#   'prepare',
#   'pure',
#   'nature',
#   'report',
#   'secure',
#   'proud',
#   'pyre',
#   'problem',
#   'cure',
#   'torture',
#   'problems',
#   'edmure',
#   'figure',
#   'perspective',
#   'procedure',
#   'lure'],
#  461: ['go_find',
#   'fine',
#   'finest',
#   'nine',
#   'line',
#   'fit',
#   'hunt',
#   'final',
#   'dine',
#   'finish',
#   'fine_fine'],
#  384: ['teach', 'breach', 'beach', 'reach'],
#  585: ['remember', 'dont_remember', 'remembered', 'umber', 'member'],
#  592: ['fuck', 'fucks', 'fucker', 'fuckers'],
#  642: ['showed',
#   'allowed',
#   'healed',
#   'called',
#   'failed',
#   'pulled',
#   'fled',
#   'sailed',
#   'saved',
#   'exile',
#   'begged',
#   'worked',
#   'bled',
#   'smiled',
#   'exiled'],
#  554: ['kings_landing',
#   'king’s',
#   'kings',
#   'kingsroad',
#   'godswood',
#   'kingslayer',
#   'kings_hand',
#   'king’s_landing',
#   'kingsguard',
#   'faith',
#   'kingswood',
#   'kin',
#   'king_tommen'],
#  497: ['lord_eddard_stark',
#   'lord_tyrion',
#   'lord_stark',
#   'lord_baelish',
#   'lord_tywin',
#   'lord_snow',
#   'lordship',
#   'lord_commander',
#   'lord_walder',
#   'lord_shes',
#   'lord_hand',
#   'lord_commander_mormont',
#   'lord_stannis',
#   'lord_eddard',
#   'lord_frey',
#   'lord_of_light',
#   'lord_varys',
#   'lord_janos',
#   'lord_karstark',
#   'lord_edmure',
#   'lord_royce'],
#  443: ['worthy', 'unless', 'less', 'wore', 'worth', 'worthless'],
#  413: ['honor', 'pray', 'dishonor', 'honorable_man', 'honorable', 'nor'],
#  612: ['i’m_trying',
#   'theyre_going',
#   'im_going',
#   'youre_going',
#   'im_not_going',
#   'we’re_going',
#   'hes_going',
#   'isnt_going',
#   'i’m_not_going',
#   'i’m_going',
#   'you’re_going',
#   'he’s_going'],
#  191: ['kingdom', 'kingdoms', 'seven_kingdoms'],
#  453: ['while', 'awhile', 'mile'],
#  630: ['stand',
#   'standing',
#   'leave',
#   'stream',
#   'strike',
#   'stannis',
#   'trial',
#   'stands',
#   'stand_a_chance',
#   'stand_and_fight',
#   'stand_trial'],
#  600: ['helped',
#   'help_us',
#   'helps',
#   'saved_us',
#   'lead_us',
#   'helped_us',
#   'led_us'],
#  391: ['iron_throne',
#   'throne',
#   'balerion_the_dread',
#   'sitting_on_the_iron_throne',
#   'claim_to_the_throne',
#   'sit_on_the_iron_throne',
#   'take_the_iron_throne',
#   'burn_the_bodies'],
#  456: ['rule', 'ruler', 'rulers'],
#  157: ['bound',
#   'found',
#   'wound',
#   'around',
#   'hound',
#   'ground',
#   'sound',
#   'round',
#   'surround'],
#  464: ['blood',
#   'bastard',
#   'bloody',
#   'trade',
#   'bastard_son',
#   'bloodshed',
#   'laws',
#   'chains',
#   'blood_of_my_blood',
#   'blood_magic',
#   'skin',
#   'fire_and_blood',
#   'bloody_gate'],
#  429: ['daughter', 'slaughtered', 'daughters', 'slaughter', 'slaughtering'],
#  434: ['manner', 'bannermen', 'banner', 'bannerman', 'banners', 'band'],
#  494: ['meaning',
#   'believe',
#   'living',
#   'saving',
#   'believes',
#   'belief',
#   'believing',
#   'believed'],
#  407: ['door', 'doors', 'doorstep'],
#  553: ['starks',
#   'stark',
#   'host',
#   'stark_boy',
#   'stars',
#   'stark_girl',
#   'stark_men',
#   'stark_boys',
#   'stare'],
#  648: ['don’t',
#   'don’t_want',
#   'don’t_know',
#   'don’t_care',
#   'don’t_let',
#   'don’t_like',
#   'don’t_believe',
#   'don’t_need',
#   'don’t_die'],
#  530: ['first',
#   'first_ranger',
#   'first_light',
#   'first_mate',
#   'first_men',
#   'first_man',
#   'first_place'],
#  414: ['short', 'whores', 'shores', 'shore'],
#  401: ['changes', 'change', 'changed', 'exchange', 'hanged'],
#  570: ['hill',
#   'full',
#   'wolf',
#   'till',
#   'fill',
#   'fell',
#   'lll',
#   'dull',
#   'skull',
#   'pull',
#   'roll',
#   'orell',
#   'quill',
#   'doll'],
#  620: ['sun',
#   'swear',
#   'wear',
#   'bear',
#   'spear',
#   'ear',
#   'appear',
#   'near',
#   'tear',
#   'sunspear'],
#  510: ['dreams', 'dreamed', 'dream', 'dreamt'],
#  559: ['every_night',
#   'every_morning',
#   'every_day',
#   'everyone',
#   'every',
#   'every_time',
#   'every_one',
#   'everywhere',
#   'every_man',
#   'ever_since',
#   'every_right',
#   'every_fucking',
#   'everybody'],
#  550: ['targaryens',
#   'house_targaryen',
#   'daenerys_targaryen',
#   'rhaegar_targaryen',
#   'targaryen',
#   'aerys_targaryen',
#   'aegons',
#   'targaryen_girl',
#   'aegon_targaryen',
#   'aegon'],
#  437: ['daenerys',
#   'dragon',
#   'fire',
#   'dragons',
#   'drag',
#   'fleet',
#   'last_dragon',
#   'dragonglass',
#   'dragon_fire',
#   'dragonstone',
#   'mother_of_dragons',
#   'three_dragons',
#   'unsullied',
#   'wagons',
#   'dragon_queen'],
#  168: ['bride', 'ride', 'pride'],
#  638: ['isn’t',
#   'wasn’t',
#   'doesnt_mean',
#   'doesnt',
#   'doesnt_make',
#   'doesn’t',
#   'make_us',
#   'doesnt_matter',
#   'doesnt_get',
#   'won’t_make',
#   'doesn’t_matter',
#   'doesn’t_make',
#   'doesn’t_mean'],
#  480: ['asked',
#   'looked',
#   'shoved',
#   'dragged',
#   'knocked',
#   'fucked',
#   'naked',
#   'liked',
#   'pushed',
#   'kicked',
#   'walked',
#   'mocked',
#   'wicked',
#   'shocked',
#   'locked'],
#  463: ['knows', 'snows', 'everyone_knows', 'one_knows'],
#  382: ['forget', 'forged', 'forge', 'form'],
#  340: ['friends',
#   'true_friend',
#   'old_friend',
#   'friend',
#   'truly',
#   'beyond',
#   'new_friend',
#   'friendship',
#   'truce'],
#  502: ['woman’s', 'woman', 'mans', 'womans'],
#  390: ['wake',
#   'stake',
#   'shake',
#   'wild',
#   'buy',
#   'joke',
#   'snake',
#   'mistake',
#   'woke',
#   'i’ll_take'],
#  377: ['history', 'stories', 'histories'],
#  272: ['dothraki',
#   'beat',
#   'horde',
#   'dothraki_horde',
#   'vaes_dothrak',
#   'flee',
#   'dothraki_screamer'],
#  173: ['defeated', 'defeat', 'treated', 'seated'],
#  608: ['course',
#   'country',
#   'bone',
#   'couple',
#   'false',
#   'court',
#   'counsel',
#   'count',
#   'countless'],
#  176: ['killers', 'killed', 'killer'],
#  616: ['dear', 'deal', 'dealt'],
#  224: ['trust', 'trusts', 'truth', 'trustworthy', 'trusted'],
#  472: ['married', 'tried', 'lied', 'cried', 'buried', 'worried'],
#  183: ['lack', 'black', 'pack', 'sack'],
#  426: ['gives', 'lives', 'wives'],
#  573: ['want_us',
#   'want_to_know',
#   'want_to_help',
#   'want_to_see',
#   'want_to_fuck',
#   'want_to_hear',
#   'want_to_say',
#   'want_to_live',
#   'want_to_leave',
#   'want_you_to_know',
#   'wants_to_see',
#   'want_to_go',
#   'want_to_fight'],
#  596: ['would_let',
#   'would_you_say',
#   'would_kill',
#   'would_like',
#   'would_happen',
#   'would_die',
#   'would_have_killed',
#   'would_you_like',
#   'would_seem',
#   'would_see',
#   'would_say',
#   'would_have_given',
#   'would_have_done',
#   'would_make',
#   'would_pay',
#   'would_take'],
#  442: ['whole', 'whose', 'whos', 'whom', 'whoa', 'whoa_whoa', 'who’s'],
#  538: ['prince',
#   'princess',
#   'princes',
#   'theon',
#   'prince_theon',
#   'prince_doran',
#   'prince_oberyn',
#   'prince_trystane'],
#  427: ['ever_lived',
#   'heard',
#   'heat',
#   'ever_saw',
#   'i’ve_heard',
#   'ive_heard',
#   'ever_heard',
#   'havent_heard',
#   'beard',
#   'ever_tell',
#   'ive_never_heard'],
#  285: ['handsome', 'hand', 'hands', 'handle', 'hang'],
#  606: ['second',
#   'fresh',
#   'master_of_coin',
#   'otherwise',
#   'wiser',
#   'livestock',
#   'dorne',
#   'dornish',
#   'supplies',
#   'fastest',
#   'astapor',
#   'master_kraznys',
#   'shireen',
#   'grey_worm',
#   'yunkai',
#   'wise_masters_of_yunkai',
#   'wise_masters',
#   'second_sons',
#   'slavers_bay',
#   'slaver’s_bay'],
#  640: ['powerful_man', 'power', 'powers', 'powerless', 'powerful'],
#  488: ['didn’t_want',
#   'didnt_see',
#   'didnt',
#   'didnt_say',
#   'didnt_kill',
#   'didnt_know',
#   'didnt_want',
#   'didnt_mean',
#   'didnt_ask',
#   'didnt_come',
#   'didnt_like',
#   'didnt_love',
#   'didnt_need',
#   'didnt_believe',
#   'didnt_listen'],
#  416: ['thought', 'though', 'thoughts', 'thought_youd', 'thought_you’d'],
#  291: ['might', 'mighty', 'might_find', 'might_even'],
#  278: ['inside',
#   'behind',
#   'alongside',
#   'alone',
#   'outside',
#   'aside',
#   'along',
#   'beside'],
#  589: ['preparing',
#   'during',
#   'hearing',
#   'boring',
#   'staring',
#   'wearing',
#   'ring',
#   'bearing'],
#  265: ['greatest',
#   'great_honor',
#   'great_big',
#   'great_victory',
#   'great',
#   'great_deal',
#   'great_warrior',
#   'greater',
#   'greatest_city_that_ever',
#   'great_hall',
#   'great_beauty',
#   'great_war',
#   'great_house',
#   'great_games'],
#  629: ['advice', 'advising', 'advise', 'chosen', 'advisor', 'advisors'],
#  417: ['armor',
#   'bastards',
#   'swords',
#   'beds',
#   'words',
#   'last_words',
#   'swordsman',
#   'birds',
#   'two_swords',
#   'pirates',
#   'sellsword',
#   'sellswords',
#   'odds',
#   'archers',
#   'records'],
#  542: ['trap', 'traveled', 'brave', 'travel', 'grave', 'travels', 'traveling'],
#  465: ['tough',
#   'rough',
#   'soon_enough',
#   'enough',
#   'thats_enough',
#   'long_enough',
#   'old_enough',
#   'far_enough',
#   'stupid_enough',
#   'fast_enough',
#   'strong_enough',
#   'it’s_not_enough'],
#  546: ['ranger', 'danger', 'strange', 'strangers', 'stranger'],
#  623: ['madness',
#   'vows',
#   'poor',
#   'business',
#   'kindness',
#   'darkness',
#   'hows',
#   'sickness',
#   'wilderness',
#   'hood',
#   'guess',
#   'hole',
#   'holy',
#   'weakness',
#   'priestess',
#   'kiss',
#   'mess',
#   'happiness',
#   'witness',
#   'holiness'],
#  621: ['talk', 'tall', 'talks', 'talked', 'talker'],
#  484: ['next',
#   'wings',
#   'small',
#   'seven_blessings',
#   'council',
#   'small_council_chamber',
#   'table',
#   'meetings',
#   'small_council',
#   'small_council_meetings'],
#  512: ['first_time',
#   'last_one',
#   'next_time',
#   'one_time',
#   'last_time',
#   'much_time',
#   'lasts',
#   'last_time_i_saw',
#   'last_name',
#   'whole_time'],
#  304: ['growing',
#   'swinging',
#   'swing',
#   'howling',
#   'singing',
#   'bringing',
#   'wing',
#   'hanging',
#   'facing',
#   'turning'],
#  374: ['hidden',
#   'highborn',
#   'highly',
#   'high_lords',
#   'high_lord',
#   'high',
#   'hide',
#   'high_septon',
#   'highgarden',
#   'mostly',
#   'kindly',
#   'high_sparrow'],
#  467: ['offer',
#   'comfortable',
#   'comfort',
#   'entirely',
#   'escort',
#   'destroy',
#   'sort',
#   'entire',
#   'behalf',
#   'former',
#   'mourn',
#   'commit',
#   'attend',
#   'support',
#   'effort',
#   'port',
#   'unfortunate',
#   'desire',
#   'moat_cailin',
#   'fortress',
#   'bend'],
#  379: ['title',
#   'force',
#   'tywin',
#   'peace',
#   'inheritance',
#   'house_tully',
#   'importance',
#   'renounce',
#   'allegiance',
#   'refuses',
#   'vengeance',
#   'influence',
#   'house_frey',
#   'best_chance',
#   'distance'],
#  378: ['fight', 'cant_fight', 'dont_fight', 'can’t_fight'],
#  218: ['belong', 'belongs', 'below', 'belonged'],
#  486: ['listen', 'listening', 'listened', 'list'],
#  236: ['stops', 'stop_stop', 'stop', 'top'],
#  643: ['maester_luwin',
#   'maester',
#   'grand_maester',
#   'citadel',
#   'samwell',
#   'library',
#   'maester_aemon',
#   'maesters',
#   'archmaester',
#   'maester_wolkan'],
#  504: ['send', 'ends', 'sends'],
#  624: ['wedding',
#   'wedding_day',
#   'wedding_night',
#   'bidding',
#   'bedding',
#   'royal_wedding',
#   'red_wedding'],
#  605: ['she’s',
#   'beautiful',
#   'child',
#   'shh',
#   'sheep',
#   'wishes',
#   'shes_dead',
#   'childhood',
#   'shy',
#   'ashes',
#   'shes_a_child',
#   'sheath'],
#  402: ['murdered', 'murders', 'murder', 'murderer', 'murdering', 'murderers'],
#  356: ['different', 'difference', 'differences'],
#  595: ['meet', 'green', 'meera', 'meereenese', 'meereen', 'mereen'],
#  288: ['khal', 'khals', 'khalasar'],
#  293: ['planning',
#   'morning',
#   'shining',
#   'winning',
#   'complaining',
#   'training',
#   'learning',
#   'waiting',
#   'beginning',
#   'landing',
#   'evening',
#   'warning',
#   'running',
#   'joining',
#   'remaining'],
#  511: ['crown', 'crow', 'crows', 'crowd', 'crowded', 'crowns'],
#  533: ['piss',
#   'boar',
#   'shit',
#   'pigs',
#   'pity',
#   'pin',
#   'piece',
#   'pig',
#   'pit',
#   'pie',
#   'pig_shit',
#   'piggy',
#   'wheel'],
#  569: ['ser_jorah',
#   'ser_jaime',
#   'ser_rodrik',
#   'ser_alliser',
#   'ser_hugh',
#   'ser_barristan',
#   'ser_gregor',
#   'ser_loras',
#   'ser_meryn',
#   'ser_dontos',
#   'ser_davos',
#   'ser_alton',
#   'ser_boros',
#   'ser_mandon',
#   'ser_bronn'],
#  432: ['served', 'deserves', 'deserved', 'deserve'],
#  563: ['pick', 'stick', 'trick', 'sick', 'lick', 'dick'],
#  252: ['putting', 'letting', 'getting', 'sitting', 'cutting', 'forgetting'],
#  235: ['let’s_go',
#   'let_me_go',
#   'lets',
#   'lets_go',
#   'let_us',
#   'let_go',
#   'let’s',
#   'i’m_gonna',
#   'go_go',
#   'we’re_gonna'],
#  626: ['little',
#   'little_lord',
#   'little_brother',
#   'visit',
#   'little_birds',
#   'littlefingers',
#   'littlefinger',
#   'little_lords',
#   'pretty_little',
#   'pass',
#   'little_lady',
#   'little_boy',
#   'little_shit',
#   'little_man',
#   'little_girl',
#   'little_princess',
#   'little_girls',
#   'little_sam'],
#  525: ['one_day',
#   'years_ago',
#   'ago',
#   'three',
#   'three_days',
#   'three_days_ago',
#   'two_days',
#   'days_ago'],
#  653: ['cover', 'lover', 'lovers', 'glover'],
#  523: ['youd',
#   'youll',
#   'youll_get',
#   'youll_want',
#   'youll_need',
#   'youll_find',
#   'youll_never',
#   'youll_see',
#   'youll_die'],
#  540: ['interest', 'interesting', 'interested', 'interests'],
#  536: ['mormont', 'jorah', 'mormonts', 'jorah_mormont'],
#  519: ['suppose', 'thats', 'supposed', 'oh_thats', 'suppose_thats'],
#  243: ['slaver', 'slaves', 'slave', 'slavers', 'slavery'],
#  244: ['selling',
#   'telling',
#   'willing',
#   'sell',
#   'calling',
#   'pulling',
#   'falling'],
#  493: ['land',
#   'story',
#   'plans',
#   'stood',
#   'vale',
#   'stone',
#   'night_lands',
#   'stormlands',
#   'winds',
#   'stores',
#   'storms_end',
#   'storm'],
#  566: ['absence',
#   'choice',
#   'presence',
#   'silence',
#   'violence',
#   'sentence',
#   'experience',
#   'patience',
#   'confidence',
#   'audience'],
#  495: ['cant_stand',
#   'cant',
#   'cant_get',
#   'cant_see',
#   'cant_defend',
#   'cant_even',
#   'cant_leave',
#   'cant_let',
#   'cant_stop',
#   'cant_sleep',
#   'cant_win',
#   'cant_believe',
#   'cant_say',
#   'cant_beat'],
#  420: ['women',
#   'children',
#   'women_and_children',
#   'grandchildren',
#   'every_man_woman_and_child',
#   'men_women_and_children'],
#  485: ['fall', 'walls', 'balls', 'halls', 'falls', 'fallen'],
#  639: ['knees', 'kneel', 'kneeling', 'kneels'],
#  306: ['service', 'serving', 'servant', 'servants'],
#  446: ['bread',
#   'breath',
#   'breathing',
#   'break',
#   'breathe',
#   'beneath',
#   'breaks'],
#  329: ['times',
#   'thousands_of_years',
#   'thousand_times',
#   'three_times',
#   'thousand',
#   'thousand_years',
#   'thousands',
#   'six_times',
#   'hundred_thousand'],
#  627: ['dressed',
#   'passed',
#   'missed',
#   'pissed',
#   'blessed',
#   'kissed',
#   'crossed',
#   'raised',
#   'carried',
#   'filled',
#   'carved',
#   'faced',
#   'tossed'],
#  537: ['fighter',
#   'fighting',
#   'knights',
#   'fights',
#   'youre_fighting',
#   'fighting_men',
#   'fighters',
#   'died_fighting',
#   'fighting_pits'],
#  588: ['forgive',
#   'course_your_grace',
#   'wish',
#   'please_your_grace',
#   'thank_you_your_grace',
#   'yes_your_grace',
#   'forgiveness',
#   'forgive_me_your_grace',
#   'dont_know_your_grace',
#   'forgiven'],
#  369: ['robert', 'king_robert', 'king_roberts', 'roberts', 'king_robb'],
#  507: ['care',
#   'take_care',
#   'dare',
#   'spare',
#   'think_im',
#   'think_youre',
#   'thinks',
#   'think_you’re',
#   'think_youll',
#   'think_shes',
#   'scare',
#   'think_i_care',
#   'think_theyll',
#   'think_it’s'],
#  305: ['screamed', 'screams', 'scream', 'screaming', 'screamer'],
#  498: ['return', 'returning', 'returned', 'returns'],
#  610: ['good_man',
#   'good_king',
#   'good_news',
#   'good_reason',
#   'good_time',
#   'good_to_see',
#   'good_one',
#   'good_men',
#   'good_deal',
#   'good_heart',
#   'good_luck',
#   'goodbye',
#   'good_lad',
#   'good_good'],
#  338: ['taken', 'stolen', 'stole'],
#  444: ['properly',
#   'proper',
#   'prophecy',
#   'proposal',
#   'property',
#   'propose',
#   'prophecies'],
#  294: ['anyway',
#   'go_away',
#   'far_away',
#   'run_away',
#   'ran_away',
#   'gave_me_away',
#   'got_away'],
#  562: ['watch', 'watched', 'watches'],
#  481: ['ive_got', 'youve_got', 'theyve', 'weve_got', 'theyve_got'],
#  607: ['needle',
#   'needs',
#   'need_a_new',
#   'need_to_get',
#   'need_help',
#   'need_to_make',
#   'need_someone',
#   'need_to_speak',
#   'need_to_find',
#   'need_to_know',
#   'need_to_keep',
#   'need_to_go',
#   'need_your_help'],
#  469: ['robert_baratheon',
#   'hey',
#   'baratheons',
#   'baratheon',
#   'stannis_baratheon',
#   'joffrey_baratheon',
#   'renly_baratheon'],
#  534: ['youve_made',
#   'ive_seen',
#   'youve_seen',
#   'ive_done',
#   'youve_done',
#   'ever_done',
#   'ever_seen',
#   'ive_never_seen',
#   'youve_come',
#   'youve_ever_seen',
#   'ive_ever_seen',
#   'youve_ever',
#   'you’ve_seen',
#   'i’ve_seen'],
#  614: ['manned',
#   'chained',
#   'trained',
#   'experienced',
#   'named',
#   'received',
#   'seemed',
#   'seized',
#   'spoke',
#   'arrived',
#   'planned',
#   'owned',
#   'sealed',
#   'spoken',
#   'drowned',
#   'joined',
#   'ruined',
#   'played',
#   'wasted',
#   'combined',
#   'signed',
#   'pardoned'],
#  350: ['sides', 'decides', 'decide', 'decided'],
#  479: ['marry', 'carry', 'arry'],
#  344: ['chance', 'lance', 'lancel', 'dance', 'mance'],
#  515: ['chances', 'alliances', 'alliance'],
#  557: ['tits', 'shits', 'sits', 'pits', 'wits', 'hits'],
#  357: ['could',
#   'could_tell',
#   'could_say',
#   'could_use',
#   'could_see',
#   'could_make',
#   'could_help',
#   'could_get',
#   'could_find',
#   'could_take',
#   'couldve'],
#  386: ['knife',
#   'twice',
#   'notice',
#   'justice',
#   'practice',
#   'voice',
#   'slice',
#   'nice',
#   'price',
#   'slit',
#   'ice'],
#  353: ['legs', 'gut', 'finds', 'guts', 'puts', 'pots'],
#  501: ['start', 'started', 'starts'],
#  339: ['ill_kill',
#   'ill_get',
#   'ill_try',
#   'ill_go',
#   'ill_tell',
#   'ill_take',
#   'l_want',
#   'ill_leave'],
#  598: ['million',
#   'champion',
#   'proof',
#   'companion',
#   'person',
#   'mission',
#   'reward',
#   'permission',
#   'opinion',
#   'personal',
#   'discussion',
#   'plan',
#   'passion',
#   'religion',
#   'onion',
#   'decision',
#   'profession',
#   'provisions',
#   'complication'],
#  422: ['threat', 'eaten', 'threatening', 'threaten', 'threats', 'threatened'],
#  489: ['ships', 'many_times', 'many_ships', 'many_men', 'many_enemies'],
#  273: ['cross', 'crossing', 'across', 'crossbow'],
#  654: ['throw', 'thrown', 'threw', 'throat', 'throats', 'pulls', 'throws'],
#  625: ['rapers', 'raped', 'rat', 'rape', 'raper'],
#  568: ['choose', 'chose', 'nose', 'lose', 'loose', 'rose'],
#  419: ['peasant', 'unpleasant', 'pleasant', 'peasants', 'giant'],
#  567: ['part', 'smart', 'art', 'apart'],
#  376: ['books', 'book', 'cook'],
#  647: ['monsters',
#   'hers',
#   'lords',
#   'masters',
#   'matters',
#   'letters',
#   'terms',
#   'crasters',
#   'quarters',
#   'invaders',
#   'oysters'],
#  388: ['belly',
#   'easily',
#   'finally',
#   'sally',
#   'silly',
#   'tully',
#   'rally',
#   'gilly',
#   'olly'],
#  587: ['steward', 'stern', 'steps', 'steal', 'stead', 'step', 'stew'],
#  555: ['require', 'squire', 'desires', 'requires', 'squires'],
#  572: ['ill_make',
#   'dont_make',
#   'wont_let',
#   'wont_get',
#   'wont_take',
#   'must_make',
#   'cant_make',
#   'wont_make'],
#  281: ['follows', 'follow', 'followed', 'following'],
#  560: ['sky',
#   'fly',
#   'flesh',
#   'group',
#   'wagon',
#   'flame',
#   'flag',
#   'flames',
#   'rocks'],
#  545: ['reason',
#   'treason',
#   'reasons',
#   'tree',
#   'treat',
#   'treasonous',
#   'reasonable'],
#  474: ['comes', 'become', 'becomes'],
#  505: ['large', 'bigger', 'larger'],
#  359: ['prayed', 'betray', 'betrayed'],
#  289: ['enemies', 'enemy', 'armies'],
#  433: ['bitch',
#   'butcher',
#   'catch',
#   'ass',
#   'hatch',
#   'eastwatch',
#   'pitch',
#   'match',
#   'kitchens',
#   'fetch',
#   'witch',
#   'kitchen'],
#  506: ['hasnt', 'ham', 'ha'],
#  547: ['ripped',
#   'chopped',
#   'stopped',
#   'wrapped',
#   'stripped',
#   'shipped',
#   'stepped',
#   'slipped',
#   'dropped',
#   'trapped',
#   'whipped'],
#  581: ['bring', 'bring_him_back', 'coming_back', 'bring_back', 'brings'],
#  476: ['joffrey',
#   'joffreys',
#   'frey',
#   'king_joffrey',
#   'freys',
#   'king_joffreys',
#   'even_joffrey',
#   'king_stannis'],
#  380: ['happened', 'happen', 'happens', 'happening'],
#  435: ['attacked', 'attack', 'attacks', 'attacking'],
#  430: ['river', 'riverrun', 'westerlands', 'lands', 'riverlands'],
#  300: ['asleep', 'deep', 'sleep', 'weep'],
#  634: ['s',
#   'hodor',
#   'hodor_hodor',
#   'hodor_hodor_hodor',
#   'hodor_hodor_hodor_hodor',
#   'hold_the_door',
#   'hold_the_door_hold_the_door'],
#  448: ['protecting',
#   'protect',
#   'protection',
#   'protected',
#   'protector',
#   'protect_us'],
#  393: ['finger', 'rangers', 'fingers'],
#  527: ['renly', 'himself', 'renlys'],
#  361: ['winter', 'wind', 'winters'],
#  436: ['cannot',
#   'cannot_give',
#   'i’ll_give',
#   'ill_give',
#   'wont_give',
#   'cannot_let'],
#  462: ['20000', '2000', '10000', '200', '100', '1000', '8000'],
#  583: ['wise', 'raise', 'rise', 'praise'],
#  450: ['nearly', 'tarly', 'clean', 'early', 'clear', 'clearly'],
#  312: ['rebel', 'rebellion', 'rebelled', 'rebels'],
#  552: ['allow', 'slow', 'low', 'blow', 'swallow', 'yellow', 'fellow'],
#  609: ['consider',
#   'refuse',
#   'choices',
#   'advantage',
#   'armory',
#   'fact',
#   'coat',
#   'continue',
#   'risk',
#   'pact',
#   'confuse',
#   'contents',
#   'wealth',
#   'control',
#   'continues',
#   'contract',
#   'destiny'],
#  314: ['command', 'commander', 'commanded', 'commands'],
#  518: ['tells', 'cells', 'martell', 'martells', 'bells'],
#  635: ['rather', 'gather', 'bother', 'further', 'fewer', 'farther', 'weather'],
#  524: ['cities',
#   'tries',
#   'dies',
#   'lies',
#   'spies',
#   'allies',
#   'flies',
#   'bodies'],
#  548: ['climb', 'climbed', 'onto', 'rope', 'climbs', 'cliff'],
#  487: ['knowledge', 'edge', 'pledge', 'sledge'],
#  334: ['turn', 'turns', 'turned'],
#  408: ['place', 'placed', 'places'],
#  517: ['hadnt',
#   'cunt',
#   'couldnt',
#   'wouldnt',
#   'wouldnt_let',
#   'wouldnt_know',
#   'wouldnt_mind',
#   'couldnt_keep',
#   'couldnt_bear',
#   'wouldnt_you_say'],
#  400: ['dont_imagine', 'imagine', 'imagined'],
#  343: ['cerseis', 'cersei', 'joffrey_cersei', 'queen_cersei'],
#  366: ['dangerous',
#   'famous',
#   'curious',
#   'vicious',
#   'generous',
#   'serious',
#   'obvious',
#   'glorious',
#   'tedious',
#   'precious',
#   'suspicious'],
#  470: ['heart', 'hearts', 'hears'],
#  345: ['arrow', 'row', 'arrows', 'sparrow'],
#  475: ['strong', 'longer', 'stronger', 'strongest'],
#  637: ['eats', 'cats', 'lts', 'rats', 'boats', 'twats'],
#  459: ['number', 'numbers', 'umbers'],
#  458: ['given', 'provided', 'provide', 'proved', 'prove', 'proven'],
#  558: ['ate', 'gates', 'gate'],
#  535: ['taste', 'red_keep', 'restore', 'waste', 'red_god', 'red_waste'],
#  603: ['cold',
#   'holds',
#   'hold',
#   'bold',
#   'sail',
#   'holdfast',
#   'grow_old',
#   'uphold',
#   'karhold'],
#  406: ['eventually', 'usually', 'actually', 'act', 'actual', 'ally'],
#  544: ['westeros', 'lords_of_westeros', 'west', 'westerosi'],
#  652: ['greyjoy',
#   'balon_greyjoy',
#   'greyjoys',
#   'lord_greyjoy',
#   'theon_greyjoy',
#   'euron_greyjoy',
#   'euron'],
#  455: ['disappointment',
#   'point',
#   'disappoint',
#   'disappeared',
#   'disappointed',
#   'points',
#   'disappear'],
#  477: ['defend', 'defense', 'defenses'],
#  368: ['marching', 'searching', 'march'],
#  371: ['possible', 'impossible', 'possibly'],
#  372: ['build', 'built', 'builders'],
#  392: ['names', 'games', 'game'],
#  657: ['guards', 'guard', 'yards', 'boat', 'board', 'regards', 'two_guards'],
#  578: ['coins',
#   'ruin',
#   'sins',
#   'remains',
#   'runs',
#   'twins',
#   'begins',
#   'wins',
#   'tywins',
#   'ruins'],
#  541: ['jons', 'tyrion', 'tyrions'],
#  532: ['claim', 'claims', 'claimed'],
#  381: ['gendry', 'davos', 'gendrys'],
#  528: ['four', 'pour', 'sour'],
#  564: ['cock', 'lock', 'luck', 'knock', 'flock', 'rock', 'nock', 'mock'],
#  473: ['lead', 'heads', 'leaves', 'leads'],
#  399: ['concerned', 'concerns', 'concerning', 'concern'],
#  522: ['loras',
#   'tyrell',
#   'loras_tyrell',
#   'tyrells',
#   'ser_loras_tyrell',
#   'margaery',
#   'house_tyrell',
#   'lord_tyrell'],
#  577: ['freedom', 'free', 'freed'],
#  411: ['safely', 'safety', 'safe', 'safer'],
#  412: ['prisoner', 'prisoners', 'prison'],
#  579: ['grant', 'grand', 'grandson', 'grandsons'],
#  424: ['charges', 'charge', 'charged'],
#  656: ['earth', 'qarth', 'tarth', 'naarth'],
#  445: ['conqueror', 'conquerors', 'conquering', 'conquered', 'conquer'],
#  561: ['smile', 'smiles', 'miles'],
#  636: ['lord_bolton',
#   'boltons',
#   'roose_bolton',
#   'ramsay',
#   'bolton',
#   'ramsay_bolton']}

# %% [markdown]
# These clusters are okay, but there's definitely a lot that could be improved.
#
# Quiz: What would make these clusters better?
# - more data
# - longer convergence iter
# - less weight on character parts

# %% [markdown]
# _Wait a second, what do you mean by better?_

# %% [markdown]
# ### How do I compare two clustering results?
#
# A metric exists to do this: the [silhouette score](https://en.wikipedia.org/wiki/Silhouette_(clustering)#:~:targetText=The%20silhouette%20value%20is%20a,poorly%20matched%20to%20neighboring%20clusters.).
#
# > The silhouette value is a measure of how similar an object is to its own cluster (cohesion) compared to other clusters (separation).
#
# From [sklearn](https://scikit-learn.org/stable/modules/generated/sklearn.metrics.silhouette_score.html#sklearn.metrics.silhouette_score)
# > The Silhouette Coefficient is calculated using the mean intra-cluster distance (a) and the mean nearest-cluster distance (b) for each sample. The Silhouette Coefficient for a sample is (b - a) / max(a, b). To clarify, b is the distance between a sample and the nearest cluster that the sample is not a part of.
#
# Sure was clear, eh?

# %% [markdown]
# Let's get a better definition of $a$ and $b$.
#
# ![intra-cluster distance](figures/silhouette-a.png)
#
# So for each point $i$ in a cluster, we define $a(i)$ to be the average distance between $i$ and every other point in the cluster. This is a measure of how well $i$ fits in its cluster.
#
# What kind of value (smaller or larger) for $a(i)$ indicates a good fit?

# %% [markdown]
# ![mean nearest-cluster distance](figures/silhouette-b.png)
#
# We find the next-best fitting (or _neighboring_) cluster for point $i$, and measure the average distance from $i$ to all points in that next-best fitting cluster.
#
# What does a high value for $b(i)$ indicate? A low one?

# %% [markdown]
# Now actually to the funciton for the silhouette score...
#
# ![silhouette-score-def](figures/silhouette-def.png)
#
# Which can also be written as a piecewise function that's easier to analyze
#
# ![silhouette-rewritten](figures/silhouette-rewritten.png)
#
# How do $a(i)$ and $b(i)$ compare in each of these situations?
#
# Does this make the silhouette score bounded or unbounded?
#
# Is a higher or lower silhouette score better?

# %% [markdown]
# Let's get a visualization of what's really going on.
#
# ![silhouette visualized](figures/silhouette-visualized.gif)

# %% [markdown]
# Since we care about more than a single point in the clustering results, we average over all points to get teh silhouete score for a data set.
#
# ![Silhouette scores](figures/silhouette_analysis.png)

# %%
from sklearn.metrics import silhouette_score
# sklearn computes the mean silhouette score for all samples
silhouette_score(vectors, af.labels_)
# Out:
# 0.05875264

# %% [markdown]
# Let's compare this with the unphrased model

# %%
# load in the unphrased model
unphrased_model_path = os.path.join('models', 'got_ft.model')
unphrased_model = FastText.load(unphrased_model_path)

# %%
# preprocess and cluster
vectors, words = get_vectors_and_words(unphrased_model)
af = AffinityPropgation()

# %%
# get the silhouette score
clusters = get_clusters(words, af)
insightful_clusters = get_insightful_clusters(clusters)    
insightful_clusters

# %% [markdown]
# ## Which model was better?
#
# Objectively: Which model had the better silhouette score?
#
# Subjectively: Let's check out the clusters too.

# %%
# look at the first 20 clusters from the unphrased model

# %% [markdown]
# Sure enough, seems like worse clusters without the phrased data.

# %% [markdown]
# ## Labeling Clusters Using a Hierarchy
#
# Powerpoint presentation [here](https://callminer-my.sharepoint.com/:p:/p/kirsten_stallings/Ef_H9hSc15FPnujGQDGVdp4B6zCQGJZSpjgCs_ZfSBChxQ?e=d6zbhY).
#
# These clusters are insightful, but there's a lot of them to dig through. It's hard to know where to start.
#
# If each cluster had a _label_, we could sort on that label and get things closer together, focusing on the clusters we want to refine first.
#
# In order to label these clusters, we need a resource to know which words tend to get this label. This is the _hierarchy_, a tree of terms.
#
# Each node cruciall has
# - a name or label, like `root-feeling-negative_sentiment-angry`
#
# and each node _might_ have
# - children -  child of `root-feeling-negative_sentiment-angry` might be `root-feeling-negative_sentiment-angry-irate`
# - parents - the parent of `root-feeling-negative_sentiment-angry` is `root-feeling-negative_sentiment`
# - words that are associated with this label, like `upset, frustrated, in_denial, angry`
#
# Each child of that node contains concepts that are more specific.
#
# For instance,
# > dog -> herders -> shetland sheepdog
#
# Given a cluster and a word embedding model, the _labeler_ moves through the hierarchy to determine the best label for this unseen cluster.
#
# ![hiearchy and labeler](figures/hierarchy-and-labeler.png)

# %% [markdown]
# ## The Hierarchy
#
# Here's an example from the hierarchy we created by using clusters from call center data.
#
# ![hierarchy expanding](figures/hierarchy-expanding.gif)
#
# Each of these children of root holds a lot of significance in the call center space. That's the first distinction we make on a word/phrase!
#
# These concepts are crucially never client or product specific. Since this will be used across many different clients, we don't want the product name from one to influence another incorrectly.

# %% [markdown]
# ## The Labeler
#
# The labeler moves throught the hierarchy to find the best fitting name for the unseen cluster generated above in the clustering step.
#
# First, we find the centroid of the unseen cluster. We average all the word vectors to get the _centroid_, a vector that represents this cluster in space.
#
# The labeler is looking to find the closest centroid in the hierarchy to the centroid of the cluster we are currrently looking at. We look at two centroids:
#
# 1. The vectors for the words in the node and it's subtree
# 2. The vectors for only the words in the node.
#
# We use the client's FastText model to calculate the centroids of the hierarchy nodes, effectively projecting the hierarchy into the client's space.
#
# Quiz: _Why is it important to use the client's model here?_
#
# We take all the word vectors in the subtree rooted at the current node and average them to get the centroid. The serves as the middle location for this node in the the client's vector space. For each child of root, we have a centroid.
#
# We also compare with the centroid based on the words at this node _only_. If either of the two of those centroids is closer than the previously-considered-closest centroid, we move to this node in the tree and repeat with its children.
#
# When the closest centroid is found (none of the children's centroids are closer than the current node's), we label this cluster with the name of this node in the hierarchy.
#
# ![moving through the hierarchy](figures/moving-through-the-hierarchy.gif)

# %%
# we can't show you any code for this - we'd have to build a whole new GOT hierarchy

# %% [markdown]
# Here are some examples of the hierarchy and labeler performing on real call center clusters:
#
# ![real life examples](figures/labeled-clusters.png)

# %% [markdown]
# # Summary
# - what is clustering?
# - clustering algorithms
#     - k-means
#     - hierarchical clustering
#         - affinity propagation
# - clustering word embeddings
#     - how to get insight from clusters of word embeddings
# - labeling clusters using a hierarchy
